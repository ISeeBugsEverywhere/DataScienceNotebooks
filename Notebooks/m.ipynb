# %%
# %load_ext autoreload

# %%
# %autoreload -p 2

# %%
import manoFunkcijos as mF
import matplotlib.pyplot as plt

# %%
fig = mF.pieOfPie([80,40,30], [50,50,90], labels=['a','b','c'], labels_s=['Y', 'N', 'F'], angle=90)
plt.show()
# Out:
# angle=90, o_r[0]=0.5333333333333333
