# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import sqlite3
import mysql.connector as cnt
import plotly.express as px

# %%
imu = pd.read_csv('../DATA/imunizacija.csv')
imu.head(2)
# Out:
#    ESRI_OID  workplace_code                     workplace_name  \
# 0         1       110004884  Uždaroji akcinė bendrovė "VILLON"
# 1         2       110005648       UAB "Informacinės paslaugos"
#
#    activity_evrk2      municipality           county  employees  \
# 0        551000.0  Vilniaus r. sav.  Vilniaus apskr.        170
# 1        620100.0  Vilniaus m. sav.  Vilniaus apskr.         25
#
#   immunised_percent  percentile_1  percentile_2  as_of_date
# 0           90-100%            92          94.0  2022-03-20
# 1           90-100%            69          71.0  2022-03-20

# %%
imu.tail(5)
# Out:
#        ESRI_OID  workplace_code workplace_name  activity_evrk2  \
# 19823     19824       305997621            NaN        422200.0
# 19824     19825       306019829            NaN             NaN
# 19825     19826       306025216            NaN             NaN
# 19826     19827       306027128            NaN             NaN
# 19827     19828       306027224            NaN             NaN
#
#             municipality            county  employees immunised_percent  \
# 19823      Kauno m. sav.      Kauno apskr.         15            70-79%
# 19824  Klaipėdos m. sav.  Klaipėdos apskr.         10           90-100%
# 19825   Vilniaus m. sav.   Vilniaus apskr.        175            80-89%
# 19826   Vilniaus m. sav.   Vilniaus apskr.         10           90-100%
# 19827   Vilniaus m. sav.   Vilniaus apskr.         10           90-100%
#
#        percentile_1  percentile_2  as_of_date
# 19823            23          24.0  2022-03-20
# 19824            49           NaN  2022-03-20
# ...

# %%
imu.dropna(subset=['activity_evrk2', 'workplace_name' ], how='all', inplace=True)

# %%
imu.tail(5)
# Out:
#        ESRI_OID  workplace_code workplace_name  activity_evrk2  \
# 19819     19820       305972116            NaN        161000.0
# 19820     19821       305973296            NaN        464200.0
# 19821     19822       305981108            NaN        475200.0
# 19822     19823       305987794            NaN        711220.0
# 19823     19824       305997621            NaN        422200.0
#
#             municipality            county  employees immunised_percent  \
# 19819      Kauno r. sav.      Kauno apskr.         80           90-100%
# 19820  Klaipėdos r. sav.  Klaipėdos apskr.         10           90-100%
# 19821   Vilniaus r. sav.   Vilniaus apskr.         10            80-89%
# 19822  Klaipėdos m. sav.  Klaipėdos apskr.         15           90-100%
# 19823      Kauno m. sav.      Kauno apskr.         15            70-79%
#
#        percentile_1  percentile_2  as_of_date
# 19819            58          60.0  2022-03-20
# 19820           100         100.0  2022-03-20
# ...

# %%
imu = pd.read_csv('../DATA/imunizacija.csv')
imu.head(2)
# Out:
#    ESRI_OID  workplace_code                     workplace_name  \
# 0         1       110004884  Uždaroji akcinė bendrovė "VILLON"
# 1         2       110005648       UAB "Informacinės paslaugos"
#
#    activity_evrk2      municipality           county  employees  \
# 0        551000.0  Vilniaus r. sav.  Vilniaus apskr.        170
# 1        620100.0  Vilniaus m. sav.  Vilniaus apskr.         25
#
#   immunised_percent  percentile_1  percentile_2  as_of_date
# 0           90-100%            92          94.0  2022-03-20
# 1           90-100%            69          71.0  2022-03-20

# %%
imu.head(6)
# Out:
#    ESRI_OID  workplace_code                     workplace_name  \
# 0         1       110004884  Uždaroji akcinė bendrovė "VILLON"
# 1         2       110005648       UAB "Informacinės paslaugos"
# 2         3       110011925               UAB "Eltel Networks"
# 3         4       110012112                            UAB IDW
# 4         5       110012450                        AB "Grigeo"
# 5         6       110015560    Uždaroji akcinė bendrovė "INTA"
#
#    activity_evrk2      municipality           county  employees  \
# 0        551000.0  Vilniaus r. sav.  Vilniaus apskr.        170
# 1        620100.0  Vilniaus m. sav.  Vilniaus apskr.         25
# 2        422200.0  Vilniaus m. sav.  Vilniaus apskr.        230
# 3        329900.0  Vilniaus m. sav.  Vilniaus apskr.        175
# 4        172200.0  Vilniaus m. sav.  Vilniaus apskr.        270
# 5        639900.0  Vilniaus m. sav.  Vilniaus apskr.         10
#
#   immunised_percent  percentile_1  percentile_2  as_of_date
# ...

# %%
imu.loc[[1,2,3,4], ['workplace_code', 'workplace_name',	'activity_evrk2','municipality','county']]
# Out:
#    workplace_code                workplace_name  activity_evrk2  \
# 1       110005648  UAB "Informacinės paslaugos"        620100.0
# 2       110011925          UAB "Eltel Networks"        422200.0
# 3       110012112                       UAB IDW        329900.0
# 4       110012450                   AB "Grigeo"        172200.0
#
#        municipality           county
# 1  Vilniaus m. sav.  Vilniaus apskr.
# 2  Vilniaus m. sav.  Vilniaus apskr.
# 3  Vilniaus m. sav.  Vilniaus apskr.
# 4  Vilniaus m. sav.  Vilniaus apskr.

# %%
imu.loc[1, 'workplace_name']
# Out:
# 'UAB "Informacinės paslaugos"'

# %%
imu.head(5)
# Out:
#    ESRI_OID  workplace_code                     workplace_name  \
# 0         1       110004884  Uždaroji akcinė bendrovė "VILLON"
# 1         2       110005648       UAB "Informacinės paslaugos"
# 2         3       110011925               UAB "Eltel Networks"
# 3         4       110012112                            UAB IDW
# 4         5       110012450                        AB "Grigeo"
#
#    activity_evrk2      municipality           county  employees  \
# 0        551000.0  Vilniaus r. sav.  Vilniaus apskr.        170
# 1        620100.0  Vilniaus m. sav.  Vilniaus apskr.         25
# 2        422200.0  Vilniaus m. sav.  Vilniaus apskr.        230
# 3        329900.0  Vilniaus m. sav.  Vilniaus apskr.        175
# 4        172200.0  Vilniaus m. sav.  Vilniaus apskr.        270
#
#   immunised_percent  percentile_1  percentile_2  as_of_date
# 0           90-100%            92          94.0  2022-03-20
# 1           90-100%            69          71.0  2022-03-20
# ...

# %%
imu.loc[1, 'workplace_name'] = "UAB Trys blynai"
imu.head()
# Out:
#    ESRI_OID  workplace_code                     workplace_name  \
# 0         1       110004884  Uždaroji akcinė bendrovė "VILLON"
# 1         2       110005648                    UAB Trys blynai
# 2         3       110011925               UAB "Eltel Networks"
# 3         4       110012112                            UAB IDW
# 4         5       110012450                        AB "Grigeo"
#
#    activity_evrk2      municipality           county  employees  \
# 0        551000.0  Vilniaus r. sav.  Vilniaus apskr.        170
# 1        620100.0  Vilniaus m. sav.  Vilniaus apskr.         25
# 2        422200.0  Vilniaus m. sav.  Vilniaus apskr.        230
# 3        329900.0  Vilniaus m. sav.  Vilniaus apskr.        175
# 4        172200.0  Vilniaus m. sav.  Vilniaus apskr.        270
#
#   immunised_percent  percentile_1  percentile_2  as_of_date
# 0           90-100%            92          94.0  2022-03-20
# 1           90-100%            69          71.0  2022-03-20
# ...

# %%
imu.loc[[1,2,3,4], ['workplace_code', 'workplace_name',	'activity_evrk2','municipality','county']] = "Sugadinau duomenis kątik"
imu.head(10)
# Out:
#    ESRI_OID            workplace_code                         workplace_name  \
# 0         1                 110004884      Uždaroji akcinė bendrovė "VILLON"
# 1         2  Sugadinau duomenis kątik               Sugadinau duomenis kątik
# 2         3  Sugadinau duomenis kątik               Sugadinau duomenis kątik
# 3         4  Sugadinau duomenis kątik               Sugadinau duomenis kątik
# 4         5  Sugadinau duomenis kątik               Sugadinau duomenis kątik
# 5         6                 110015560        Uždaroji akcinė bendrovė "INTA"
# 6         7                 110018147                             UAB "RASO"
# 7         8                 110019434  UŽDAROJI AKCINĖ BENDROVĖ "TRANSLITAS"
# 8         9                 110022220                            UAB "KOMEX"
# 9        10                 110027534                       UAB "Transfriga"
#
#              activity_evrk2              municipality  \
# 0                  551000.0          Vilniaus r. sav.
# ...

# %%
imu.iloc[[1,2],[1,2,3,4]]
# Out:
#              workplace_code            workplace_name  \
# 1  Sugadinau duomenis kątik  Sugadinau duomenis kątik
# 2  Sugadinau duomenis kątik  Sugadinau duomenis kątik
#
#              activity_evrk2              municipality
# 1  Sugadinau duomenis kątik  Sugadinau duomenis kątik
# 2  Sugadinau duomenis kątik  Sugadinau duomenis kątik

# %%
df = imu.iloc[[*range(10,21,2)], [1,2,3,4,5]]

# %%
df
# Out:
#    workplace_code                                     workplace_name  \
# 10      110032524                 Uždaroji akcinė bendrovė "SEIFUVA"
# 12      110051115  Bendra Lietuvos-Rusijos-Olandijos įmonė uždaro...
# 14      110051834               Akcinė bendrovė "Lietuvos draudimas"
# 16      110053842           Akcinė bendrovė "Lietuvos geležinkeliai"
# 18      110057335  Viešoji įstaiga Lietuvos žemės ūkio konsultavi...
# 20      110058241                Lietuvos pramonininkų konfederacija
#
#    activity_evrk2           county
# 10       259900.0    Utenos apskr.
# 12       581100.0  Vilniaus apskr.
# 14       651200.0  Vilniaus apskr.
# 16       492000.0  Vilniaus apskr.
# 18       749000.0     Kauno apskr.
# 20       941100.0  Vilniaus apskr.

# %%
df.drop('county', axis=1)
# Out:
#    workplace_code                                     workplace_name  \
# 10      110032524                 Uždaroji akcinė bendrovė "SEIFUVA"
# 12      110051115  Bendra Lietuvos-Rusijos-Olandijos įmonė uždaro...
# 14      110051834               Akcinė bendrovė "Lietuvos draudimas"
# 16      110053842           Akcinė bendrovė "Lietuvos geležinkeliai"
# 18      110057335  Viešoji įstaiga Lietuvos žemės ūkio konsultavi...
# 20      110058241                Lietuvos pramonininkų konfederacija
#
#    activity_evrk2
# 10       259900.0
# 12       581100.0
# 14       651200.0
# 16       492000.0
# 18       749000.0
# 20       941100.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import sqlite3
import mysql.connector as cnt
import plotly.express as px

# %%
f = pd.read_csv('../DATA/OOP_DATA/V1145_A_3k_FW_2.05.dat', usecols=[0,1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 f = pd.read_csv('../DATA/OOP_DATA/V1145_A_3k_FW_2.05.dat', usecols=[0,1])
#
# File /usr/lib/python3/dist-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
# ...
