# %%
class PirmojiKlase():
    def __init__(self) -> None:
        print('konstruktorius sukurtas')

a= PirmojiKlase()
# Out:
# konstruktorius sukurtas

# %%
class PirmojiKlase():
    def __init__(self) -> None:
        print('konstruktorius sukurtas')
    
    def __del__(self):
        print('destruktorius veikia')
        
a= PirmojiKlase()
del a
# Out:
# konstruktorius sukurtas
# destruktorius veikia

# %%
class PirmojiKlase():
    def __init__(self) -> None:
        self.X=15


a=PirmojiKlase()

print(a.X)
a.X=30

print(a.X)
# Out:
# 15
# 30

# %%
class PirmojiKlase():
    def __init__(self) -> None:
        self.X=15
    
    def getX(self):
        print(self.X)
    
    def keiciamX(self):
        self.X=self.X*2
        


a=PirmojiKlase()
a.getX()
a.keiciamX()
a.getX()
# Out:
# 15
# 30

# %%
import time
class Tarakonas():
    def __init__(self) -> None:
        print('išsirito tarakonas')
        self.gimtadienis=time.time()
    def __del__(self):
        print('Tarakonas mirė. Jis gyveno:',time.time()-self.gimtadienis)
Rudis=Tarakonas()
time.sleep(0.7)
Juodis=Tarakonas()
time.sleep(0.7)
Pilkis=Tarakonas()
print(Rudis.gimtadienis)
print(Juodis.gimtadienis)
print(Pilkis.gimtadienis)
del Rudis
del Juodis
del Pilkis
# Out:
# išsirito tarakonas
# Tarakonas mirė. Jis gyveno: 32.023568868637085
# išsirito tarakonas
# Tarakonas mirė. Jis gyveno: 32.02310395240784
# išsirito tarakonas
# Tarakonas mirė. Jis gyveno: 32.022924184799194
# 1721234686.790143
# 1721234687.4912407
# 1721234688.1917195
# Tarakonas mirė. Jis gyveno: 1.4015765190124512
# Tarakonas mirė. Jis gyveno: 0.7004787921905518
# Tarakonas mirė. Jis gyveno: 0.0

# %%
failo_vardas = 'V1670_2024-04-24.dat'

failas = open(failo_vardas, mode='r', encoding='utf-8')
turinys = failas.readlines()
failas.close()

list1=[]
list2=[]
list3=[]
list4=[]
list5=[]
list6=[]

for i in turinys[3:-1]:
    eilute=i.split()
    if eilute[0]=='Tamsa':
        break
    list1.append(float(eilute[0]))
    list2.append(float(eilute[1]))
    list3.append(float(eilute[2]))
    list4.append(float(eilute[3]))
    list5.append(float(eilute[4]))
    list6.append(eilute[5])   

print(list5)
# Out:
# [4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 4.0, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 4.0, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 4.0, 3.93, 4.0, 4.0, 4.07, 4.07, 4.07, 4.07, 4.07, 3.86, 3.86, 4.07, 4.07, 3.73, 3.73, 4.27, 4.27, 3.73, 3.73, 3.73, 3.73, 3.73, 3.73, 3.79, 3.79, 3.79, 3.86, 3.86, 3.86, 3.86, 4.07, 4.07, 4.07, 3.86, 3.86, 3.86, 3.86, 3.93, 3.93, 3.93, 3.93, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 3.93, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 4.0, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 
# ...

# %%
import os
import glob

os.chdir(r"C:\Users\pauli\Desktop\DataScienceNotebooks\DATA")
dat_failai = glob.glob('*.dat')


list1=[]
list2=[]
list3=[]
list4=[]
list5=[]
list6=[]

for f in dat_failai:
    
    failas = open(f, mode='r', encoding='utf-8')
    turinys = failas.readlines()
    failas.close()
    
    for i in turinys[3:-1]:
        eilute=i.split()
        if eilute[0]=='Tamsa':
            break
        list1.append(float(eilute[0]))
        list2.append(float(eilute[1]))
        list3.append(float(eilute[2]))
        list4.append(float(eilute[3]))
        list5.append(float(eilute[4]))
        list6.append(eilute[5])   

print(list5)
# Out:
# [4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 4.0, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 4.0, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 4.0, 3.93, 4.0, 4.0, 4.07, 4.07, 4.07, 4.07, 4.07, 3.86, 3.86, 4.07, 4.07, 3.73, 3.73, 4.27, 4.27, 3.73, 3.73, 3.73, 3.73, 3.73, 3.73, 3.79, 3.79, 3.79, 3.86, 3.86, 3.86, 3.86, 4.07, 4.07, 4.07, 3.86, 3.86, 3.86, 3.86, 3.93, 3.93, 3.93, 3.93, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 3.93, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 4.0, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 
# ...

# %%
import os
import glob

os.chdir(r"C:\Users\pauli\Desktop\DataScienceNotebooks\DATA")
dat_failai = glob.glob('*.dat')

def is_float(string):
    try:
        float(string)
        return True
    except ValueError:
        return False

list1=[]
list2=[]
list3=[]
list4=[]
list5=[]
list6=[]

for f in dat_failai:
    
    failas = open(f, mode='r', encoding='utf-8')
    turinys = failas.readlines()
    failas.close()
    
    for i in turinys:
        eilute=i.split()
        if is_float(eilute[0]):
            list1.append(float(eilute[0]))
            list2.append(float(eilute[1]))
            list3.append(float(eilute[2]))
            list4.append(float(eilute[3]))
            list5.append(float(eilute[4]))
            list6.append(eilute[5])   

print(list5)
# Out:
# [4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 4.0, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 4.0, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 4.0, 3.93, 4.0, 4.0, 4.07, 4.07, 4.07, 4.07, 4.07, 3.86, 3.86, 4.07, 4.07, 3.73, 3.73, 4.27, 4.27, 3.73, 3.73, 3.73, 3.73, 3.73, 3.73, 3.79, 3.79, 3.79, 3.86, 3.86, 3.86, 3.86, 4.07, 4.07, 4.07, 3.86, 3.86, 3.86, 3.86, 3.93, 3.93, 3.93, 3.93, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 4.07, 3.93, 3.93, 3.93, 4.0, 4.0, 4.0, 4.07, 4.07, 4.0, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 3.93, 4.0, 4.0, 4.0, 4.0, 4.07, 4.07, 3.93, 
# ...

# %%
import os
import glob

os.chdir(r"C:\Users\pauli\Desktop\DataScienceNotebooks\DATA")
dat_failai = glob.glob('*.dat')
print(dat_failai)
txt_failai = glob.glob('*.txt')
print(txt_failai)

def is_float(string):
    try:
        float(string)
        return True
    except ValueError:
        return False
    
def is_empty(list, nr):
    try:
        len(list[nr]) >0
        return True
    except IndexError:
        return False



def atrenkame_stulpeli(f, st):
    
    failas = open(f, mode='r', encoding='utf-8')
    turinys = failas.readlines()
    failas.close()
    
    for i in range(0, len(turinys)):
        turinys[i]=turinys[i].replace(';','').replace(',', '.').split()

    ats=[]
    
    if len(turinys[0]) >= stulpelio_nr and stulpelio_nr>0:
        for i in turinys: 
            if is_empty(i, 0):
                if is_float(i[0]) and is_float(i[1]):
                    if is_float(i[st-1]):
                        ats.append(float(i[st-1]))
                    else:
                        ats.append(i[st-1])       
    else:
        print('ivedete per dideli arba per maza stulpelio nr')
    return ats


list=[]
stulpelio_nr=2
list=atrenkame_stulpeli(dat_failai[1], stulpelio_nr)
print(list)
# Out:
# ['V1670_2024-04-24.dat', 'V1671_2024-04-24.dat', 'V1672(CB)_2024-04-24.dat', 'V1672(DCM)_2024-04-24.dat']
# ['Skaityk.txt', 'V1244S_20210409_14h56.txt', 'V1296OLD_20210409_18h24.txt', 'V1296S_20210409_15h31.txt', 'V1296T_20210409_16h20.txt']
# ...

# %%
import os
import glob

os.chdir(r"C:\Users\pauli\Desktop\DataScienceNotebooks\DATA")
txt_failai = glob.glob('*.txt')
print(txt_failai)

failas = open(txt_failai[2], mode='r', encoding='utf-8')
turinys = failas.readlines()
failas.close()
    
for i in range(0, len(turinys)):
    turinys[i]=turinys[i].replace(';','').replace(',', '.').split()
    
print(turinys[0])
print(turinys[1])
print(turinys[5])
list=['a', '1', '5.32', '45', 'gdh4']

a=turinys[1]

def is_float(string):
    try:
        float(string)
        return True
    except ValueError:
        return False
    

    
def is_empty(list, nr):
    try:
        len(list[nr]) >0
        return True
    except IndexError:
        return False
    
if is_empty(a, 0):
    if is_float(a[0]):
        print('floatas')
    else:
        print('nefloatas')
else:
    print('tuscias')

    
#is_float(a[1])
# Out:
# ['Skaityk.txt', 'V1244S_20210409_14h56.txt', 'V1296OLD_20210409_18h24.txt', 'V1296S_20210409_15h31.txt', 'V1296T_20210409_16h20.txt']
# ['Eil.Nr.', 'hv.', '[eV]', 'Cor(N/Le)', '[min-1]Cor(N/Lq)', '[min-1]Ni', 'vertė', 'Ni/min.', 'Sqrt(Ni)', 'Dujos', 'E.light', 'Q.Light', 'Laikas']
# []
# ['3', '4.5', '73', '65', '9', '54', '7', '226', '0.740906', '0.83348', '16:24:08']
# tuscias
