# %%
# dat_failai = glob.glob('../../DATA/OOP_DATA/*.dat')
import os
import glob

failai = os.listdir()
print(failai)
# Out:
# ['01.ipynb', '02.ipynb', '03.ipynb', '04.ipynb', '05.ipynb', '06.ipynb', '07.ipynb', '08-09.ipynb', '10.ipynb', '11.ipynb', '12.ipynb', '13.ipynb', '14.ipynb', '15.ipynb', '16.ipynb', '21.ipynb', '22.ipynb', '23.ipynb', '24.ipynb', '25.ipynb', '26-27.ipynb', '28.ipynb', '29.ipynb', '30.ipynb', '31.ipynb', '32.ipynb', '33.ipynb', '34.ipynb', '35.ipynb', '36.ipynb', '37.ipynb', '38.ipynb', '39.ipynb', '40.ipynb', '41.ipynb', '42 autopliuslt uzduotis.ipynb', '42-43 uzduoties grafikai.ipynb', '44-47.ipynb', '48.ipynb', '49.ipynb', '50.ipynb', '51.ipynb', 'DATA', 'elektros vartojimas.ipynb', 'Skriptai', 'Tekstiniai failai', 'templates.ipynb', '__pycache__']

# %%
dat_failai = glob.glob('C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0/REF*.dat')

# %%
print(dat_failai)
df[' P[mW/cm^2]']
# Out:
# ['C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0\\REF_D_1k_FW_2.08.dat', 'C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0\\REF_D_2k_FW_2.05.dat', 'C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0\\REF_D_3k_FW_2.03.dat', 'C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0\\REF_D_4k_FW_2.05.dat', 'C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0\\REF_D_5k_FW_2.05.dat', 'C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0\\REF_D_5k_FW_2.07.dat']

# %%
def get_file_by_min_val(location, column):
    import pandas as pd
    import glob
    dat_failai = glob.glob(location)
    files = []
    min_p = []
    for file in dat_failai:
        df = pd.read_csv(file, delimiter=';')
        min_p.append(min(list(df[column])))
        files.append(file)
        
    for file, val in zip(files,min_p):
        if val == min(min_p):
            print(file, val)
            f = file.split('/')[-1]
            print(f)
            return [file, round(val*-1,2), f]

# %%
print(get_file_by_min_val('C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0/REF*.dat',' P[mW/cm^2]'))
# Out:
# C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0\REF_D_1k_FW_2.08.dat

# %%
import pandas as pd
# REF
file_day0 = get_file_by_min_val('C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0/REF*.dat',' P[mW/cm^2]')
file_day1 = get_file_by_min_val('C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY1/REF*.dat',' P[mW/cm^2]')
file_day2 = get_file_by_min_val('C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY2/REF*.dat',' P[mW/cm^2]')
df_day0 = pd.read_csv(file_day0[0], delimiter=';')
df_day1 = pd.read_csv(file_day1[0], delimiter=';')
df_day2 = pd.read_csv(file_day2[0], delimiter=';')
df_day0['j']= df_day0[' j[mA/cm^2] '].apply(lambda x: x*-1)
df_day0['Type']= df_day0[' j[mA/cm^2] '].apply(lambda x: f"DAY0 {file_day0[2]} {file_day0[1]}%")
df_day1['j']= df_day1[' j[mA/cm^2] '].apply(lambda x: x*-1)
df_day1['Type']= df_day1[' j[mA/cm^2] '].apply(lambda x: f"DAY1 {file_day1[2]} {file_day1[1]}%")
df_day2['j']= df_day2[' j[mA/cm^2] '].apply(lambda x: x*-1)
df_day2['Type']= df_day2[' j[mA/cm^2] '].apply(lambda x: f"DAY2 {file_day2[2]} {file_day2[1]}%")
df = pd.concat([df_day0,df_day1,df_day2])
# V1145
file1_day0 = get_file_by_min_val('C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0/V1145*.dat',' P[mW/cm^2]')
file1_day1 = get_file_by_min_val('C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY1/V1145*.dat',' P[mW/cm^2]')
file1_day2 = get_file_by_min_val('C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY2/V1145*.dat',' P[mW/cm^2]')
df1_day0 = pd.read_csv(file1_day0[0], delimiter=';')
df1_day1 = pd.read_csv(file1_day1[0], delimiter=';')
df1_day2 = pd.read_csv(file1_day2[0], delimiter=';')
df1_day0['j']= df1_day0[' j[mA/cm^2] '].apply(lambda x: x*-1)
df1_day0['Type']= df1_day0[' j[mA/cm^2] '].apply(lambda x: f"DAY0 {file1_day0[2]} {file1_day0[1]}%")
df1_day1['j']= df1_day1[' j[mA/cm^2] '].apply(lambda x: x*-1)
df1_day1['Type']= df1_day1[' j[mA/cm^2] '].apply(lambda x: f"DAY1 {file1_day1[2]} {file1_day1[1]}%")
df1_day2['j']= df1_day2[' j[mA/cm^2] '].apply(lambda x: x*-1)
df1_day2['Type']= df1_day2[' j[mA/cm^2] '].apply(lambda x: f"DAY2 {file1_day2[2]} {file1_day2[1]}%")
df1 = pd.concat([df1_day0,df1_day1,df1_day2])
# Out:
# C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0\REF_D_1k_FW_2.08.dat -14.9890787
# REF_D_1k
# C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY1\REF_D_1k_24h_FW_2.03.dat -9.7706286
# REF_D_1k
# C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY2\REF_D_1k_48h_x2_FW_2.03.dat -10.1821277
# REF_D_1k
# C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0\V1145_A_5k_FW_2.03.dat -10.3472289
# V1145_A_5k
# C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY1\V1145_A_4k_24h_FW_2.03.dat -10.0113906
# V1145_A_4k
# C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY2\V1145_A_4k_48h_FW_2.05.dat -9.414509
# V1145_A_4k

# %%
df.columns
# Out:
# Index(['U[V] ', ' I[A] ', ' j[mA/cm^2] ', ' P[mW/cm^2]'], dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1,2,figsize=(15,8))
axes[0].set_title(f'REF')
sns.lineplot(data=df[df['U[V] '] >= 0],x = 'U[V] ', y='j', ax=axes[0], hue='Type')
axes[1].set_title(f'V1145')
sns.lineplot(data=df1[df1['U[V] '] >= 0],x = 'U[V] ', y='j', ax=axes[1], hue='Type')
plt.show()

# %%
# Failo pavadinime yra specifinis kodas (D_5k, D_2k, B_1k, ir taip toliau). Pagal ansktesnį pavyzdį
# matyti, jog taip paprastai atrenkant - tas trumpinys pakinta
# pakeiskite skriptą taip, kad
# jei jūsų skriptas rado, kad pavyzdžiui, DAY0 geriausias REF yra su kodu D_5k, tai
# DAY1 ir DAY2 turi būti vaizduojami duomenys iš failų su tuo pat kodu (D_5k pavyzdžiui)
def get_file_by_min_val(location, column):
    import pandas as pd
    import glob
    dat_failai = glob.glob(location)
    files = []
    min_p = []
    for file in dat_failai:
        df = pd.read_csv(file, delimiter=';')
        min_p.append(min(list(df[column])))
        files.append(file)
        
    for file, val in zip(files,min_p):
        if val == min(min_p):
            print(file, val)
            f = file.split('/')[-1]
            s = '_'.join(f.split('\\')[1].split('_')[:3])
            print(s)
            return [file, round(val*-1,2), f, s]

# %%
import pandas as pd
# REF
file_day0 = get_file_by_min_val('C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0/REF*.dat',' P[mW/cm^2]')
file_day1 = get_file_by_min_val(f'C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY1/{file_day0[3]}*.dat',' P[mW/cm^2]')
file_day2 = get_file_by_min_val(f'C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY2/{file_day0[3]}*.dat',' P[mW/cm^2]')
df_day0 = pd.read_csv(file_day0[0], delimiter=';')
df_day1 = pd.read_csv(file_day1[0], delimiter=';')
df_day2 = pd.read_csv(file_day2[0], delimiter=';')
df_day0['j']= df_day0[' j[mA/cm^2] '].apply(lambda x: x*-1)
df_day0['Type']= df_day0[' j[mA/cm^2] '].apply(lambda x: f"DAY0 {file_day0[2]} {file_day0[1]}%")
df_day1['j']= df_day1[' j[mA/cm^2] '].apply(lambda x: x*-1)
df_day1['Type']= df_day1[' j[mA/cm^2] '].apply(lambda x: f"DAY1 {file_day1[2]} {file_day1[1]}%")
df_day2['j']= df_day2[' j[mA/cm^2] '].apply(lambda x: x*-1)
df_day2['Type']= df_day2[' j[mA/cm^2] '].apply(lambda x: f"DAY2 {file_day2[2]} {file_day2[1]}%")
df = pd.concat([df_day0,df_day1,df_day2])
# V1145
file1_day0 = get_file_by_min_val('C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0/V1145*.dat',' P[mW/cm^2]')
file1_day1 = get_file_by_min_val(f'C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY1/{file1_day0[3]}*.dat',' P[mW/cm^2]')
file1_day2 = get_file_by_min_val(f'C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY2/{file1_day0[3]}*.dat',' P[mW/cm^2]')
df1_day0 = pd.read_csv(file1_day0[0], delimiter=';')
df1_day1 = pd.read_csv(file1_day1[0], delimiter=';')
df1_day2 = pd.read_csv(file1_day2[0], delimiter=';')
df1_day0['j']= df1_day0[' j[mA/cm^2] '].apply(lambda x: x*-1)
df1_day0['Type']= df1_day0[' j[mA/cm^2] '].apply(lambda x: f"DAY0 {file1_day0[2]} {file1_day0[1]}%")
df1_day1['j']= df1_day1[' j[mA/cm^2] '].apply(lambda x: x*-1)
df1_day1['Type']= df1_day1[' j[mA/cm^2] '].apply(lambda x: f"DAY1 {file1_day1[2]} {file1_day1[1]}%")
df1_day2['j']= df1_day2[' j[mA/cm^2] '].apply(lambda x: x*-1)
df1_day2['Type']= df1_day2[' j[mA/cm^2] '].apply(lambda x: f"DAY2 {file1_day2[2]} {file1_day2[1]}%")
df1 = pd.concat([df1_day0,df1_day1,df1_day2])
# Out:
# C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0\REF_D_1k_FW_2.08.dat -14.9890787
# REF_D_1k
# C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY1\REF_D_1k_24h_FW_2.03.dat -9.7706286
# REF_D_1k
# C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY2\REF_D_1k_48h_x2_FW_2.03.dat -10.1821277
# REF_D_1k
# C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY0\V1145_A_5k_FW_2.03.dat -10.3472289
# V1145_A_5k
# C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY1\V1145_A_5k_24h_FW_2.03.dat -9.4560646
# V1145_A_5k
# C:/Users/manta/OneDrive/Dokumentai/Python projektai/DATA/DAY2\V1145_A_5k_48h_FW_2.05.dat -8.6531179
# V1145_A_5k

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1,2,figsize=(15,8))
axes[0].set_title(f'REF')
sns.lineplot(data=df[df['U[V] '] >= 0],x = 'U[V] ', y='j', ax=axes[0], hue='Type')
axes[1].set_title(f'V1145')
sns.lineplot(data=df1[df1['U[V] '] >= 0],x = 'U[V] ', y='j', ax=axes[1], hue='Type')
plt.show()

# %%
import numpy as np
# https://infogram.com/darbo-uzmokestis-savivaldybese-2023-m-antraji-ketvirti-1h7z2l835wndx6o 
df = pd.read_csv('C:/Users/manta/OneDrive/Dokumentai/Python projektai/atlyginimai.csv', delimiter=',')

# %%
df.head()
# Out:
#                sort Bruto, EUR Pokytis proc. per metus Neto, EUR  \
# 0       Šalies ūkis    2 000,1                    12,3   1 241,2
# 1   Akmenės r. sav.    1 758,8                      14   1 111,9
# 2   Alytaus m. sav.    1 685,4                    10,5   1 073,7
# 3   Alytaus r. sav.    1 528,5                     8,6     991,9
# 4  Anykščių r. sav.    1 537,7                    11,5     996,7
#
#   Pokytis proc. per metus.1
# 0                      11,2
# 1                      12,7
# 2                       9,9
# 3                       8,6
# 4                      10,9

# %%
df_new = df

# %%
df_new.columns
# Out:
# Index(['sort', 'Bruto, EUR', 'Pokytis proc. per metus', 'Neto, EUR',
#        'Pokytis proc. per metus.1'],
#       dtype='object')

# %%
def vard_from_kilm(x):
    if x == 'Alytaus':
        return 'Alytus'
    elif x == 'Kauno':
        return 'Kaunas'
    elif x == 'Klaipėdos':
        return 'Klaipėda'
    elif x == 'Palanga':
        return 'Palanga'
    elif x == 'Panevėžio':
        return 'Panevėžys'
    elif x == 'Šiaulių':
        return 'Šiauliai'
    elif x == 'Vilniaus':
        return 'Vilnius'
    else:
        return None

# %%
df_new['Miestas'] = df_new['sort'].apply(lambda x: x.split()[0] if x.split()[1] == 'm.' else "None")
df_miestai = df_new[df_new['Miestas'] != 'None']
df_miestai['Miestas'] = df_miestai['Miestas'].apply(vard_from_kilm)
# Out:
# C:\Users\manta\AppData\Local\Temp\ipykernel_5828\362518377.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_miestai['Miestas'] = df_miestai['Miestas'].apply(vard_from_kilm)

# %%
df_miestai.head(10)
# Out:
#                  sort Bruto, EUR Pokytis proc. per metus Neto, EUR  \
# 2     Alytaus m. sav.    1 685,4                    10,5   1 073,7
# 15      Kauno m. sav.    2 046,2                      11   1 267,4
# 20  Klaipėdos m. sav.    2 002,5                    13,1   1 242,5
# 31   Palangos m. sav.    1 559,6                    15,5   1 008,1
# 32  Panevėžio m. sav.    1 800,7                    12,9   1 133,7
# 44    Šiaulių m. sav.    1 753,3                    10,9   1 109,0
# 57   Vilniaus m. sav.    2 290,7                    12,2   1 406,5
#
#    Pokytis proc. per metus.1    Miestas
# 2                        9,9     Alytus
# 15                      10,1     Kaunas
# 20                      11,9   Klaipėda
# 31                      14,2       None
# 32                      11,8  Panevėžys
# 44                      10,2   Šiauliai
# 57                      11,2    Vilnius

# %%
from Skriptai.manofunkcijos import *

# %%
db_path = '../../../web_scrap.db'
query = 'SELECT * FROM autopliuslt2;'  # SQL užklausa, kurią norite vykdyti
df_auto = query_to_dataframe(db_path,query)
df_auto['Miestas'] = df_auto['Miestas'].apply(lambda x: x.split(',')[0] if x != None else x)

# %%
df_auto.head()
# Out:
#    id   Markė     Modelis  Kaina    Miestas Pirma registracija Kuro tipas  \
# 0   1  -Kita-      -kita-   1750      Utena            2008-09  Dyzelinas
# 1   2  -Kita-      -kita-   3900  Jurbarkas               2011    Elektra
# 2   3  -Kita-      -kita-   6800  Kėdainiai            2020-02    Elektra
# 3   4  -Kita-      -kita-  60500    Vilnius               2024    Elektra
# 4   5  Abarth  124 Spider  18900     Kaunas               2017   Benzinas
#
#                 Kėbulo tipas Durų skaičius Pavarų dėžė  ... CO₂ emisija, g/km  \
# 0  Krovininis mikroautobusas          Kita   Mechaninė  ...              None
# 1                    Sedanas           2/3        None  ...              None
# 2                   Hečbekas           2/3        None  ...              None
# 3  Krovininis mikroautobusas           4/5        None  ...              None
# 4                Kabrioletas           2/3   Mechaninė  ...          148 g/km
#
#   Mieste Užmiestyje Vidutinės Defektai Pagaminimo data Vairo padėtis  \
# 0   None       None      None     None            None          None
# 1   None       None      None     None            None          None
# 2   None       None      None     None            None          None
# 3   None       None      None     None            None          None
# 4    8,5        5,1       6,4     None            None          None
#
#   Registracijos data Ilgis Aukštis
# 0               None  None    None
# 1               None  None    None
# 2               None  None    None
# 3               None  None    None
# 4               None  None    None
#
# [5 rows x 40 columns]

# %%
df_auto = pd.merge(df_auto, df_miestai, how='left', on='Miestas')

# %%
df_auto['Kaina'] = df_auto['Kaina'].apply(lambda x: float(x) if x != None else x)
df_auto['Neto, EUR'] = df_auto['Neto, EUR'].apply(lambda x: str(x).replace('1\xa0406.5','') if x != None else x)
df_auto['Neto, EUR'] = df_auto['Neto, EUR'].apply(lambda x: x.replace(',','.') if x != None else x)
# '1\xa0406.5'
# df_auto['Neto, EUR'] = df_auto['Neto, EUR'].apply(lambda x: x.replace('1\xa0406.5','') if x != None else x)
# df_auto['Neto, EUR'] = df_auto['Neto, EUR'].apply(lambda x: float(x) if x != None else x)

# %%
df
fig, axes = plt.subplots(1,2,figsize=(15,8))
axes[0].set_title(f'REF')
sns.lineplot(data=df[df['U[V] '] >= 0],x = 'U[V] ', y='j', ax=axes[0], hue='Type')
axes[1].set_title(f'V1145')
sns.lineplot(data=df1[df1['U[V] '] >= 0],x = 'U[V] ', y='j', ax=axes[1], hue='Type')
plt.show()
