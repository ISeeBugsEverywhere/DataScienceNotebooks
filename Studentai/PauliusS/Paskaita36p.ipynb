# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import sqlite3
import mysql.connector as cnt
import plotly.express as px

# %%
imu = pd.read_csv('../../DATA/imunizacija.csv')
imu.head(2)
# Out:
#    ESRI_OID  workplace_code                     workplace_name  \
# 0         1       110004884  Uždaroji akcinė bendrovė "VILLON"
# 1         2       110005648       UAB "Informacinės paslaugos"
#
#    activity_evrk2      municipality           county  employees  \
# 0        551000.0  Vilniaus r. sav.  Vilniaus apskr.        170
# 1        620100.0  Vilniaus m. sav.  Vilniaus apskr.         25
#
#   immunised_percent  percentile_1  percentile_2  as_of_date
# 0           90-100%            92          94.0  2022-03-20
# 1           90-100%            69          71.0  2022-03-20

# %%
imu.dropna(subset=['activity_evrk2', 'workplace_name'], how = 'all').tail(5)   #tikrina visus stulpelius, jei bent viename randa Na, istrina visa eilute
# Out:
#        ESRI_OID  workplace_code workplace_name  activity_evrk2  \
# 19819     19820       305972116            NaN        161000.0
# 19820     19821       305973296            NaN        464200.0
# 19821     19822       305981108            NaN        475200.0
# 19822     19823       305987794            NaN        711220.0
# 19823     19824       305997621            NaN        422200.0
#
#             municipality            county  employees immunised_percent  \
# 19819      Kauno r. sav.      Kauno apskr.         80           90-100%
# 19820  Klaipėdos r. sav.  Klaipėdos apskr.         10           90-100%
# 19821   Vilniaus r. sav.   Vilniaus apskr.         10            80-89%
# 19822  Klaipėdos m. sav.  Klaipėdos apskr.         15           90-100%
# 19823      Kauno m. sav.      Kauno apskr.         15            70-79%
#
#        percentile_1  percentile_2  as_of_date
# 19819            58          60.0  2022-03-20
# 19820           100         100.0  2022-03-20
# ...

# %%
imu = pd.read_csv('../../DATA/imunizacija.csv')
imu.head(2)
# Out:
#    ESRI_OID  workplace_code                     workplace_name  \
# 0         1       110004884  Uždaroji akcinė bendrovė "VILLON"
# 1         2       110005648       UAB "Informacinės paslaugos"
#
#    activity_evrk2      municipality           county  employees  \
# 0        551000.0  Vilniaus r. sav.  Vilniaus apskr.        170
# 1        620100.0  Vilniaus m. sav.  Vilniaus apskr.         25
#
#   immunised_percent  percentile_1  percentile_2  as_of_date
# 0           90-100%            92          94.0  2022-03-20
# 1           90-100%            69          71.0  2022-03-20

# %%
imu.fillna(-1)   #visur uzpildo -1 kur buvo NaN
# Out:
#        ESRI_OID  workplace_code                     workplace_name  \
# 0             1       110004884  Uždaroji akcinė bendrovė "VILLON"
# 1             2       110005648       UAB "Informacinės paslaugos"
# 2             3       110011925               UAB "Eltel Networks"
# 3             4       110012112                            UAB IDW
# 4             5       110012450                        AB "Grigeo"
# ...         ...             ...                                ...
# 19823     19824       305997621                                 -1
# 19824     19825       306019829                                 -1
# 19825     19826       306025216                                 -1
# 19826     19827       306027128                                 -1
# 19827     19828       306027224                                 -1
#
#        activity_evrk2       municipality            county  employees  \
# 0            551000.0   Vilniaus r. sav.   Vilniaus apskr.        170
# ...

# %%
imu['workplace_name'] = imu['workplace_name'].fillna('nenurodyta')
imu.tail(10)     #pvz kai keiciame viename stulpelyje
# Out:
#        ESRI_OID  workplace_code workplace_name  activity_evrk2  \
# 19818     19819       305971701     nenurodyta        412000.0
# 19819     19820       305972116     nenurodyta        161000.0
# 19820     19821       305973296     nenurodyta        464200.0
# 19821     19822       305981108     nenurodyta        475200.0
# 19822     19823       305987794     nenurodyta        711220.0
# 19823     19824       305997621     nenurodyta        422200.0
# 19824     19825       306019829     nenurodyta             NaN
# 19825     19826       306025216     nenurodyta             NaN
# 19826     19827       306027128     nenurodyta             NaN
# 19827     19828       306027224     nenurodyta             NaN
#
#               municipality            county  employees immunised_percent  \
# 19818  Radviliškio r. sav.    Šiaulių apskr.         15            60-69%
# 19819        Kauno r. sav.      Kauno apskr.         80           90-100%
# ...

# %%
imu.loc[[1,3,4,5],['workplace_code', 'workplace_name', 'municipality','county']] 
# issikerpame konkrecia eilute ir konkrecius stulpelius
# Out:
#    workplace_code                   workplace_name      municipality  \
# 1       110005648     UAB "Informacinės paslaugos"  Vilniaus m. sav.
# 3       110012112                          UAB IDW  Vilniaus m. sav.
# 4       110012450                      AB "Grigeo"  Vilniaus m. sav.
# 5       110015560  Uždaroji akcinė bendrovė "INTA"  Vilniaus m. sav.
#
#             county
# 1  Vilniaus apskr.
# 3  Vilniaus apskr.
# 4  Vilniaus apskr.
# 5  Vilniaus apskr.

# %%
imu.loc[1,'workplace_name']   #pasiekiame konkretu irasa 
imu.loc[1,'workplace_name'] = "UAB Trys blynai"  #pakeiciame konkretu irasa
imu.head()
# Out:
#    ESRI_OID  workplace_code                     workplace_name  \
# 0         1       110004884  Uždaroji akcinė bendrovė "VILLON"
# 1         2       110005648                    UAB Trys blynai
# 2         3       110011925               UAB "Eltel Networks"
# 3         4       110012112                            UAB IDW
# 4         5       110012450                        AB "Grigeo"
#
#    activity_evrk2      municipality           county  employees  \
# 0        551000.0  Vilniaus r. sav.  Vilniaus apskr.        170
# 1        620100.0  Vilniaus m. sav.  Vilniaus apskr.         25
# 2        422200.0  Vilniaus m. sav.  Vilniaus apskr.        230
# 3        329900.0  Vilniaus m. sav.  Vilniaus apskr.        175
# 4        172200.0  Vilniaus m. sav.  Vilniaus apskr.        270
#
#   immunised_percent  percentile_1  percentile_2  as_of_date
# 0           90-100%            92          94.0  2022-03-20
# 1           90-100%            69          71.0  2022-03-20
# ...

# %%
imu.iloc[[*range(10,21,2)],[1,2,3,4,5]]  #issitraukiame skaiciu sarasus per indeksus
# Out:
#     workplace_code                                     workplace_name  \
# 10       110032524                 Uždaroji akcinė bendrovė "SEIFUVA"
# 12       110051115  Bendra Lietuvos-Rusijos-Olandijos įmonė uždaro...
# 14       110051834               Akcinė bendrovė "Lietuvos draudimas"
# 16       110053842           Akcinė bendrovė "Lietuvos geležinkeliai"
# 18       110057335  Viešoji įstaiga Lietuvos žemės ūkio konsultavi...
# 20       110058241                Lietuvos pramonininkų konfederacija
#
#     activity_evrk2      municipality           county
# 10        259900.0    Utenos r. sav.    Utenos apskr.
# 12        581100.0  Vilniaus m. sav.  Vilniaus apskr.
# 14        651200.0  Vilniaus m. sav.  Vilniaus apskr.
# 16        492000.0  Vilniaus m. sav.  Vilniaus apskr.
# 18        749000.0  Kėdainių r. sav.     Kauno apskr.
# 20        941100.0  Vilniaus m. sav.  Vilniaus apskr.

# %%
df = imu.iloc[[*range(10,21,2)],[1,2,3,4,5]]

# %%
df.drop(columns=['municipality'], inplace=True)    #inplece=True padaro pati pakeitima (drop tik printina)
                                                    #panaikiname stulpeli

# %%
df.drop(16, axis=0)   #panaikina eilute
# Out:
#     workplace_code                                     workplace_name  \
# 10       110032524                 Uždaroji akcinė bendrovė "SEIFUVA"
# 12       110051115  Bendra Lietuvos-Rusijos-Olandijos įmonė uždaro...
# 14       110051834               Akcinė bendrovė "Lietuvos draudimas"
# 18       110057335  Viešoji įstaiga Lietuvos žemės ūkio konsultavi...
# 20       110058241                Lietuvos pramonininkų konfederacija
#
#     activity_evrk2           county
# 10        259900.0    Utenos apskr.
# 12        581100.0  Vilniaus apskr.
# 14        651200.0  Vilniaus apskr.
# 18        749000.0     Kauno apskr.
# 20        941100.0  Vilniaus apskr.

# %%
df.drop('county', axis=1)  #panaikiname stulpeli
# Out:
#     workplace_code                                     workplace_name  \
# 10       110032524                 Uždaroji akcinė bendrovė "SEIFUVA"
# 12       110051115  Bendra Lietuvos-Rusijos-Olandijos įmonė uždaro...
# 14       110051834               Akcinė bendrovė "Lietuvos draudimas"
# 16       110053842           Akcinė bendrovė "Lietuvos geležinkeliai"
# 18       110057335  Viešoji įstaiga Lietuvos žemės ūkio konsultavi...
# 20       110058241                Lietuvos pramonininkų konfederacija
#
#     activity_evrk2
# 10        259900.0
# 12        581100.0
# 14        651200.0
# 16        492000.0
# 18        749000.0
# 20        941100.0
