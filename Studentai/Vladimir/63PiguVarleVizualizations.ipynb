# %%
from regex import P

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import sqlite3
import mysql.connector as cnt
import plotly.express as px
import psycopg2
import requests
import pandas as pd
import plotly.express as px
from datetime import datetime, timedelta

from bs4 import BeautifulSoup as BS

# %%
import sqlite3

# %%
ptI = pd.read_csv('piguTabletsI.csv')

# %%
ptI
# Out:
#         id    price    brand  \
# 0        1   156.90  Samsung
# 1        2   136.94   Xiaomi
# 2        3   152.37   Xiaomi
# 3        4   136.94   Xiaomi
# 4        5   221.14   Xiaomi
# ...    ...      ...      ...
# 1127  1128   435.80  Samsung
# 1128  1129    -1.00   Lenovo
# 1129  1130   699.00    Apple
# 1130  1131  2472.08    Apple
# 1131  1132  2472.08    Apple
#
#                                                  brandI         3G:   4G:  \
# 0     Samsung Galaxy Tab A9+ WiFi 4/64GB Graphite SM...          Ne    Ne
# 1             Xiaomi Redmi Pad SE 4/128GB Graphite Gray          Ne    Ne
# 2                  Xiaomi Redmi Pad SE 11" 8/256GB grey        Taip    Ne
# 3                           Xiaomi Redmi Pad SE 4/128GB          Ne    Ne
# 4     Xiaomi Redmi Pad Pro 12.1 6GB/128GB Graphite Gray          Ne    Ne
# ...                                                 ...         ...   ...
# 1127  Samsung Galaxy Tab S6 Lite Wi-Fi LTE 4G 4/128 ...  Nenurodyta  Taip
# ...

# %%
top_5e = ptI.nlargest(5, 'price')

ptI['price'] = pd.to_numeric(ptI['price'], errors='coerce').replace(-1, np.nan)
ptI['price'] = ptI['price'].astype(float) 
top_5c = ptI[ptI['price'].notna()].nsmallest(5, 'price')
middle_5 = ptI.iloc[len(ptI)//2 - 2:len(ptI)//2 + 3]

# ptI = ptI.dropna(subset=['brand'], inplace=True)

# %%
# ptI.dropna(subset=['brand'], inplace=True)
ptI = ptI.dropna(subset=['brand'], axis=0)

# %%
pd.set_option('display.max_columns', None)
print(ptI)
# Out:
#         id    price    brand  \
# 0        1   156.90  Samsung
# 1        2   136.94   Xiaomi
# 2        3   152.37   Xiaomi
# 3        4   136.94   Xiaomi
# 4        5   221.14   Xiaomi
# ...    ...      ...      ...
# 1127  1128   435.80  Samsung
# 1128  1129    -1.00   Lenovo
# 1129  1130   699.00    Apple
# 1130  1131  2472.08    Apple
# 1131  1132  2472.08    Apple
#
#                                                  brandI         3G:   4G:  \
# 0     Samsung Galaxy Tab A9+ WiFi 4/64GB Graphite SM...          Ne    Ne
# 1             Xiaomi Redmi Pad SE 4/128GB Graphite Gray          Ne    Ne
# 2                  Xiaomi Redmi Pad SE 11" 8/256GB grey        Taip    Ne
# 3                           Xiaomi Redmi Pad SE 4/128GB          Ne    Ne
# 4     Xiaomi Redmi Pad Pro 12.1 6GB/128GB Graphite Gray          Ne    Ne
# ...                                                 ...         ...   ...
# 1127  Samsung Galaxy Tab S6 Lite Wi-Fi LTE 4G 4/128 ...  Nenurodyta  Taip
# ...

# %%
import streamlit as st

st.title("Price Analysis of Tablets")


st.subheader("Top 5 Most Expensive Tablets")
fig, ax = plt.subplots()
top_5e.plot(x='brand', y='price', kind='bar', ax=ax, color='red', legend=False)
ax.set_ylabel('Price (€)')
ax.set_title('Top 5 Most Expensive Tablets')
st.pyplot(fig)


st.subheader("Top 5 Cheapest Tablets")
fig, ax = plt.subplots()
top_5c.plot(x='brand', y='price', kind='bar', ax=ax, color='green', legend=False)
ax.set_ylabel('Price (€)')
ax.set_title('Top 5 Cheapest Tablets')
st.pyplot(fig)


st.subheader("Middle 5 Tablets")
fig, ax = plt.subplots()
middle_5.plot(x='brand', y='price', kind='bar', ax=ax, color='blue', legend=False)
ax.set_ylabel('Price (€)')
ax.set_title('Middle 5 Tablets')
st.pyplot(fig)

# %%
DB = sqlite3.connect(r"C:\Users\Batia\Desktop\DataScienceNotebooks\Studentai\Vladimir\varleDrons.db")
C = DB.cursor()
#sql užklausa per pandas sql_query
sql="""select * from Specifications_varleD"""
dfv = pd.read_sql_query(sql, con=DB)
omg1 = dfv.groupby('product_id').nth(slice(0,60)).pivot(index='product_id', columns='spec_key', values='spec_value')
print(omg1)
# Out:
# spec_key     4G Akinių modelis Akinių pavadinimas Akumuliatoriaus modelis  \
# product_id
# 1           NaN            NaN                NaN                 LiPo 2S
# 2           NaN            NaN                NaN                     NaN
# 3           NaN            NaN                NaN                 LiPo 2S
# 4           NaN            NaN                NaN                     NaN
# 5           NaN            NaN                NaN                     NaN
# ...         ...            ...                ...                     ...
# 105         NaN            NaN                NaN                     NaN
# 106         NaN            NaN                NaN                     NaN
# 107         NaN            NaN                NaN                     NaN
# 108         NaN            NaN                NaN                     NaN
# 109         NaN            NaN                NaN                     NaN
#
# ...

# %%
unique_spec_keys = dfv['spec_key'].unique()
print(unique_spec_keys[:1000])
# Out:
# ['Gamintojas' 'Modelis' 'Stabilizavimas' 'Spalva' 'Energija'
#  'Kiti formatai' 'Maksimalus kilimo greitis' 'Įtampa'
#  'Maksimalus kampinis greitis' 'Veikimo dažnis'
#  'Didžiausias mobiliojo prietaiso plotis' 'Didžiausias skrydžio aukštis'
#  'Talpa' 'Svoris' 'Didžiausias skrydžio laikas' 'Vaizdo raiška'
#  'Maksimalus reguliuojamas greitis' 'Sklandymas viduje'
#  'Židinio nuotolis (35 mm fotoaparato ekvivalentas)' 'Išvesties įtampa'
#  'Kampinis vibracijos diapazonas' 'Mechaninis diapazonas'
#  'Maksimalus nusileidimo greitis' 'Jutiklio dydis' 'Mobilioji programėlė'
#  'Užvedimo tikslumas (gps režimas)' 'Tinkamos operacinės sitemos'
#  'Didžiausio vaizdo dydis' 'Didžiausia įkrovimo galia'
#  'Valdomas diapazonas' 'Maksimalus greitis' 'Atminties kortelės tipas'
#  'Išvesties galia' 'Filmų formatas' 'Bitų skaičius' 'Įrašymo laikmena'
#  'Matymo laukas' 'Diagonalinis atstumas' 'Didžiausias pakreipimo kampas'
#  'Akumuliatoriaus modelis' 'Įkrovimo temperatūra' 'Maitinimo šaltinis'
# ...

# %%
for i in unique_spec_keys:
    stabiliza

# %%
stabiliza_columns = [col for col in omg1.columns if 'stabiliza' in col.lower()]
omg1['Combined_Stabilization'] = omg1[stabiliza_columns].apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)

# %%
talpa_columns = [col for col in omg1.columns if 'talpa' in col.lower()]
omg1['Combined_Talpa'] = omg1[talpa_columns].apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)

# %%
atstumas_columns = [col for col in omg1.columns if 'atstumas' in col.lower()]
omg1['Combined_Atstumas'] = omg1[atstumas_columns].apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)

# %%
Laikas_columns = [col for col in omg1.columns if 'laikas' in col.lower()]
omg1['Combined_Laikas'] = omg1[Laikas_columns].apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)

# %%
gps_columns = [col for col in omg1.columns if 'gps' in col.lower()]
omg1['Combined_gps'] = omg1[gps_columns].apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)

# %%
svoris_columns = [col for col in omg1.columns if 'svoris' in col.lower()]
omg1['Combined_svoris'] = omg1[svoris_columns].apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)

# %%
print(omg1['Combined_svoris'])
# Out:
# product_id
# 1      86,2 g 246
# 2           249 g
# 3      86,2 g 246
# 4
# 5           249 g
#           ...
# 105          0.02
# 106
# 107           3.7
# 108     247 g 724
# 109
# Name: Combined_svoris, Length: 102, dtype: object

# %%
print(omg1['Vaizdo raiška'])
# Out:
# product_id
# 1          2.7K 2720 × 1530 30p
# 2      [4K UHD] 3840 × 2160 60p
# 3          2.7K 2720 × 1530 30p
# 4                           NaN
# 5      [4K UHD] 3840 × 2160 60p
#                  ...
# 105                         NaN
# 106                         NaN
# 107                         NaN
# 108    [4K UHD] 3840 × 2160 60p
# 109                         NaN
# Name: Vaizdo raiška, Length: 102, dtype: object

# %%
print(omg1['Combined_gps'])
# Out:
# product_id
# 1      Vertikalus: ±10 cm, Horizontalus: ±30 cm
# 2
# 3      Vertikalus: ±10 cm, Horizontalus: ±30 cm
# 4
# 5
#                          ...
# 105
# 106
# 107
# 108
# 109
# Name: Combined_gps, Length: 102, dtype: object

# %%
print(omg1['Combined_Stabilization'])
# Out:
# product_id
# 1      3 ašių (3-axis)
# 2      3 ašių (3-axis)
# 3      3 ašių (3-axis)
# 4
# 5      3 ašių (3-axis)
#             ...
# 105
# 106
# 107
# 108    3 ašių (3-axis)
# 109
# Name: Combined_Stabilization, Length: 102, dtype: object

# %%
print(omg1['Combined_Talpa'])
# Out:
# product_id
# 1      2250 mAh
# 2      2590 mAh
# 3      2250 mAh
# 4
# 5      2453 mAh
#          ...
# 105
# 106
# 107
# 108    4276 mAh
# 109
# Name: Combined_Talpa, Length: 102, dtype: object

# %%
print(omg1['Combined_Atstumas'])
# Out:
# product_id
# 1                      213 mm EB: 6000 m
# 2                           CE: 10 000 m
# 3      213 mm FCC: 10 000 m, CE: 6 000 m
# 4
# 5                             EB: 6000 m
#                      ...
# 105
# 106
# 107
# 108
# 109
# Name: Combined_Atstumas, Length: 102, dtype: object

# %%
print(omg1['Combined_Laikas'])
# Out:
# product_id
# 1       31 minutė
# 2      34 minutes
# 3       31 minutė
# 4
# 5
#           ...
# 105
# 106
# 107
# 108    45 minutes
# 109
# Name: Combined_Laikas, Length: 102, dtype: object

# %%
print(omg1['Vaizdo raiška'])
# Out:
# product_id
# 1          2.7K 2720 × 1530 30p
# 2      [4K UHD] 3840 × 2160 60p
# 3          2.7K 2720 × 1530 30p
# 4                           NaN
# 5      [4K UHD] 3840 × 2160 60p
#                  ...
# 105                         NaN
# 106                         NaN
# 107                         NaN
# 108    [4K UHD] 3840 × 2160 60p
# 109                         NaN
# Name: Vaizdo raiška, Length: 102, dtype: object

# %%
DB = sqlite3.connect(r"C:\Users\Batia\Desktop\DataScienceNotebooks\Studentai\Vladimir\varleDrons.db")
C = DB.cursor()
#sql užklausa per pandas sql_query
sql="""select * from Products_varleD"""
dfvp = pd.read_sql_query(sql, con=DB)
# omg1 = dfv.groupby('product_id').nth(slice(0,60)).pivot(index='product_id', columns='spec_key', values='spec_value')
print(dfvp)
# Out:
#       id    brand  price
# 0      1      DJI    28€
# 1      2      DJI    96€
# 2      3      DJI   329€
# 3      4      DJI   142€
# 4      5      DJI    63€
# ..   ...      ...    ...
# 104  105   Parrot     8€
# 105  106      DJI   404€
# 106  107  Chasing   None
# 107  108      DJI  1340€
# 108  109      DJI   None
#
# [109 rows x 3 columns]

# %%
selected_columns = [ 'Vaizdo raiška', 'Combined_Laikas', 'Combined_Atstumas', 'Combined_Talpa', 'Combined_Stabilization', 'Combined_gps', 'Combined_svoris']

# Merge the tables
merged_table = dfvp.merge(omg1[selected_columns], left_on='id', right_index=True, how='inner')

# Display the result
print(merged_table)
# Out:
#       id    brand  price             Vaizdo raiška Combined_Laikas  \
# 0      1      DJI    28€      2.7K 2720 × 1530 30p       31 minutė
# 1      2      DJI    96€  [4K UHD] 3840 × 2160 60p      34 minutes
# 2      3      DJI   329€      2.7K 2720 × 1530 30p       31 minutė
# 3      4      DJI   142€                       NaN
# 4      5      DJI    63€  [4K UHD] 3840 × 2160 60p
# ..   ...      ...    ...                       ...             ...
# 104  105   Parrot     8€                       NaN
# 105  106      DJI   404€                       NaN
# 106  107  Chasing   None                       NaN
# 107  108      DJI  1340€  [4K UHD] 3840 × 2160 60p      45 minutes
# 108  109      DJI   None                       NaN
#
#                      Combined_Atstumas Combined_Talpa Combined_Stabilization  \
# 0                    213 mm EB: 6000 m       2250 mAh        3 ašių (3-axis)
# 1                         CE: 10 000 m       2590 mAh        3 ašių (3-axis)
# ...

# %%
merged_table.to_csv('varleDronsTI.csv')

# %%
DB = sqlite3.connect(r"C:\Users\Batia\Desktop\DataScienceNotebooks\Studentai\Vladimir\varleDrons.db")
C = DB.cursor()
#sql užklausa per pandas sql_query
sql="""select * from Specifications_varleT1"""
dfvp1 = pd.read_sql_query(sql, con=DB)
omg2 = dfvp1.groupby('product_id').nth(slice(0,60)).pivot(index='product_id', columns='spec_key', values='spec_value')
print(omg2)
# Out:
# spec_key   "Android enterprise" rekomenduojama "Bluetooth" protokolai  \
# product_id
# 1                                          NaN                    NaN
# 2                                          NaN                    NaN
# 3                                          NaN                    NaN
# 4                                          NaN                    NaN
# 5                                          NaN                    NaN
# ...                                        ...                    ...
# 914                                        NaN                    NaN
# 915                                        NaN                    NaN
# 916                                        NaN                    NaN
# 917                                        NaN                    NaN
# 918                                        NaN                    NaN
#
# spec_key   2G juostos (pirminė SIM)  3 g 3,5 mm garso lizdas   4G  \
# product_id
# ...

# %%
unique_spec_keys = dfvp1['spec_key'].unique()
print(unique_spec_keys[:1000])
# Out:
# ['Gamintojas' 'Ekrano įstrižainė' 'Operacinė sistema'
#  'Vidinė atmintis (GB)' 'Atmintis (RAM) (GB)' 'Ypatybės'
#  'Atminties kortelė' 'Spalva' 'Modelio pavadinimas' 'Modelis'
#  'Procesoriaus modelis' 'Procesoriaus dažnis' 'Ekrano dydis'
#  'Ekrano raiška' 'Gylis' 'Įmontuotas mikrofonas' 'Plotis'
#  'Pridedama klaviatūra' 'Infraraudonųjų spindulių prievadas' 'Aukščio'
#  'Bluetooth' 'SIM kortelės palaikymas' 'Operatyvioji atmintis'
#  'Ekrano tipas' 'Skambinimo parinktis' 'USB' 'GPS navigacija'
#  'Priekinė kamera' 'Pc002 procesorius' 'Korpuso medžiaga'
#  'Akumuliatoriaus talpa' 'HDMI' 'Matmenys' 'Pc006 vaizdo įrašas'
#  'Branduolių skaičius' 'Svorio' 'Disko atmintis' 'Bevielis internetas'
#  'Planšetinio kompiuterio tipas' 'Serija' 'Pirštų atspaudų skaitytuvas'
#  'NFC' 'Ausinių prijungimas' 'Mobiliojo ryšio duomenys'
#  'Operatyvioji RAM atmintis' 'Svoris' 'Integruoti jutikliai'
#  'Papildomi priedai' 'Pagrindinė kamera' 'Vidinės atminties dydis'
# ...

# %%
ekranorai_columns = [col for col in omg2.columns if 'ekrano rai' in col.lower()]
omg2['Combined_ekrano_rai'] = omg2[ekranorai_columns].apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)

# %%
print(omg2['Combined_ekrano_rai'])
# Out:
# product_id
# 1
# 2
# 3      1920 x 1200
# 4
# 5      1200 x 2000
#           ...
# 914
# 915
# 916
# 917
# 918
# Name: Combined_ekrano_rai, Length: 918, dtype: object

# %%
ekranodyd_columns = [col for col in omg2.columns if 'ekrano dyd' in col.lower()]
omg2['Combined_ekrano_dyd'] = omg2[ekranodyd_columns].apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)

# %%
print(omg2['Combined_ekrano_dyd'])
# Out:
# product_id
# 1
# 2
# 3        11"
# 4
# 5      10,4"
#        ...
# 914
# 915
# 916
# 917
# 918
# Name: Combined_ekrano_dyd, Length: 918, dtype: object

# %%
ekranoįs_columns = [col for col in omg2.columns if 'ekrano įs' in col.lower()]
omg2['Combined_ekrano_įs'] = omg2[ekranoįs_columns].apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)

# %%
print(omg2['Combined_ekrano_įs'])
# Out:
# product_id
# 1            11.0
# 2            10.1
# 3      11" - 11,9
# 4             9.0
# 5      10" - 10,9
#           ...
# 914
# 915          11.0
# 916          11.0
# 917          10.2
# 918
# Name: Combined_ekrano_įs, Length: 918, dtype: object

# %%
ekranot_columns = [col for col in omg2.columns if 'ekrano t' in col.lower()]
omg2['Combined_ekrano_t'] = omg2[ekranot_columns].apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)

# %%
print(omg2['Combined_ekrano_t'])
# Out:
# product_id
# 1
# 2
# 3      IPS
# 4
# 5      IPS
#       ...
# 914
# 915
# 916
# 917
# 918
# Name: Combined_ekrano_t, Length: 918, dtype: object

# %%
gps_columns = [col for col in omg2.columns if 'GPS' in col.lower()]
omg2['Combined_gps'] = omg2[gps_columns].apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)

# %%
print(omg2['Combined_gps'])
# Out:
# product_id
# 1
# 2
# 3
# 4
# 5
#       ..
# 914
# 915
# 916
# 917
# 918
# Name: Combined_gps, Length: 918, dtype: object

# %%
vidinė_columns = [col for col in omg2.columns if 'vidinė' in col.lower()]
omg2['Combined_vidinė'] = omg2[vidinė_columns].apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)

# %%
print(omg2['Combined_vidinė'])
# Out:
# product_id
# 1             128
# 2              64
# 3         128 128
# 4              64
# 5      128 128 GB
#           ...
# 914
# 915           128
# 916
# 917            64
# 918
# Name: Combined_vidinė, Length: 918, dtype: object

# %%
svor_columns = [col for col in omg2.columns if 'svor' in col.lower()]
omg2['Combined_svor'] = omg2[svor_columns].apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)

# %%
print(omg2['Combined_svor'])
# Out:
# product_id
# 1
# 2
# 3      0,465 0.82
# 4
# 5       0,460 0.8
#           ...
# 914
# 915
# 916
# 917
# 918         0.281
# Name: Combined_svor, Length: 918, dtype: object

# %%
g4g_columns = [col for col in omg2.columns if '4g' in col.lower()]
omg2['Combined_g4g'] = omg2[g4g_columns].apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)

# %%
print(omg2['Combined_g4g'])
# Out:
# product_id
# 1
# 2
# 3
# 4
# 5
#       ..
# 914
# 915
# 916
# 917
# 918
# Name: Combined_g4g, Length: 918, dtype: object

# %%
DB = sqlite3.connect(r"C:\Users\Batia\Desktop\DataScienceNotebooks\Studentai\Vladimir\varleDrons.db")
C = DB.cursor()
#sql užklausa per pandas sql_query
sql="""select * from Product_TabletsMax"""
dfvp1 = pd.read_sql_query(sql, con=DB)
# omg1 = dfv.groupby('product_id').nth(slice(0,60)).pivot(index='product_id', columns='spec_key', values='spec_value')
print(dfvp1)
# Out:
#       id                                              title   price      brand
# 0      1  Planšetė Lenovo Tab M11 11“ 8GB / 128GB LTE + ...     225     Lenovo
# 1      2  Planšetinis kompiuteris Lenovo Tab M10 (3rd Ge...     129     Lenovo
# 2      3  Planšetinis kompiuteris Lenovo Tab M11, 11", 4...     179     Lenovo
# 3      4  Planšetė Lenovo Tab M11 11“ 8GB / 128GB LTE + ...     225     Lenovo
# 4      5  Planšetinis kompiuteris Lenovo Tab M10 (3rd Ge...     129     Lenovo
# ..   ...                                                ...     ...        ...
# 921  922  Planšetė Nokia Tab T21 4+64GB 4G anglies pilka...  205.99      Nokia
# 922  923  Planšetė Apple Išparduodama. onth warranty]...  939.99      Apple
# 923  924  Planšetė Blackview TAB11 SE 11" 128GB LTE, Mėl...     165  Blackview
# 924  925  Planšetė Apple Išparduodama. onth warranty]...  379.99      Apple
# 925  926  Planšetė Renewda Renewd iPhone 12 mini 64GB (p...  539.99    Renewda
#
# [926 rows x 4 columns]

# %%
selected_columns = [ 'Combined_ekrano_rai', 'Combined_ekrano_dyd', 'Combined_ekrano_įs', 'Combined_ekrano_t', 'Combined_gps', 'Combined_vidinė', 'Combined_svor', 'Combined_g4g']


merged_table1T = dfvp1.merge(omg2[selected_columns], left_on='id', right_index=True, how='inner')


print(merged_table1T)
# Out:
#       id                                              title    price  \
# 0      1  Planšetė Lenovo Tab M11 11“ 8GB / 128GB LTE + ...      225
# 1      2  Planšetinis kompiuteris Lenovo Tab M10 (3rd Ge...      129
# 2      3  Planšetinis kompiuteris Lenovo Tab M11, 11", 4...      179
# 3      4  Planšetė Lenovo Tab M11 11“ 8GB / 128GB LTE + ...      225
# 4      5  Planšetinis kompiuteris Lenovo Tab M10 (3rd Ge...      129
# ..   ...                                                ...      ...
# 913  914  Planšetė Hmd Global HMD T21 LTE 6GB/128GB SYST...   369.99
# 914  915  Samsung Tab S10 Ultra 512 GB 37.1 cm (14.6") 1...  1135.99
# 915  916  Planšetė Lenovo Tab M8 (4th Gen) 3/32GB Arctic...   126.99
# 916  917  Planšetė Zebra MC: WLAN, GUN, 2DER, 58KY, 4/32...  3229.99
# 917  918              Planšetė Umax UMAX VisionBook 10A LTE   119.99
#
#           brand Combined_ekrano_rai Combined_ekrano_dyd Combined_ekrano_įs  \
# ...

# %%
merged_table1T.to_csv('varleTabletsTI.csv')
