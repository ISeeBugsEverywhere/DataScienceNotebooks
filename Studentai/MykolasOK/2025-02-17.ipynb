# %%
# from datetime import datetime as dt
# import os 
# import pandas as pd
# import numpy as np
# import warnings
# warnings.filterwarnings('ignore')

# %%
# :simp

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
# import sqlite3
# import mysql.connector as cnt
# import plotly.express as px

# %%
from sklearn.datasets import make_blobs

X,y = make_blobs(n_samples=500, n_features=2, centers=3, random_state=23)

fig, (ax1, ax2) = plt.subplots(2,gridspec_kw={'height_ratios':[1,1]},figsize=[3,6])

ax1.scatter(X[:,0], X[:,1])
ax1.grid(True)

sns.scatterplot(x=X[:,0], y=X[:,1], hue=labels, ax=ax2)
ax2.grid(True)

fig.tight_layout()
plt.show()

# %%
from sklearn.cluster import KMeans

# kmeans=KMeans(n_clusters=3)
# labels=kmeans.fit_predict(X)

labels3=KMeans(n_clusters=3).fit_predict(X)
labels7=KMeans(n_clusters=7).fit_predict(X)

# %%
fig, (ax1, ax2) = plt.subplots(2,gridspec_kw={'height_ratios':[1,1]},figsize=[3,6])

sns.scatterplot(x=X[:,0], y=X[:,1], hue=labels3, ax=ax1)
ax1.grid(True)

sns.scatterplot(x=X[:,0], y=X[:,1], hue=labels7, ax=ax2)
ax2.grid(True)

fig.tight_layout()
plt.show()

# %%
sse=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)

ax=sns.lineplot(x=[*range(1,11)],y=sse)
# ax.loglog()
y
x = list(range(1,11))
plt.xticks(x)
plt.show()
