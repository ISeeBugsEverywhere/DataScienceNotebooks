# %%
# pip install scikit-learn --break-system-packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# import sqlite3
# import mysql.connector as cnt
# import plotly.express as px

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

from datetime import datetime as dt # MOK
print('69 paskaita. Tema: mašininis mokymas (2).')
print('Pasiruošta',dt.now().replace(microsecond=0))
# Out:
# 69 paskaita. Tema: mašininis mokymas (2).
# Pasiruošta 2024-12-18 18:23:40

# %%
import os
path = os.getcwd()
print(path)
print('/home/administratorius/git/python_kursai/gautiDuomenys/insurance.csv')
# Out:
# /home/administratorius/git/python_kursai/DataScienceNotebooks/Studentai/MykolasOK
# /home/administratorius/git/python_kursai/gautiDuomenys/insurance.csv

# %%
ins=pd.read_csv('../../../gautiDuomenys/insurance.csv')
# ins.info()

# %%
# a) Parašyti kainos prognozės skriptą, kuris prognozuotų būsto kainą. 
# Naudoti Liearregression
# kategorines vertes užkoduoti su LabelEncoder'iu

# %%
# b) iš autoplius duomenų, pasirinkti 7-8 parametrus ir parašyti skriptą 
# automobilio vertės nustatymui.
# Įvertinkite tikslumaą su score parametru.

# %%
#######################################################################

from my_lib.properties_of import properties_of
from my_lib.my_db_functions import df_to_sqlite

aruodas=properties_of('aruodas',engine='pandas')

# %%
adf=aruodas.export_to_df()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 adf=aruodas.export_to_df()
#
# File ~/git/python_kursai/DataScienceNotebooks/Studentai/MykolasOK/my_lib/properties_of_7.py:94, in properties_of.export_to_df(self, properties)
#      87 """
#      88 Eksportuoja savybes į Pandas DataFrame.
#      89
#      90 :param properties: Savybių sąrašas. Jei `None`, grąžina visas savybes.
#      91 :return: Pandas DataFrame su kiekvienai savybei atskiru stulpeliu.
#      92 """
#      93 if self.engine == "pandas":
# ---> 94     df = self.df_property.pivot(index="id", columns="property_id", values="value").reset_index()
#      95 elif self.engine == "pyspark":
#      96     df = self.df_property.toPandas().pivot(index="id", columns="property_id", values="value").reset_index()
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:9339, in DataFrame.pivot(self, columns, index, values)
#    9332 @Substitution("")
#    9333 @Appender(_shared_docs["pivot"])
#    9334 def pivot(
#    9335     self, *, columns, index=lib.no_default, values=lib.no_default
#    9336 ) -> DataFrame:
#    9337     from pandas.core.reshape.pivot import pivot
# -> 9339     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:553, in pivot(data, columns, index, values)
#     549         index_list = [
#     550             data._constructor_sliced(data.index, name=data.index.name)
#     551         ]
#     552 else:
# --> 553     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     555 data_columns = [data[col] for col in columns_listlike]
#     556 index_list.extend(data_columns)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'id'

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import sqlite3
import mysql.connector as cnt
import plotly.express as px
import random
# from manofunkcijos import *

import requests
from bs4 import BeautifulSoup
import selenium
from selenium import webdriver # naršyklės kontroleris
from selenium.webdriver.chrome.options import Options #Naršyklės
# pip install beautifulsoup4 selenium
import time

# %%
Objekto_tipai = {'Butai pardavimui':'butai', 'Butai nuomai':'butu-nuoma'}
Miestai = {'Kaunas':'kaune', 'Vilnius':'vilniuje', 'Klaipėda':'klaipedoje', 'Šiauliai':'siauliuose', 'Panevėžys':'panevezyje', 'Alytus':'alytuje', 'Palanga':'palangoje'}
for obj in Objekto_tipai.keys():
    print(Objekto_tipai[obj])
    puslapis = 1
    opcijos = Options()
    opcijos.add_argument('--incognito')
    driver = webdriver.Chrome(options=opcijos)
    url = f'https://www.aruodas.lt/{Objekto_tipai[obj]}/puslapis/{puslapis}/?FOwnerDbId0=1&FOwnerDbId2=1'
    driver.get(url)
    time.sleep(3)
    source = driver.page_source
    bs = BeautifulSoup(source, 'html.parser')
    first = bs.find('div', {'class':'markTexts'})
    skelbimai = first.find('div', {'class':'number'})
    puslapiai = int(int(skelbimai.text.strip().replace('(','').replace(')',''))/25)
    for puslapis in range(puslapiai):
        puslapis = puslapis + 1
        url = f'https://www.aruodas.lt/{Objekto_tipai[obj]}/puslapis/{puslapis}/?FOwnerDbId0=1&FOwnerDbId2=1'
        driver.get(url)
        source = driver.page_source
        bs = BeautifulSoup(source, 'html.parser')
        skelbimas = bs.find_all('div', {'class':'list-adress-v2'})
        for s in skelbimas:
            try:
                # if not check_if_value_exists_or_max('../../../web_scrap.db','aruodas','URL',url):
                if True:
                    skelbimai = {}
                    url = s.find('a')['href']
                    print("\n"),os.path.basename(url)
                    item_id = url.split('/')[-2].split('-')[-1]
                    skelbimai['Miestas'] = s.find('a').text.strip()
                    skelbimai['Kaina'] = s.find_all('span', {'class':'list-item-price-v2'})[0].text.strip().replace(' ','')[:-1]
                    driver.get(url)
                    source = driver.page_source
                    bs = BeautifulSoup(source, 'html.parser')
                    pav = bs.find('dl', {'class':'obj-details'}).find_all('dt')
                    values = bs.find('dl', {'class':'obj-details'}).find_all('dd')
                    skelbimai['Adresas'] = bs.find('h1', {'class':'obj-header-text'}).text.strip()
                    for p, v in zip(pav,values):
                        skelbimai[p.text.strip()[:-1]] = v.text.strip()
                    skelbimai['URL'] = url
                    for prop in skelbimai:
                        # print(f"{item_id}, {prop}, {skelbimai[prop]}")
                        aruodas.add_property(item_id,prop,skelbimai[prop])
                    print(skelbimai)
            except Exception as e:
                print(f"Exception: {e}")
    driver.close()
# Out:
# butai
# Exception: 'NoneType' object is not subscriptable
# Exception: 'NoneType' object is not subscriptable
#
#
# {'Miestas': 'Kaunas, Žemieji ŠančiaiA. Juozapavičiaus pr.', 'Kaina': '294780', 'Adresas': 'Kaunas, Žemieji Šančiai, A. Juozapavičiaus pr., 4 kambarių butas', 'Namo numeris': '11', 'Plotas': '98,26 m²', 'Kambarių sk.': '4', 'Aukštas': '5', 'Aukštų sk.': '5', 'Metai': '2023', 'Pastato tipas': 'Monolitinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Dalinė apdaila', 'Pastato energijos suvartojimo klasė': 'A++', 'Ypatybės': 'Aukštos lubos\nNauja kanalizacija\nNauja elektros instaliacija\nInternetas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Sandėliukas\nBalkonas\nVieta automobiliui\nDrabužinė', 'Papildoma įranga': 'Kondicionierius\nRekuperacinė sistema', 'Apsauga': 'Šarvuotos durys\nSignalizacija\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-kaune-sanciuose-a-juozapaviciaus-pr-butas-yra-isskirtiniame-wwwjuozapaviciaus-1-3342907/?search_pos=1'}
#
#
# {'Miestas': 'Kaunas, Žemieji ŠančiaiA. Juozapavičiaus pr.', 'Kaina': '105000', 'Adresas': 'Kaunas, Žemieji Šančiai, A. Juozapavičiaus pr., 1 kambario butas', 'Namo numeris': '11A', 'Plotas': '26,97 m²', 'Kambarių sk.': '1', 'Aukštas': '3', 'Aukštų sk.': '5', 'Metai': '2024', 'Pastato tipas': 'Monolitinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Pastato energijos suvartojimo klasė': 'A++', 'Ypatybės': 'Yra liftas\nAukštos lubos\nNauja kanalizacija\nNauja elektros instaliacija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas', 'Papildoma įranga': 'Kondicionierius\nSu baldais\nŠaldytuvas\nŠildomos grindys\nVirtuvės komplektas\nViryklė\nDušo kabina\nRekuperacinė sistema', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-kaune-sanciuose-a-juozapaviciaus-pr-butas-yra-isskirtiniame-wwwjuozapaviciaus-1-3496385/?search_pos=2'}
#
#
# {'Miestas': 'Vilnius, ViršuliškėsBuivydiškių g.', 'Kaina': '103000', 'Adresas': 'Vilnius, Viršuliškės, Buivydiškių g., 2 kambarių butas', 'Namo numeris': '36', 'Plotas': '34 m²', 'Kambarių sk.': '2', 'Aukštas': '1', 'Aukštų sk.': '5', 'Metai': '2022', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Aukštos lubos\nButas per kelis aukštus\nNauja kanalizacija\nNauja elektros instaliacija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Terasa\nVieta automobiliui\nDrabužinė', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nIndaplovė\nDušo kabina', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-virsuliskese-buivydiskiu-g-parduodamas-kokybiskai-irengtas-kambariu-1-3497917/?search_pos=3'}
#
#
# {'Miestas': 'Vilnius, AntakalnisSmėlio g.', 'Kaina': '116000', 'Adresas': 'Vilnius, Antakalnis, Smėlio g., 2 kambarių butas', 'Namo numeris': '7', 'Plotas': '28,83 m²', 'Kambarių sk.': '2', 'Aukštas': '1', 'Aukštų sk.': '4', 'Metai': '1968', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Pastato energijos suvartojimo klasė': 'C', 'Ypatybės': 'Nauja kanalizacija\nNauja elektros instaliacija\nUždaras kiemas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Sandėliukas\nRūsys\nVieta automobiliui', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nIndaplovė\nDušo kabina', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-antakalnyje-smelio-g-moderniai-ir-kokybiskai-irengtas-kambariu-1-3499545/?search_pos=4'}
#
#
# {'Miestas': 'Palanga, PalangaA. Mickevičiaus g.', 'Kaina': '268000', 'Adresas': 'Palanga, Palanga, A. Mickevičiaus g., 2 kambarių butas', 'Plotas': '35 m²', 'Kambarių sk.': '2', 'Aukštas': '1', 'Aukštų sk.': '3', 'Metai': '2023', 'Pastato tipas': 'Kita', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Pastato energijos suvartojimo klasė': 'B', 'Ypatybės': 'Nauja kanalizacija\nNauja elektros instaliacija\nInternetas', 'Papildomos patalpos': 'Sandėliukas\nTerasa\nVieta automobiliui', 'Papildoma įranga': 'Kondicionierius\nSu baldais\nŠaldytuvas\nŠildomos grindys\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nIndaplovė\nDušo kabina', 'Apsauga': 'Šarvuotos durys\nSignalizacija\nKodinė laiptinės spyna\nVaizdo kameros', 'URL': 'https://www.aruodas.lt/butai-palangoje-palangoje-a-mickeviciaus-g-norime-pristatyti-jums-musu-parduodamus-1-3427260/?search_pos=5'}
#
#
# {'Miestas': 'Vilnius, VilkpėdėLiepsnos g.', 'Kaina': '65000', 'Adresas': 'Vilnius, Vilkpėdė, Liepsnos g., 2 kambarių butas', 'Plotas': '45 m²', 'Kambarių sk.': '2', 'Aukštas': '3', 'Aukštų sk.': '3', 'Metai': '1981 statyba, 2024 renovacija', 'Pastato tipas': 'Blokinis', 'Šildymas': 'Aeroterminis', 'Įrengimas': 'Dalinė apdaila', 'Ypatybės': 'Aukštos lubos\nButas per kelis aukštus', 'Apsauga': 'Šarvuotos durys', 'URL': 'https://www.aruodas.lt/butai-vilniuje-vilkpedeje-liepsnos-g-kvieciame-jus-i-atviru-duru-diena-1-3501287/?search_pos=6'}
#
#
# {'Miestas': 'Klaipėda, CentrasH. Manto g.', 'Kaina': '269000', 'Adresas': 'Klaipėda, Centras, H. Manto g., 4 kambarių butas', 'Namo numeris': '46', 'Buto numeris': '10', 'Plotas': '220 m²', 'Kambarių sk.': '4', 'Aukštas': '4', 'Aukštų sk.': '4', 'Metai': '1928', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Dujinis', 'Įrengimas': 'Įrengtas', 'Pastato energijos suvartojimo klasė': 'B', 'Ypatybės': 'Aukštos lubos\nButas per kelis aukštus\nNauja kanalizacija\nNauja elektros instaliacija\nUždaras kiemas\nInternetas\nKabelinė televizija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Yra palėpė', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nŠildomos grindys\nVirtuvės komplektas\nViryklė\nŽidinys\nPlastikiniai vamzdžiai\nIndaplovė\nVonia', 'Apsauga': 'Šarvuotos durys\nSignalizacija\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-klaipedoje-centre-h-manto-g-parduodamas-kvm-butas-su-kvm-1-3452424/?search_pos=7'}
#
#
# {'Miestas': 'Klaipėda, SenamiestisTiltų g.', 'Kaina': '335000', 'Adresas': 'Klaipėda, Senamiestis, Tiltų g., 3 kambarių butas', 'Namo numeris': '6A', 'Plotas': '95 m²', 'Kambarių sk.': '3', 'Aukštas': '5', 'Aukštų sk.': '5', 'Metai': '1982', 'Pastato tipas': 'Blokinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Dalinė apdaila', 'Papildomos patalpos': 'Sandėliukas\nBalkonas\nTerasa\nDrabužinė', 'Apsauga': 'Šarvuotos durys\nSignalizacija', 'URL': 'https://www.aruodas.lt/butai-klaipedoje-senamiestyje-tiltu-g-isskirtinis-butas-su-terasomis-i-klaipedos-1-3443640/?search_pos=8'}
#
#
# {'Miestas': 'Kaunas, VilijampolėRaudondvario pl.', 'Kaina': '59500', 'Adresas': 'Kaunas, Vilijampolė, Raudondvario pl., 2 kambarių butas', 'Plotas': '35 m²', 'Kambarių sk.': '2', 'Aukštas': '4', 'Aukštų sk.': '6', 'Metai': '2023', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Dalinė apdaila', 'URL': 'https://www.aruodas.lt/butai-kaune-vilijampoleje-raudondvario-pl-palankiomis-salygomis-suteikiame-kredita-1-3414581/?search_pos=9'}
#
#
# {'Miestas': 'Vilnius, KaroliniškėsSausio 13-osios g.', 'Kaina': '188130', 'Adresas': 'Vilnius, Karoliniškės, Sausio 13-osios g., 2 kambarių butas', 'Namo numeris': '31', 'Plotas': '48,18 m²', 'Kambarių sk.': '2', 'Aukštas': '1', 'Aukštų sk.': '5', 'Metai': '2024', 'Pastato tipas': 'Monolitinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Pastato energijos suvartojimo klasė': 'A', 'Ypatybės': 'Nauja kanalizacija\nNauja elektros instaliacija\nUždaras kiemas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Terasa', 'Papildoma įranga': 'Šaldytuvas\nVirtuvės komplektas\nViryklė\nIndaplovė\nDušo kabina\nRekuperacinė sistema', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna\nVaizdo kameros', 'URL': 'https://www.aruodas.lt/butai-vilniuje-karoliniskese-sausio-13-osios-g-parduodamas-erdvus-kokybiskai-irengtas-1-3408549/?search_pos=10'}
#
#
# {'Miestas': 'Palanga, PalangaAido tak.', 'Kaina': '197000', 'Adresas': 'Palanga, Palanga, Aido tak., 3 kambarių butas', 'Namo numeris': '34', 'Plotas': '61 m²', 'Kambarių sk.': '3', 'Aukštas': '2', 'Aukštų sk.': '2', 'Metai': '2022', 'Pastato tipas': 'Kita', 'Šildymas': 'Dujinis', 'Įrengimas': 'Įrengtas', 'Pastato energijos suvartojimo klasė': 'A+', 'Ypatybės': 'Butas per kelis aukštus\nAtskiras įėjimas\nUždaras kiemas\nNauja kanalizacija\nNauja elektros instaliacija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Yra palėpė\nVieta automobiliui\nTerasa', 'Papildoma įranga': 'Šildomos grindys\nPlastikiniai vamzdžiai\nRekuperacinė sistema', 'Apsauga': 'Signalizacija', 'URL': 'https://www.aruodas.lt/butai-palangoje-palangoje-aido-tak-butas-kunigiskiai-kvm-palanga-kunigiskiai-1-3180086/?search_pos=11'}
#
#
# {'Miestas': 'Klaipėda, SmiltynėSmiltynės g.', 'Kaina': '115000', 'Adresas': 'Klaipėda, Smiltynė, Smiltynės g., 1 kambario butas', 'Namo numeris': '17', 'Plotas': '22,28 m²', 'Kambarių sk.': '1', 'Aukštas': '2', 'Aukštų sk.': '3', 'Metai': '1930', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis, aeroterminis', 'Įrengimas': 'Dalinė apdaila', 'Ypatybės': 'Nauja kanalizacija\nNauja elektros instaliacija\nUždaras kiemas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Vieta automobiliui', 'Papildoma įranga': 'Kondicionierius', 'Apsauga': 'Šarvuotos durys', 'URL': 'https://www.aruodas.lt/butai-klaipedoje-smiltyneje-smiltynes-g-rekonstruotame-istoriniame-smiltynes-kurhauzo-1-3503421/?search_pos=12'}
#
#
# {'Miestas': 'Kaunas, VilijampolėVytenio g.', 'Kaina': '95000', 'Adresas': 'Kaunas, Vilijampolė, Vytenio g., 2 kambarių butas', 'Namo numeris': '4', 'Plotas': '43 m²', 'Kambarių sk.': '2', 'Aukštas': '2', 'Aukštų sk.': '5', 'Metai': '1963', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Nauja kanalizacija\nNauja elektros instaliacija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas\nRūsys\nDrabužinė', 'Papildoma įranga': 'Su baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nIndaplovė\nDušo kabina', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-kaune-vilijampoleje-vytenio-g-naujas-objektas-rinkoje-parduodamas-1-3503807/?search_pos=13'}
#
#
# {'Miestas': 'Vilnius, RasosStepono Batoro g.', 'Kaina': '200500', 'Adresas': 'Vilnius, Rasos, Stepono Batoro g., 3 kambarių butas', 'Namo numeris': '34', 'Plotas': '57,22 m²', 'Kambarių sk.': '3', 'Aukštas': '2', 'Aukštų sk.': '3', 'Metai': '2023', 'Pastato tipas': 'Monolitinis', 'Šildymas': 'Geoterminis', 'Įrengimas': 'Dalinė apdaila', 'Pastato energijos suvartojimo klasė': 'A++', 'Ypatybės': 'Nauja kanalizacija\nNauja elektros instaliacija\nUždaras kiemas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas', 'Papildoma įranga': 'Šildomos grindys', 'Apsauga': 'Šarvuotos durys', 'URL': 'https://www.aruodas.lt/butai-vilniuje-rasose-stepono-batoro-g-batoro-tai-unikalus-projektas-skirtas-1-3388941/?search_pos=14'}
#
#
# {'Miestas': 'Vilnius, BaltupiaiDidlaukio g.', 'Kaina': '145000', 'Adresas': 'Vilnius, Baltupiai, Didlaukio g., 3 kambarių butas', 'Plotas': '48 m²', 'Kambarių sk.': '3', 'Aukštas': '1', 'Aukštų sk.': '5', 'Metai': '1978', 'Pastato tipas': 'Blokinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Nauja kanalizacija\nNauja elektros instaliacija\nInternetas\nKabelinė televizija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Sandėliukas\nBalkonas\nRūsys', 'Papildoma įranga': 'Su baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nIndaplovė\nVonia', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-baltupiuose-didlaukio-g-parduodamas-kambariu-butas-atliktas-buto-1-3488457/?search_pos=15'}
#
#
# {'Miestas': 'Vilnius, ŠeškinėUkmergės g.', 'Kaina': '141500', 'Adresas': 'Vilnius, Šeškinė, Ukmergės g., 3 kambarių butas', 'Namo numeris': '196', 'Unikalus daikto numeris (RC numeris)': '1097-9010-4011:0068', 'Plotas': '54,5 m²', 'Kambarių sk.': '3', 'Aukštas': '5', 'Aukštų sk.': '9', 'Metai': '1979', 'Pastato tipas': 'Blokinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Yra liftas', 'URL': 'https://www.aruodas.lt/butai-vilniuje-seskineje-ukmerges-g-parduodamas-sviesus-jaukus-naujai-irengtas-1-3504069/?search_pos=16'}
#
#
# {'Miestas': 'Vilnius, RasosStepono Batoro g.', 'Kaina': '228000', 'Adresas': 'Vilnius, Rasos, Stepono Batoro g., 3 kambarių butas', 'Namo numeris': '34', 'Plotas': '67,21 m²', 'Kambarių sk.': '3', 'Aukštas': '2', 'Aukštų sk.': '3', 'Metai': '2024', 'Pastato tipas': 'Monolitinis', 'Šildymas': 'Geoterminis', 'Įrengimas': 'Dalinė apdaila', 'Pastato energijos suvartojimo klasė': 'A++', 'Ypatybės': 'Yra liftas\nAukštos lubos\nNauja kanalizacija\nUždaras kiemas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas\nVieta automobiliui\nDrabužinė', 'Papildoma įranga': 'Šildomos grindys', 'Apsauga': 'Šarvuotos durys\nSignalizacija\nKodinė laiptinės spyna\nVaizdo kameros', 'URL': 'https://www.aruodas.lt/butai-vilniuje-rasose-stepono-batoro-g-batoro-tai-projektas-zmonems-1-3484769/?search_pos=17'}
#
#
# {'Miestas': 'Vilnius, RasosStepono Batoro g.', 'Kaina': '220000', 'Adresas': 'Vilnius, Rasos, Stepono Batoro g., 3 kambarių butas', 'Namo numeris': '34', 'Plotas': '63,09 m²', 'Kambarių sk.': '3', 'Aukštas': '2', 'Aukštų sk.': '3', 'Metai': '2023', 'Pastato tipas': 'Monolitinis', 'Šildymas': 'Geoterminis', 'Įrengimas': 'Dalinė apdaila', 'Pastato energijos suvartojimo klasė': 'A++', 'Ypatybės': 'Atskiras įėjimas\nAukštos lubos\nNauja kanalizacija\nUždaras kiemas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas\nVieta automobiliui', 'Papildoma įranga': 'Šildomos grindys', 'Apsauga': 'Šarvuotos durys\nSignalizacija\nKodinė laiptinės spyna\nVaizdo kameros', 'URL': 'https://www.aruodas.lt/butai-vilniuje-rasose-stepono-batoro-g-batoro-komfortiskam-ir-privatuma-1-3398417/?search_pos=18'}
#
#
# {'Miestas': 'Vilnius, BaltupiaiKazio Ulvydo g.', 'Kaina': '310000', 'Adresas': 'Vilnius, Baltupiai, Kazio Ulvydo g., 3 kambarių butas', 'Plotas': '78,53 m²', 'Kambarių sk.': '3', 'Aukštas': '5', 'Aukštų sk.': '5', 'Metai': '2015', 'Pastato tipas': 'Blokinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Uždaras kiemas', 'Papildomos patalpos': 'Balkonas', 'Papildoma įranga': 'Kondicionierius\nRekuperacinė sistema', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-baltupiuose-kazio-ulvydo-g-parduodamas-erdvus-kambariu-butas-kulvydo-1-3494545/?search_pos=19'}
#
#
# {'Miestas': 'Vilnius, UžupisKreivasis skg.', 'Kaina': '359000', 'Adresas': 'Vilnius, Užupis, Kreivasis skg., 3 kambarių butas', 'Namo numeris': '4', 'Plotas': '76,38 m²', 'Kambarių sk.': '3', 'Aukštas': '1', 'Aukštų sk.': '3', 'Metai': '2024', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Geoterminis', 'Įrengimas': 'Dalinė apdaila', 'Pastato energijos suvartojimo klasė': 'A+', 'Ypatybės': 'Nauja kanalizacija\nNauja elektros instaliacija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas\nDrabužinė', 'Papildoma įranga': 'Šildomos grindys\nRekuperacinė sistema', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna\nVaizdo kameros', 'URL': 'https://www.aruodas.lt/butai-vilniuje-uzupyje-kreivasis-skg-prestiziniame-uzupio-rajone-isikures-naujos-1-3488363/?search_pos=20'}
#
#
# {'Miestas': 'Vilnius, GudeliaiRojaus g.', 'Kaina': '523740', 'Adresas': 'Vilnius, Gudeliai, Rojaus g., 6 kambarių butas', 'Namo numeris': '4C', 'Plotas': '149,64 m²', 'Kambarių sk.': '6', 'Aukštas': '1', 'Aukštų sk.': '3', 'Metai': '2024', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Geoterminis', 'Įrengimas': 'Dalinė apdaila', 'Pastato energijos suvartojimo klasė': 'A++', 'Ypatybės': 'Atskiras įėjimas\nAukštos lubos\nButas per kelis aukštus\nNauja kanalizacija\nNauja elektros instaliacija', 'Papildomos patalpos': 'Sandėliukas\nVieta automobiliui', 'Papildoma įranga': 'Šildomos grindys', 'URL': 'https://www.aruodas.lt/butai-vilniuje-gudeliuose-rojaus-g-parduodamas-prabangus-metu-statybos-a-1-3488315/?search_pos=21'}
#
#
# {'Miestas': 'Vilnius, LazdynėliaiŽaibo g.', 'Kaina': '165000', 'Adresas': 'Vilnius, Lazdynėliai, Žaibo g., 2 kambarių butas', 'Namo numeris': '7', 'Plotas': '44 m²', 'Kambarių sk.': '2', 'Aukštas': '1', 'Aukštų sk.': '4', 'Metai': '2022', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'URL': 'https://www.aruodas.lt/butai-vilniuje-lazdyneliuose-zaibo-g-parduodamas-stilingai-ir-kokybiskai-irengtas-1-3498561/?search_pos=22'}
#
#
# {'Miestas': 'Kaunas, EiguliaiUkmergės g.', 'Kaina': '118817', 'Adresas': 'Kaunas, Eiguliai, Ukmergės g., 2 kambarių butas', 'Namo numeris': '18A', 'Plotas': '44,17 m²', 'Kambarių sk.': '2', 'Aukštas': '5', 'Aukštų sk.': '6', 'Metai': '2024', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Dalinė apdaila', 'Pastato energijos suvartojimo klasė': 'A++', 'Ypatybės': 'Yra liftas', 'URL': 'https://www.aruodas.lt/butai-kaune-eiguliuose-ukmerges-g-siaurio-namai-kai-viskas-mieste-pasiekiama-1-3476653/?search_pos=23'}
#
#
# {'Miestas': 'Klaipėda, RumpiškėsRumpiškės g.', 'Kaina': '175000', 'Adresas': 'Klaipėda, Rumpiškės, Rumpiškės g., 3 kambarių butas', 'Plotas': '49,53 m²', 'Kambarių sk.': '3', 'Aukštas': '3', 'Aukštų sk.': '4', 'Metai': '2006', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'URL': 'https://www.aruodas.lt/butai-klaipedoje-rumpiskese-rumpiskes-g-rumpiskes-gatveje-naujos-statybos-name-1-3271838/?search_pos=24'}
#
#
# {'Miestas': 'Kaunas, LampėdžiaiP. Leono g.', 'Kaina': '90400', 'Adresas': 'Kaunas, Lampėdžiai, P. Leono g., 2 kambarių butas', 'Namo numeris': '13', 'Plotas': '42,91 m²', 'Kambarių sk.': '2', 'Aukštas': '1', 'Aukštų sk.': '3', 'Metai': '2025', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Dalinė apdaila', 'Pastato energijos suvartojimo klasė': 'A++', 'Ypatybės': 'Nauja kanalizacija\nNauja elektros instaliacija\nUždaras kiemas\nInternetas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Terasa', 'Papildoma įranga': 'Plastikiniai vamzdžiai', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-kaune-lampedziuose-p-leono-g-noriu-jums-pristatyti-nauja-naujos-statybos-1-3493629/?search_pos=25'}
# Exception: 'NoneType' object is not subscriptable
# Exception: 'NoneType' object is not subscriptable
#
#
# {'Miestas': 'Kaunas, AleksotasKiečių g.', 'Kaina': '159000', 'Adresas': 'Kaunas, Aleksotas, Kiečių g., 4 kambarių butas', 'Namo numeris': '64', 'Plotas': '81,33 m²', 'Kambarių sk.': '4', 'Aukštas': '1', 'Aukštų sk.': '2', 'Metai': '1963', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Aeroterminis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Uždaras kiemas\nInternetas', 'Papildomos patalpos': 'Terasa\nVieta automobiliui', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nŽidinys\nDušo kabina\nVonia', 'Apsauga': 'Šarvuotos durys', 'URL': 'https://www.aruodas.lt/butai-kaune-aleksote-kieciu-g-puiki-galimybe-isigyti-buta-pirmajame-namo-1-3504553/?search_pos=26'}
#
#
# {'Miestas': 'Kaunas, SenamiestisVilniaus g.', 'Kaina': '200000', 'Adresas': 'Kaunas, Senamiestis, Vilniaus g., 3 kambarių butas', 'Namo numeris': '66', 'Plotas': '67 m²', 'Kambarių sk.': '3', 'Aukštas': '2', 'Aukštų sk.': '3', 'Metai': '1965', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Aukštos lubos\nNauja elektros instaliacija\nVirtuvė sujungta su kambariu', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nDušo kabina', 'Apsauga': 'Signalizacija\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-kaune-senamiestyje-vilniaus-g-parduodamas-triju-kambariu-butas-su-puikiu-1-3500891/?search_pos=27'}
#
#
# {'Miestas': 'Kaunas, SenamiestisŠv. Gertrūdos g.', 'Kaina': '162000', 'Adresas': 'Kaunas, Senamiestis, Šv. Gertrūdos g., 2 kambarių butas', 'Namo numeris': '14B', 'Plotas': '50 m²', 'Kambarių sk.': '2', 'Aukštas': '1', 'Aukštų sk.': '2', 'Metai': '1900', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Dujinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Atskiras įėjimas\nAukštos lubos\nNauja kanalizacija\nNauja elektros instaliacija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Vieta automobiliui\nDrabužinė', 'Papildoma įranga': 'Kondicionierius\nSkalbimo mašina\nŠaldytuvas\nŠildomos grindys\nVirtuvės komplektas\nViryklė\nIndaplovė\nDušo kabina\nRekuperacinė sistema', 'URL': 'https://www.aruodas.lt/butai-kaune-senamiestyje-sv-gertrudos-g-senamiestyje-prie-pat-vilniaus-g-ir-laisves-1-3499451/?search_pos=28'}
#
#
# {'Miestas': 'Kauno r. sav., Jonučių II k.Versmės g.', 'Kaina': '155000', 'Adresas': 'Kauno r. sav., Jonučių II k., Versmės g., 3 kambarių butas', 'Namo numeris': '3', 'Plotas': '70,77 m²', 'Kambarių sk.': '3', 'Aukštas': '4', 'Aukštų sk.': '4', 'Metai': '2009', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Dujinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Nauja kanalizacija\nNauja elektros instaliacija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas\nDrabužinė', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nIndaplovė\nDušo kabina', 'Apsauga': 'Šarvuotos durys\nSignalizacija\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-kauno-rajone-jonuciu-ii-k-versmes-g-parduodamas-patogus-ir-jaukiai-irengtas-1-3496503/?search_pos=29'}
#
#
# {'Miestas': 'Kaunas, Aukštieji ŠančiaiAšmenos 1-oji g.', 'Kaina': '169000', 'Adresas': 'Kaunas, Aukštieji Šančiai, Ašmenos 1-oji g., 3 kambarių butas', 'Namo numeris': '12', 'Plotas': '67,85 m²', 'Kambarių sk.': '3', 'Aukštas': '3', 'Aukštų sk.': '16', 'Metai': '2011', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Yra liftas\nNauja kanalizacija\nNauja elektros instaliacija\nInternetas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas', 'Papildoma įranga': 'Šaldytuvas\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nVonia', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-kaune-aukstuosiuose-sanciuose-asmenos-1-oji-g-parduodamas-kambariu-kvm-ploto-butas-1-3496281/?search_pos=30'}
#
#
# {'Miestas': 'Kauno r. sav., Raudondvario k.Vejuonos g.', 'Kaina': '165000', 'Adresas': 'Kauno r. sav., Raudondvario k., Vejuonos g., 4 kambarių butas', 'Namo numeris': '9', 'Plotas': '90,26 m²', 'Kambarių sk.': '4', 'Aukštas': '1', 'Aukštų sk.': '1', 'Metai': '2022 statyba, 2024 renovacija', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Dujinis', 'Įrengimas': 'Dalinė apdaila', 'Ypatybės': 'Atskiras įėjimas\nAukštos lubos\nNauja kanalizacija\nNauja elektros instaliacija\nUždaras kiemas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Sandėliukas\nRūsys\nVieta automobiliui\nDrabužinė', 'Papildoma įranga': 'Šildomos grindys\nPlastikiniai vamzdžiai', 'Apsauga': 'Signalizacija', 'URL': 'https://www.aruodas.lt/butai-kauno-rajone-raudondvario-k-vejuonos-g-parduodamas-erdvus-butas-vejuonos-g-1-3504629/?search_pos=31'}
#
#
# {'Miestas': 'Vilnius, JustiniškėsTaikos g.', 'Kaina': '119999', 'Adresas': 'Vilnius, Justiniškės, Taikos g., 3 kambarių butas', 'Plotas': '49,36 m²', 'Kambarių sk.': '3', 'Aukštas': '3', 'Aukštų sk.': '5', 'Metai': '1984', 'Pastato tipas': 'Blokinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Internetas\nTualetas ir vonia atskirai\nVirtuvė sujungta su kambariu\nKabelinė televizija', 'Papildomos patalpos': 'Balkonas\nRūsys\nDrabužinė', 'Papildoma įranga': 'Su baldais\nKondicionierius\nSkalbimo mašina\nVonia', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-justiniskese-taikos-g-kvieciame-jus-i-atviru-duru-diena-1-3499373/?search_pos=32'}
#
#
# {'Miestas': 'Vilnius, SenamiestisA. Goštauto g.', 'Kaina': '349000', 'Adresas': 'Vilnius, Senamiestis, A. Goštauto g., 4 kambarių butas', 'Plotas': '92 m²', 'Kambarių sk.': '4', 'Aukštas': '4', 'Aukštų sk.': '5', 'Metai': '1955', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Internetas\nAukštos lubos', 'Papildomos patalpos': 'Sandėliukas\nRūsys', 'Papildoma įranga': 'Su baldais\nSkalbimo mašina\nŠaldytuvas\nViryklė\nDušo kabina\nVonia', 'Apsauga': 'Šarvuotos durys', 'URL': 'https://www.aruodas.lt/butai-vilniuje-senamiestyje-a-gostauto-g-erdvus-kambariu-butas-su-vaizdais-i-neries-1-3503985/?search_pos=33'}
#
#
# {'Miestas': 'Kaunas, ŽaliakalnisSavanorių pr.', 'Kaina': '124900', 'Adresas': 'Kaunas, Žaliakalnis, Savanorių pr., 3 kambarių butas', 'Plotas': '54,3 m²', 'Kambarių sk.': '3', 'Aukštas': '5', 'Aukštų sk.': '5', 'Metai': '1965', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Virtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas\nRūsys\nDrabužinė', 'Papildoma įranga': 'Su baldais\nKondicionierius\nSkalbimo mašina', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-kaune-zaliakalnyje-savanoriu-pr-parduodamas-sviesus-ir-siltas-kambariu-1-3489789/?search_pos=34'}
#
#
# {'Miestas': 'Kaunas, DainavaPartizanų g.', 'Kaina': '136000', 'Adresas': 'Kaunas, Dainava, Partizanų g., 3 kambarių butas', 'Namo numeris': '192B', 'Plotas': '50 m²', 'Kambarių sk.': '3', 'Aukštas': '2', 'Aukštų sk.': '5', 'Metai': '2023', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Nauja kanalizacija\nNauja elektros instaliacija\nUždaras kiemas\nInternetas\nKabelinė televizija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas\nVieta automobiliui', 'Papildoma įranga': 'Šildomos grindys\nDušo kabina', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna\nVaizdo kameros', 'URL': 'https://www.aruodas.lt/butai-kaune-dainavoje-partizanu-g-k-butas-su-pilna-apdaila-projekte-paparcio-1-3500179/?search_pos=35'}
#
#
# {'Miestas': 'Vilnius, PilaitėM. Mažvydo g.', 'Kaina': '123000', 'Adresas': 'Vilnius, Pilaitė, M. Mažvydo g., 2 kambarių butas', 'Namo numeris': '29', 'Buto numeris': '46', 'Plotas': '45,64 m²', 'Kambarių sk.': '2', 'Aukštas': '1', 'Aukštų sk.': '5', 'Metai': '2024', 'Pastato tipas': 'Blokinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Dalinė apdaila', 'Pastato energijos suvartojimo klasė': 'A++', 'Ypatybės': 'Yra liftas\nAukštos lubos\nNauja kanalizacija\nNauja elektros instaliacija\nInternetas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Sandėliukas\nBalkonas\nVieta automobiliui', 'Papildoma įranga': 'Šildomos grindys\nRekuperacinė sistema', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna\nVaizdo kameros', 'URL': 'https://www.aruodas.lt/butai-vilniuje-pilaiteje-m-mazvydo-g-modernios-architekturos-a-energines-klases-1-3493325/?search_pos=36'}
#
#
# {'Miestas': 'Vilnius, ŠnipiškėsGiedraičių g.', 'Kaina': '109000', 'Adresas': 'Vilnius, Šnipiškės, Giedraičių g., 2 kambarių butas', 'Plotas': '48,2 m²', 'Kambarių sk.': '2', 'Aukštas': '5', 'Aukštų sk.': '5', 'Metai': '1979', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Papildomos patalpos': 'Balkonas\nRūsys', 'Papildoma įranga': 'Vonia', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-snipiskese-giedraiciu-g-giedraiciu-gatveje-penkiaaukscio-blokinio-1-3500687/?search_pos=37'}
#
#
# {'Miestas': 'Vilnius, PašilaičiaiPerkūnkiemio g.', 'Kaina': '123000', 'Adresas': 'Vilnius, Pašilaičiai, Perkūnkiemio g., 2 kambarių butas', 'Plotas': '44,23 m²', 'Kambarių sk.': '2', 'Aukštas': '8', 'Aukštų sk.': '9', 'Metai': '2007', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Virtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nDušo kabina', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-pasilaiciuose-perkunkiemio-g-parduodamas-kambariu-butas-perkunkiemio-1-3498887/?search_pos=38'}
#
#
# {'Miestas': 'Vilnius, NaujininkaiPelesos g.', 'Kaina': '137000', 'Adresas': 'Vilnius, Naujininkai, Pelesos g., 2 kambarių butas', 'Plotas': '49,88 m²', 'Kambarių sk.': '2', 'Aukštas': '1', 'Aukštų sk.': '3', 'Metai': '1940', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Kietu kuru', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Aukštos lubos', 'Papildoma įranga': 'Su baldais', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-naujininkuose-pelesos-g-kambariu-butas-aukstomis-lubomis-1-3496721/?search_pos=39'}
#
#
# {'Miestas': 'Vilnius, AntakalnisDuburio g.', 'Kaina': '194980', 'Adresas': 'Vilnius, Antakalnis, Duburio g., 3 kambarių butas', 'Plotas': '71,19 m²', 'Kambarių sk.': '3', 'Aukštas': '3', 'Aukštų sk.': '4', 'Metai': '2023', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Dujinis', 'Įrengimas': 'Įrengtas', 'Pastato energijos suvartojimo klasė': 'A+', 'Ypatybės': 'Virtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas', 'Papildoma įranga': 'Vonia', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-antakalnyje-duburio-g-kvieciu-i-apziura-si-ketvirtadieni-arba-si-1-3503475/?search_pos=40'}
#
#
# {'Miestas': 'Vilnius, ŠnipiškėsKonstitucijos pr.', 'Kaina': '449000', 'Adresas': 'Vilnius, Šnipiškės, Konstitucijos pr., 4 kambarių butas', 'Namo numeris': '15', 'Plotas': '90,42 m²', 'Kambarių sk.': '4', 'Aukštas': '13', 'Aukštų sk.': '29', 'Metai': '2018', 'Pastato tipas': 'Monolitinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Aukštos lubos\nNauja kanalizacija\nNauja elektros instaliacija\nUždaras kiemas\nInternetas\nKabelinė televizija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas\nVieta automobiliui\nDrabužinė', 'Papildoma įranga': 'Kondicionierius\nSkalbimo mašina\nSu baldais\nŠaldytuvas\nŠildomos grindys\nVirtuvės komplektas\nViryklė\nIndaplovė\nDušo kabina\nRekuperacinė sistema', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna\nVaizdo kameros\nBudintis sargas', 'URL': 'https://www.aruodas.lt/butai-vilniuje-snipiskese-konstitucijos-pr-erdvus-moderniai-irengtas-butas-premium-1-3491543/?search_pos=41'}
#
#
# {'Miestas': 'Kaunas, ŽaliakalnisŽuvinto g.', 'Kaina': '179900', 'Adresas': 'Kaunas, Žaliakalnis, Žuvinto g., 2 kambarių butas', 'Namo numeris': '30', 'Plotas': '57,7 m²', 'Kambarių sk.': '2', 'Aukštas': '4', 'Aukštų sk.': '6', 'Metai': '2007', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Pastato energijos suvartojimo klasė': 'B', 'Papildomos patalpos': 'Balkonas', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nVonia\nRekuperacinė sistema', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-kaune-zaliakalnyje-zuvinto-g-top-pasiulymas-zaliakalnis-parduodamas-1-3503491/?search_pos=42'}
#
#
# {'Miestas': 'Klaipėda, ŠauliaiPilkalnio g.', 'Kaina': '109000', 'Adresas': 'Klaipėda, Šauliai, Pilkalnio g., 2 kambarių butas', 'Namo numeris': '3', 'Plotas': '38,7 m²', 'Kambarių sk.': '2', 'Aukštas': '2', 'Aukštų sk.': '4', 'Metai': '2002', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Pastato energijos suvartojimo klasė': 'A+', 'Ypatybės': 'Aukštos lubos\nNauja kanalizacija\nNauja elektros instaliacija\nUždaras kiemas\nInternetas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas', 'Papildoma įranga': 'Šaldytuvas\nŠildomos grindys\nVirtuvės komplektas\nViryklė\nIndaplovė\nVonia\nRekuperacinė sistema', 'Apsauga': 'Šarvuotos durys\nSignalizacija\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-klaipedoje-sauliuose-pilkalnio-g-jaukus-irengtas-su-virtuves-baldais-ir-1-3504595/?search_pos=43'}
#
#
# {'Miestas': 'Kaunas, RomainiaiS. Banaičio g.', 'Kaina': '143000', 'Adresas': 'Kaunas, Romainiai, S. Banaičio g., 3 kambarių butas', 'Namo numeris': '42', 'Plotas': '62 m²', 'Kambarių sk.': '3', 'Aukštas': '2', 'Aukštų sk.': '2', 'Metai': '2023', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Dujinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Aukštos lubos\nNauja kanalizacija\nNauja elektros instaliacija\nUždaras kiemas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Vieta automobiliui', 'Papildoma įranga': 'Kondicionierius\nSkalbimo mašina\nSu baldais\nŠaldytuvas\nŠildomos grindys\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nIndaplovė\nDušo kabina', 'Apsauga': 'Šarvuotos durys\nSignalizacija\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-kaune-romainiuose-s-banaicio-g-parduodamas-naujai-ir-stilingai-irengtas-1-3498281/?search_pos=44'}
#
#
# {'Miestas': 'Kauno r. sav., Vijūkų k.Plytupio g.', 'Kaina': '124000', 'Adresas': 'Kauno r. sav., Vijūkų k., Plytupio g., 3 kambarių butas', 'Plotas': '63 m²', 'Kambarių sk.': '3', 'Aukštas': '2', 'Aukštų sk.': '2', 'Metai': '2023', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Aeroterminis', 'Įrengimas': 'Įrengtas', 'URL': 'https://www.aruodas.lt/butai-kauno-rajone-vijuku-k-plytupio-g-butai-tiesiogiai-is-statytojo-vijukuose-1-3472713/?search_pos=45'}
#
#
# {'Miestas': 'Kauno r. sav., Užliedžių k.Pienių g.', 'Kaina': '132000', 'Adresas': 'Kauno r. sav., Užliedžių k., Pienių g., 3 kambarių butas', 'Plotas': '72,72 m²', 'Kambarių sk.': '3', 'Aukštas': '3', 'Aukštų sk.': '3', 'Metai': '2023', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Aeroterminis', 'Įrengimas': 'Įrengtas', 'URL': 'https://www.aruodas.lt/butai-kauno-rajone-uzliedziu-k-pieniu-g-butai-tiesiogiai-is-statytojo-uzliedziai-1-3478425/?search_pos=46'}
#
#
# {'Miestas': 'Kauno r. sav., Vijūkų k.Plytupio g.', 'Kaina': '135000', 'Adresas': 'Kauno r. sav., Vijūkų k., Plytupio g., 3 kambarių butas', 'Plotas': '66 m²', 'Kambarių sk.': '3', 'Aukštas': '1', 'Aukštų sk.': '2', 'Metai': '2023', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Aeroterminis', 'Įrengimas': 'Įrengtas', 'URL': 'https://www.aruodas.lt/butai-kauno-rajone-vijuku-k-plytupio-g-butai-tiesiogiai-is-statytojo-vijukai-1-3499891/?search_pos=47'}
#
#
# {'Miestas': 'Vilnius, NaujamiestisT. Ševčenkos g.', 'Kaina': '92900', 'Adresas': 'Vilnius, Naujamiestis, T. Ševčenkos g., 1 kambario butas', 'Namo numeris': '16', 'Plotas': '19 m²', 'Kambarių sk.': '1', 'Aukštas': '2', 'Aukštų sk.': '4', 'Metai': '1950 statyba, 2024 renovacija', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis, centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Pastato energijos suvartojimo klasė': 'A+', 'Ypatybės': 'Yra liftas\nAtskiras įėjimas\nAukštos lubos\nNauja kanalizacija\nNauja elektros instaliacija\nUždaras kiemas\nInternetas\nKabelinė televizija\nVirtuvė sujungta su kambariu', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nDušo kabina', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna\nVaizdo kameros\nBudintis sargas', 'URL': 'https://www.aruodas.lt/butai-vilniuje-naujamiestyje-t-sevcenkos-g-parduodami-pilnai-naujai-irengti-apartamentai-1-3494939/?search_pos=48'}
#
#
# {'Miestas': 'Vilnius, MarkučiaiKaukysos g.', 'Kaina': '199900', 'Adresas': 'Vilnius, Markučiai, Kaukysos g., 2 kambarių butas', 'Namo numeris': '5', 'Plotas': '43 m²', 'Kambarių sk.': '2', 'Aukštas': '1', 'Aukštų sk.': '6', 'Metai': '2024', 'Pastato tipas': 'Monolitinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Pastato energijos suvartojimo klasė': 'A+', 'Ypatybės': 'Yra liftas\nUždaras kiemas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas\nVieta automobiliui', 'Papildoma įranga': 'Kondicionierius\nSu baldais\nŠaldytuvas\nŠildomos grindys\nVirtuvės komplektas\nViryklė\nIndaplovė\nVonia\nRekuperacinė sistema', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-markuciuose-kaukysos-g-parduodamas-visiskai-naujas-negyventas-1-3463302/?search_pos=49'}
#
#
# {'Miestas': 'Vilnius, NaujamiestisStatybininkų g.', 'Kaina': '285000', 'Adresas': 'Vilnius, Naujamiestis, Statybininkų g., 2 kambarių butas', 'Namo numeris': '1', 'Plotas': '68,38 m²', 'Kambarių sk.': '2', 'Aukštas': '5', 'Aukštų sk.': '9', 'Metai': '2018', 'Pastato tipas': 'Monolitinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Pastato energijos suvartojimo klasė': 'A+', 'Ypatybės': 'Tualetas ir vonia atskirai\nNauja kanalizacija\nNauja elektros instaliacija\nUždaras kiemas\nInternetas\nKabelinė televizija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas\nVieta automobiliui\nDrabužinė', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nŠildomos grindys\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nIndaplovė\nDušo kabina\nRekuperacinė sistema', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna\nVaizdo kameros', 'URL': 'https://www.aruodas.lt/butai-vilniuje-naujamiestyje-statybininku-g-erdvus-ir-skoningas-butas-labai-geroje-1-3307161/?search_pos=50'}
# Exception: 'NoneType' object is not subscriptable
# Exception: 'NoneType' object is not subscriptable
#
#
# {'Miestas': 'Klaipėda, SportininkaiJ. Janonio g.', 'Kaina': '95000', 'Adresas': 'Klaipėda, Sportininkai, J. Janonio g., 2 kambarių butas', 'Namo numeris': '28', 'Plotas': '35,14 m²', 'Kambarių sk.': '2', 'Aukštas': '3', 'Aukštų sk.': '5', 'Metai': '1962 statyba, 2024 renovacija', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'URL': 'https://www.aruodas.lt/butai-klaipedoje-sportininkuose-j-janonio-g-parduodamas-sviesus-siltas-jaukus-dvieju-1-3480727/?search_pos=51'}
#
#
# {'Miestas': 'Vilnius, Šiaurės miestelisŽygio g.', 'Kaina': '162000', 'Adresas': 'Vilnius, Šiaurės miestelis, Žygio g., 2 kambarių butas', 'Namo numeris': '92', 'Plotas': '47,17 m²', 'Kambarių sk.': '2', 'Aukštas': '6', 'Aukštų sk.': '9', 'Metai': '2009', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Yra liftas\nUždaras kiemas\nInternetas\nKabelinė televizija', 'Papildomos patalpos': 'Sandėliukas\nBalkonas\nVieta automobiliui\nDrabužinė', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-siaures-miestelyje-zygio-g-is-pirmu-seimininku-parduodamas-jaukus-1-3496735/?search_pos=52'}
#
#
# {'Miestas': 'Palanga, PalangaVasaros g.', 'Kaina': '110000', 'Adresas': 'Palanga, Palanga, Vasaros g., 3 kambarių butas', 'Namo numeris': '9', 'Plotas': '63 m²', 'Kambarių sk.': '3', 'Aukštas': '3', 'Aukštų sk.': '3', 'Metai': '1995', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Elektra, aeroterminis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Tualetas ir vonia atskirai\nInternetas', 'Papildomos patalpos': 'Balkonas', 'Papildoma įranga': 'Kondicionierius\nSkalbimo mašina\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nIndaplovė\nDušo kabina', 'Apsauga': 'Šarvuotos durys', 'URL': 'https://www.aruodas.lt/butai-palangoje-palangoje-vasaros-g-parduodamas-erdvus-kambariu-butas-palangoje-1-3486155/?search_pos=53'}
#
#
# {'Miestas': 'Vilnius, ŽirmūnaiŽirmūnų g.', 'Kaina': '115000', 'Adresas': 'Vilnius, Žirmūnai, Žirmūnų g., 2 kambarių butas', 'Namo numeris': '68', 'Plotas': '30 m²', 'Kambarių sk.': '2', 'Aukštas': '2', 'Aukštų sk.': '3', 'Metai': '2023', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Aukštos lubos\nButas per kelis aukštus\nNauja kanalizacija\nNauja elektros instaliacija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Vieta automobiliui\nDrabužinė', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nDušo kabina\nRekuperacinė sistema', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-zirmunuose-zirmunu-g-parduodamas-moderniai-ir-kokybiskai-irengtas-1-3500105/?search_pos=54'}
#
#
# {'Miestas': 'Kaunas, FredaLakūnų pl.', 'Kaina': '79999', 'Adresas': 'Kaunas, Freda, Lakūnų pl., 2 kambarių butas', 'Plotas': '32 m²', 'Kambarių sk.': '2', 'Aukštas': '1', 'Aukštų sk.': '2', 'Metai': '2024', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Dalinė apdaila', 'Ypatybės': 'Atskiras įėjimas\nAukštos lubos\nButas per kelis aukštus\nNauja kanalizacija\nNauja elektros instaliacija\nUždaras kiemas\nInternetas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Terasa\nVieta automobiliui', 'Papildoma įranga': 'Šildomos grindys\nPlastikiniai vamzdžiai\nRekuperacinė sistema', 'Apsauga': 'Šarvuotos durys', 'URL': 'https://www.aruodas.lt/butai-kaune-fredoje-lakunu-pl-lakunu-studijos-isskirtinai-uzburiantis-1-3458078/?search_pos=55'}
#
#
# {'Miestas': 'Palanga, PalangaSakalo g.', 'Kaina': '219000', 'Adresas': 'Palanga, Palanga, Sakalo g., 2 kambarių butas', 'Namo numeris': '30', 'Plotas': '48 m²', 'Kambarių sk.': '2', 'Aukštas': '2', 'Aukštų sk.': '2', 'Metai': '2019', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Dujinis', 'Įrengimas': 'Įrengtas', 'URL': 'https://www.aruodas.lt/butai-palangoje-palangoje-sakalo-g-jusu-ateities-namai-pusu-apsuptyje-1-3420809/?search_pos=56'}
#
#
# {'Miestas': 'Palanga, PalangaVanagupės g.', 'Kaina': '210000', 'Adresas': 'Palanga, Palanga, Vanagupės g., 2 kambarių butas', 'Namo numeris': '9D', 'Buto numeris': '14', 'Plotas': '38,39 m²', 'Kambarių sk.': '2', 'Aukštas': '2', 'Aukštų sk.': '3', 'Metai': '2023', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Pastato energijos suvartojimo klasė': 'A+', 'Papildomos patalpos': 'Balkonas\nVieta automobiliui\nDrabužinė', 'Papildoma įranga': 'Kondicionierius\nSkalbimo mašina\nSu baldais\nŠaldytuvas\nŠildomos grindys\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nIndaplovė\nDušo kabina\nVonia\nRekuperacinė sistema', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna\nVaizdo kameros', 'URL': 'https://www.aruodas.lt/butai-palangoje-palangoje-vanagupes-g-butas-salia-pusyno-su-balkonu-niekada-1-3472393/?search_pos=57'}
#
#
# {'Miestas': 'Vilnius, ŠeškinėŠeškinės g.', 'Kaina': '88000', 'Adresas': 'Vilnius, Šeškinė, Šeškinės g., 2 kambarių butas', 'Namo numeris': '59', 'Plotas': '53 m²', 'Kambarių sk.': '2', 'Aukštas': '1', 'Aukštų sk.': '16', 'Metai': '1985', 'Pastato tipas': 'Monolitinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Yra liftas\nTualetas ir vonia atskirai', 'Papildomos patalpos': 'Balkonas\nDrabužinė', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nVonia', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-seskineje-seskines-g-parduodamas-kambariu-butas-seskines-g-1-3475091/?search_pos=58'}
#
#
# {'Miestas': 'Klaipėda, SportininkaiSportininkų g.', 'Kaina': '107000', 'Adresas': 'Klaipėda, Sportininkai, Sportininkų g., 3 kambarių butas', 'Namo numeris': '13', 'Buto numeris': '15', 'Plotas': '65 m²', 'Kambarių sk.': '3', 'Aukštas': '1', 'Aukštų sk.': '3', 'Metai': '1970 statyba, 2023 renovacija', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis, elektra', 'Įrengimas': 'Dalinė apdaila', 'Pastato energijos suvartojimo klasė': 'A+', 'Ypatybės': 'Atskiras įėjimas\nButas per kelis aukštus\nNauja kanalizacija\nNauja elektros instaliacija\nUždaras kiemas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Terasa\nVieta automobiliui', 'URL': 'https://www.aruodas.lt/butai-klaipedoje-sportininkuose-sportininku-g-savininkas-parduoda-buta-per-du-aukstus-1-3504503/?search_pos=59'}
#
#
# {'Miestas': 'Klaipėda, KaunasKauno g.', 'Kaina': '105000', 'Adresas': 'Klaipėda, Kaunas, Kauno g., 2 kambarių butas', 'Namo numeris': '47', 'Plotas': '50 m²', 'Kambarių sk.': '2', 'Aukštas': '2', 'Aukštų sk.': '5', 'Metai': '1978', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Nauja kanalizacija\nNauja elektros instaliacija\nInternetas\nKabelinė televizija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nVonia', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-klaipedoje-kauno-mikrorajone-kauno-g-parduodamas-kambariu-butas-kauno-g-1-3503461/?search_pos=60'}
#
#
# {'Miestas': 'Klaipėda, GiruliaiTuristų g.', 'Kaina': '153000', 'Adresas': 'Klaipėda, Giruliai, Turistų g., 2 kambarių butas', 'Namo numeris': '1D', 'Buto numeris': '3', 'Plotas': '52 m²', 'Kambarių sk.': '2', 'Aukštas': '1', 'Aukštų sk.': '1', 'Metai': '2022', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Elektra', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Atskiras įėjimas\nAukštos lubos\nButas per kelis aukštus\nNauja kanalizacija\nNauja elektros instaliacija\nInternetas\nKabelinė televizija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Terasa\nVieta automobiliui', 'Papildoma įranga': 'Kondicionierius\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nŽidinys\nPlastikiniai vamzdžiai\nIndaplovė\nDušo kabina\nRekuperacinė sistema', 'Apsauga': 'Šarvuotos durys\nSignalizacija', 'URL': 'https://www.aruodas.lt/butai-klaipedoje-giruliuose-turistu-g-parduodami-lofto-tipo-apartamentai-giruliuose-1-3479005/?search_pos=61'}
#
#
# {'Miestas': 'Vilnius, AntakalnisKarių Kapų g.', 'Kaina': '326000', 'Adresas': 'Vilnius, Antakalnis, Karių Kapų g., 2 kambarių butas', 'Namo numeris': '12', 'Buto numeris': '14', 'Plotas': '81,62 m²', 'Kambarių sk.': '2', 'Aukštas': '3', 'Aukštų sk.': '3', 'Metai': '1999', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Dujinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Aukštos lubos\nButas per kelis aukštus\nInternetas\nKabelinė televizija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Sandėliukas\nVieta automobiliui', 'Papildoma įranga': 'Kondicionierius\nSkalbimo mašina\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nIndaplovė\nDušo kabina\nVonia', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-antakalnyje-kariu-kapu-g-ypatingai-sviesus-erdvus-isskirtinio-1-3183438/?search_pos=62'}
#
#
# {'Miestas': 'Vilnius, LazdynaiArchitektų g.', 'Kaina': '179000', 'Adresas': 'Vilnius, Lazdynai, Architektų g., 3 kambarių butas', 'Namo numeris': '64A', 'Unikalus daikto numeris (RC numeris)': '4400-0189-5198:1709', 'Plotas': '63,72 m²', 'Kambarių sk.': '3', 'Aukštas': '1', 'Aukštų sk.': '5', 'Metai': '2005', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Yra liftas\nTualetas ir vonia atskirai\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas\nVieta automobiliui', 'Papildoma įranga': 'Skalbimo mašina\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nIndaplovė\nVonia', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-lazdynuose-architektu-g-unikali-galimybe-apsigyventi-moderniuose-ir-1-3503215/?search_pos=63'}
#
#
# {'Miestas': 'Vilnius, AntakalnisDuburio g.', 'Kaina': '153570', 'Adresas': 'Vilnius, Antakalnis, Duburio g., 2 kambarių butas', 'Plotas': '49,37 m²', 'Kambarių sk.': '2', 'Aukštas': '4', 'Aukštų sk.': '4', 'Metai': '2023', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Dujinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Virtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-antakalnyje-duburio-g-parduodami-nauji-tik-gyvenamosios-paskirties-1-3498991/?search_pos=64'}
#
#
# ...
#
#
# {'Miestas': 'Vilnius, BajoraiBajorų kel.', 'Kaina': '149700', 'Adresas': 'Vilnius, Bajorai, Bajorų kel., 2 kambarių butas', 'Namo numeris': '29D', 'Buto numeris': '33', 'Unikalus daikto numeris (RC numeris)': '4400-6006-8960:2690', 'Plotas': '37,7 m²', 'Kambarių sk.': '2', 'Aukštas': '4', 'Aukštų sk.': '4', 'Metai': '2024', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Yra liftas', 'URL': 'https://www.aruodas.lt/butai-vilniuje-bajoruose-bajoru-kel-tiesioginis-pardavimas-be-tarpininku-1-3502847/?search_pos=1275'}
# Exception: 'NoneType' object is not subscriptable
# Exception: 'NoneType' object is not subscriptable
#
#
# {'Miestas': 'Panevėžio r. sav., Dembavos k.Melioratorių g.', 'Kaina': '41000', 'Adresas': 'Panevėžio r. sav., Dembavos k., Melioratorių g., 1 kambario butas', 'Namo numeris': '7', 'Plotas': '35 m²', 'Kambarių sk.': '1', 'Aukštas': '2', 'Aukštų sk.': '4', 'Metai': '1990 statyba, 2020 renovacija', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Neįrengtas', 'Papildomos patalpos': 'Balkonas\nRūsys', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-panevezio-rajone-dembavos-k-melioratoriu-g-parduodamas-kambario-butas-dembavoje-1-3502837/?search_pos=1276'}
#
#
# {'Miestas': 'Vilnius, FabijoniškėsVėtrungių g.', 'Kaina': '98000', 'Adresas': 'Vilnius, Fabijoniškės, Vėtrungių g., 1 kambario butas', 'Plotas': '37 m²', 'Kambarių sk.': '1', 'Aukštas': '3', 'Aukštų sk.': '12', 'Metai': '2004', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Yra liftas\nUždaras kiemas\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas\nVieta automobiliui\nDrabužinė', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nVonia', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-fabijoniskese-vetrungiu-g-naujas-pasiulymas-rinkoje-parduodamas-k-1-3502801/?search_pos=1277'}
#
#
# {'Miestas': 'Vilnius, PaupysPaupio g.', 'Kaina': '151000', 'Adresas': 'Vilnius, Paupys, Paupio g., 1 kambario butas', 'Namo numeris': '29A', 'Plotas': '30 m²', 'Kambarių sk.': '1', 'Aukštas': '2', 'Aukštų sk.': '4', 'Metai': '1960', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Nauja kanalizacija\nNauja elektros instaliacija\nInternetas\nKabelinė televizija\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Balkonas\nRūsys\nVieta automobiliui', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nŠildomos grindys\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nIndaplovė', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-paupyje-paupio-g-be-tarpininku-parduodamas-jaukus-butas-1-3502791/?search_pos=1278'}
#
#
# {'Miestas': 'Klaipėda, SenamiestisDanės g.', 'Kaina': '450000', 'Adresas': 'Klaipėda, Senamiestis, Danės g., 3 kambarių butas', 'Namo numeris': '9', 'Plotas': '132,47 m²', 'Kambarių sk.': '3', 'Aukštas': '2', 'Aukštų sk.': '8', 'Metai': '1985 statyba, 2020 renovacija', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'Papildomos patalpos': 'Balkonas\nTerasa', 'Papildoma įranga': 'Kondicionierius\nVirtuvės komplektas\nŽidinys\nIndaplovė', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna\nVaizdo kameros', 'URL': 'https://www.aruodas.lt/butai-klaipedoje-senamiestyje-danes-g-parduodamas-kambariu-butas-pacioje-1-3502497/?search_pos=1279'}
#
#
# {'Miestas': 'Klaipėda, AlksnynėTaikos pr.', 'Kaina': '168000', 'Adresas': 'Klaipėda, Alksnynė, Taikos pr., 3 kambarių butas', 'Plotas': '78 m²', 'Kambarių sk.': '3', 'Aukštas': '1', 'Aukštų sk.': '9', 'Metai': '2008', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Įrengtas', 'URL': 'https://www.aruodas.lt/butai-klaipedoje-alksnyneje-taikos-pr--ju-kambariu-butas-parduodamas-ju-1-3502793/?search_pos=1280'}
#
#
# {'Miestas': 'Vilnius, ŠnipiškėsKalvarijų g.', 'Kaina': '64900', 'Adresas': 'Vilnius, Šnipiškės, Kalvarijų g., 1 kambario butas', 'Namo numeris': '194', 'Plotas': '25,19 m²', 'Kambarių sk.': '1', 'Aukštas': '1', 'Aukštų sk.': '12', 'Metai': '1984', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Pastato energijos suvartojimo klasė': 'B', 'Ypatybės': 'Tualetas ir vonia atskirai', 'Papildomos patalpos': 'Vieta automobiliui', 'Papildoma įranga': 'Su baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nVonia', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-vilniuje-snipiskese-kalvariju-g-parduodamas-kambario-butas-su-baldais-ir-1-3502763/?search_pos=1281'}
#
#
# {'Miestas': 'Alytus, DainavaVarėnos g.', 'Kaina': '63000', 'Adresas': 'Alytus, Dainava, Varėnos g., 2 kambarių butas', 'Namo numeris': '31', 'Plotas': '51,37 m²', 'Kambarių sk.': '2', 'Aukštas': '5', 'Aukštų sk.': '5', 'Metai': '1984', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Tualetas ir vonia atskirai', 'Papildomos patalpos': 'Balkonas\nRūsys\nVieta automobiliui', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nVirtuvės komplektas\nViryklė\nVonia', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-alytuje-dainavoje-varenos-g-parduodamas-jaukus-kambariu-butas-su-1-3479169/?search_pos=1282'}
#
#
# {'Miestas': 'Vilnius, NaujamiestisEigulių g.', 'Kaina': '280000', 'Adresas': 'Vilnius, Naujamiestis, Eigulių g., 3 kambarių butas', 'Namo numeris': '7', 'Plotas': '59 m²', 'Kambarių sk.': '3', 'Aukštas': '4', 'Aukštų sk.': '6', 'Metai': '2023', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis kolektorinis', 'Įrengimas': 'Dalinė apdaila', 'Ypatybės': 'Yra liftas', 'URL': 'https://www.aruodas.lt/butai-vilniuje-naujamiestyje-eiguliu-g-erdvus-butas-su-labai-didele-terasa-prie-1-3502729/?search_pos=1283'}
#
#
# {'Miestas': 'Klaipėda, Žvejybos uostasNidos g.', 'Kaina': '74500', 'Adresas': 'Klaipėda, Žvejybos uostas, Nidos g., 2 kambarių butas', 'Namo numeris': '56', 'Plotas': '56,54 m²', 'Kambarių sk.': '2', 'Aukštas': '7', 'Aukštų sk.': '9', 'Metai': '1981', 'Pastato tipas': 'Blokinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Tualetas ir vonia atskirai', 'Papildomos patalpos': 'Balkonas', 'Papildoma įranga': 'Su baldais\nŠaldytuvas\nViryklė', 'Apsauga': 'Šarvuotos durys\nKodinė laiptinės spyna', 'URL': 'https://www.aruodas.lt/butai-klaipedoje-zvejybos-uoste-nidos-g-kambariu-butas-kvm-aukstas-1-3502699/?search_pos=1284'}
#
#
# {'Miestas': 'Marijampolės m., DegučiaiDegučių g.', 'Kaina': '25500', 'Adresas': 'Marijampolės m., Degučiai, Degučių g., 2 kambarių butas', 'Plotas': '36 m²', 'Kambarių sk.': '2', 'Aukštas': '2', 'Aukštų sk.': '5', 'Metai': '1970', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Internetas\nKabelinė televizija', 'Papildomos patalpos': 'Balkonas\nVieta automobiliui', 'Papildoma įranga': 'Skalbimo mašina\nSu baldais\nŠaldytuvas\nViryklė\nVonia', 'URL': 'https://www.aruodas.lt/butai-marijampoleje-deguciuose-deguciu-g-kambariai-siltilangai-i-gatves-pusenetoli-1-3405845/?search_pos=1285'}
#
#
# {'Miestas': 'Akmenės r. sav., Naujosios Akmenės m.Respublikos g.', 'Kaina': '19500', 'Adresas': 'Akmenės r. sav., Naujosios Akmenės m., Respublikos g., 2 kambarių butas', 'Namo numeris': '5', 'Plotas': '44,25 m²', 'Kambarių sk.': '2', 'Aukštas': '5', 'Aukštų sk.': '5', 'Metai': '1970', 'Pastato tipas': 'Blokinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Nauja elektros instaliacija', 'Papildomos patalpos': 'Balkonas\nRūsys', 'Papildoma įranga': 'Su baldais\nPlastikiniai vamzdžiai\nSkalbimo mašina\nVirtuvės komplektas', 'URL': 'https://www.aruodas.lt/butai-akmeneje-naujosios-akmenes-m-respublikos-g-parduodamas-kambariu-butas-respublikos-1-3502673/?search_pos=1286'}
#
#
# {'Miestas': 'Kaunas, ŽaliakalnisRimvydo g.', 'Kaina': '29800', 'Adresas': 'Kaunas, Žaliakalnis, Rimvydo g., 1 kambario butas', 'Namo numeris': '17', 'Plotas': '18 m²', 'Kambarių sk.': '1', 'Aukštas': '2', 'Aukštų sk.': '5', 'Metai': '1970', 'Pastato tipas': 'Blokinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'URL': 'https://www.aruodas.lt/butai-kaune-zaliakalnyje-rimvydo-g-parduodamas-vieno-kambario-butas-daugiau-1-3502659/?search_pos=1287'}
#
#
# {'Miestas': 'Kaunas, ŽaliakalnisVaižganto g.', 'Kaina': '367000', 'Adresas': 'Kaunas, Žaliakalnis, Vaižganto g., 3 kambarių butas', 'Namo numeris': '7', 'Plotas': '100 m²', 'Kambarių sk.': '3', 'Aukštas': '1', 'Aukštų sk.': '4', 'Metai': '2006', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Ypatybės': 'Yra liftas\nAukštos lubos\nVirtuvė sujungta su kambariu', 'Papildomos patalpos': 'Vieta automobiliui', 'Papildoma įranga': 'Kondicionierius\nSkalbimo mašina\nSu baldais\nŠaldytuvas\nŠildomos grindys\nVirtuvės komplektas\nViryklė\nPlastikiniai vamzdžiai\nIndaplovė\nDušo kabina\nVonia\nRekuperacinė sistema', 'Apsauga': 'Šarvuotos durys\nSignalizacija\nKodinė laiptinės spyna\nVaizdo kameros', 'URL': 'https://www.aruodas.lt/butai-kaune-zaliakalnyje-vaizganto-g-1-3478091/?search_pos=1288'}
#
#
# {'Miestas': 'Jurbarko m.Algirdo g.', 'Kaina': '37000', 'Adresas': 'Jurbarko m., Algirdo g., 2 kambarių butas', 'Namo numeris': '10', 'Plotas': '47 m²', 'Kambarių sk.': '2', 'Aukštas': '3', 'Aukštų sk.': '5', 'Metai': '1980', 'Pastato tipas': 'Blokinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'URL': 'https://www.aruodas.lt/butai-jurbarke-algirdo-g-butas-jurbarke-parduodamas-ju-kambariu-1-3502639/?search_pos=1289'}
#
#
# {'Miestas': 'Panevėžys, KniaudiškiaiAinių g.', 'Kaina': '89000', 'Adresas': 'Panevėžys, Kniaudiškiai, Ainių g., 2 kambarių butas', 'Plotas': '35 m²', 'Kambarių sk.': '2', 'Aukštas': '2', 'Aukštų sk.': '4', 'Metai': '2023', 'Pastato tipas': 'Mūrinis', 'Šildymas': 'Centrinis', 'Įrengimas': 'Įrengtas', 'Papildomos patalpos': 'Sandėliukas\nBalkonas\nVieta automobiliui', 'Papildoma įranga': 'Kondicionierius\nSkalbimo mašina\nSu baldais\nŠaldytuvas\nŠildomos grindys\nVirtuvės komplektas\nViryklė\nDušo kabina\nRekuperacinė sistema', 'URL': 'https://www.aruodas.lt/butai-panevezyje-kniaudiskiuose-ainiu-g-parduodamas-modernus-naujos-statybos-butas-1-3499159/?search_pos=1290'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 34
#      32 skelbimai['Miestas'] = s.find('a').text.strip()
#      33 skelbimai['Kaina'] = s.find_all('span', {'class':'list-item-price-v2'})[0].text.strip().replace(' ','')[:-1]
# ---> 34 driver.get(url)
#      35 source = driver.page_source
#      36 bs = BeautifulSoup(source, 'html.parser')
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:363, in WebDriver.get(self, url)
#     361 def get(self, url: str) -> None:
#     362     """Loads a web page in the current browser session."""
# --> 363     self.execute(Command.GET, {"url": url})
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:352, in WebDriver.execute(self, driver_command, params)
#     349     elif "sessionId" not in params:
#     350         params["sessionId"] = self.session_id
# --> 352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
#     354     self.error_handler.check_response(response)
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/remote/remote_connection.py:306, in RemoteConnection.execute(self, command, params)
#     304 trimmed = self._trim_large_entries(params)
#     305 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 306 return self._request(command_info[0], url, body=data)
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/remote/remote_connection.py:326, in RemoteConnection._request(self, method, url, body)
#     323     body = None
#     325 if self.keep_alive:
# --> 326     response = self._conn.request(method, url, body=body, headers=headers)
#     327     statuscode = response.status
#     328 else:
#
# File /usr/lib/python3/dist-packages/urllib3/_request_methods.py:118, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     110     return self.request_encode_url(
#     111         method,
#     112         url,
#    (...)
#     115         **urlopen_kw,
#     116     )
#     117 else:
# --> 118     return self.request_encode_body(
#     119         method, url, fields=fields, headers=headers, **urlopen_kw
#     120     )
#
# File /usr/lib/python3/dist-packages/urllib3/_request_methods.py:217, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     213     extra_kw["headers"].setdefault("Content-Type", content_type)
#     215 extra_kw.update(urlopen_kw)
# --> 217 return self.urlopen(method, url, **extra_kw)
#
# File /usr/lib/python3/dist-packages/urllib3/poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /usr/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /usr/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /usr/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
skelbimai
# Out:
# {'Miestas': 'Vilnius, ŽvėrynasSėlių g.', 'Kaina': '163000'}

# %%
aruodas.write_narrow('aruodas_narrow.csv','csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 aruodas.write_narrow('aruodas_narrow.csv','csv')
#
# AttributeError: 'properties_of' object has no attribute 'write_narrow'

# %%
Objekto_tipai = {'Butai pardavimui':'butai', 'Butai nuomai':'butu-nuoma'}
Miestai = {'Kaunas':'kaune', 'Vilnius':'vilniuje', 'Klaipėda':'klaipedoje', 'Šiauliai':'siauliuose', 'Panevėžys':'panevezyje', 'Alytus':'alytuje', 'Palanga':'palangoje'}
for obj in Objekto_tipai.keys():
    print(Objekto_tipai[obj])
    puslapis = 1
    opcijos = Options()
    opcijos.add_argument('--incognito')
    driver = webdriver.Chrome(options=opcijos)
    url = f'https://www.aruodas.lt/{Objekto_tipai[obj]}/puslapis/{puslapis}/?FOwnerDbId0=1&FOwnerDbId2=1'
    driver.get(url)
    time.sleep(3)
    source = driver.page_source
    bs = BeautifulSoup(source, 'html.parser')
    first = bs.find('div', {'class':'markTexts'})
    skelbimai = first.find('div', {'class':'number'})
    puslapiai = int(int(skelbimai.text.strip().replace('(','').replace(')',''))/25)
    for puslapis in range(puslapiai):
        puslapis = puslapis + 1
        url = f'https://www.aruodas.lt/{Objekto_tipai[obj]}/puslapis/{puslapis}/?FOwnerDbId0=1&FOwnerDbId2=1'
        driver.get(url)
        source = driver.page_source
        bs = BeautifulSoup(source, 'html.parser')
        skelbimas = bs.find_all('div', {'class':'list-adress-v2'})
        for s in skelbimas:
            try:
                if True:
                    skelbimai = {}
                    url = s.find('a')['href']
                    item_id = url.split('/')[-2].split('-')[-1]
                    print(f"\n{item_id}")
                    item_miestas = s.find('a').text.strip()
                    item_kaina = s.find_all('span',{'class':'list-item-price-v2'})[0].text.strip().replace(' ','')[:-1]
                    driver.get(url)
                    source = driver.page_source
                    bs = BeautifulSoup(source, 'html.parser')
                    pav = bs.find('dl', {'class':'obj-details'}).find_all('dt')
                    values = bs.find('dl', {'class':'obj-details'}).find_all('dd')
                    item_adresas = bs.find('h1', {'class':'obj-header-text'}).text.strip()
                    for p, v in zip(pav,values):
                        skelbimai[p.text.strip()[:-1]] = v.text.strip()
                    print(f"{item_id}\n{item_Miestas}, {item_Kaina}")
                    if item_id:
                        aruodas.add_property(item_id,'url',url)
                        aruodas.add_property(item_id,'miestas',item_miestas)
                        aruodas.add_property(item_id,'kaina',item_kaina)
                        aruodas.add_property(item_id,'adresas',item_adresas)
                    for p, v in zip(pav,values):
                        skelbimai[p.text.strip()[:-1]] = v.text.strip()
                        print(f" {p.text.strip()[:-1]} === {v.text.strip()} ")
            except Exception as e:
                print(f"Exception '{e}'")
    driver.close()

# %%
url='https://www.aruodas.lt/butai-kaune-sanciuose-a-juozapaviciaus-pr-butas-yra-isskirtiniame-wwwjuozapaviciaus-1-3496385/?search_pos=2'
print(url)

item_id = url.split('/')[-2].split('-')[-1]

print(item_id)
# Out:
# https://www.aruodas.lt/butai-kaune-sanciuose-a-juozapaviciaus-pr-butas-yra-isskirtiniame-wwwjuozapaviciaus-1-3496385/?search_pos=2
# 3496385

# %%
db_path = '../../../web_scrap.db'
query = 'SELECT * FROM aruodas;'

df = query_to_dataframe(db_path, query)
df.head()
