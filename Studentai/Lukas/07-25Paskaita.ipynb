# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# sudetingesnis

f = [1,2,3,4]
m = [-2,5,1,3]

# langas, grafikas = plt.subplots()
fig, axis = plt.subplots()

axis.plot(f, m)

plt.show()

# %%
f = [1,2,3,4]
m = [-2,5,1,3]

fig, axis = plt.subplots(2, 2)

axis[1,0].plot(f,m)
axis[1,0].plot(f, list(map(lambda x: x*1.25, m)))
axis[1,0].plot(f, list(map(lambda x: x+0.25, m)))
axis[1,1].plot(f, list(map(lambda x: x+0.25, m)))

plt.show()

# %%
fix, axes = plt.subplots(1,2, figsize=[12, 4])



plt.show()

# %%
plt.plot(f, m, label='pvz1', marker='H', markersize=10, mfc='red')
plt.plot(f, list(map(lambda x: x*1.25, m)), label='pvz2')
plt.grid()
plt.legend(loc='best')
plt.show()

# %%
a = np.arange(1,11)
b = np.random.randint(1,15,10)
c = np.random.randint(1,15,10)
d = np.random.randint(1,15,10)

fig, axis = plt.subplots(figsize=(8,6))
#plotting code:

axis.plot(a,b, color='green', ms = 12, marker = 's', lw=3, ls='-.', label='plot pvz')

axis.scatter(a,c, marker='s', s=64, color='xkcd:deep blue', label='scatter pvz.')

axis.legend(loc='best')
#axis.ticklabel_format(style='plain')
fig.tight_layout()
plt.show()

# %%
# A) Duotas sąrašas x=[1,2,3,4,5,6,7,8,9]
# Viename lange, skirtingose ašyse atvaizduokite x2 , x ⋅ 3,
# x ⋅ a, čia a - įvedamas vartotojo.
# Panaudokite skirtingas spalvas, linijų tipus.


x=[1,2,3,4,5,6,7,8,9]
a = 5
y1 = list(map(lambda y: y**2, x))
y2 = list(map(lambda y: y*3, x))
y3 = list(map(lambda y: y*a, x))

fig, axis = plt.subplots(1,3, figsize=[12,4])
axis[0].plot(x, y1, color='green', lw=3, ls='-.')
axis[1].plot(x, y2, color='red', lw=3, ls=':')
axis[2].plot(x, y3, color='blue', lw=4, ls='--')

plt.show()

# %%
# B) Duoti sąrašai x = [1,2,3,4,5], y1=[2,2,0,0,2], y2 =
# [4,3,2,1,-1], y3 = [2,4,9,16,25], y4 = [-1,1,-1,1,-1]
# Atvaizduokite viename lange x~y1, x~y2,
# x~y3, x~y4 kreives (grafikus). Pirmasis grafikas - linijinis, antrasis - taškinis,
# trečiasis - linija su duomenų taškais, ketvirtasis - brūkšninis.
# Spalvos visų turi būti skirtingos. Grafikai, ašys turi turėti
# pavadinimus.
x = [1,2,3,4,5]
y1=[2,2,0,0,2]
y2 = [4,3,2,1,-1]
y3 = [2,4,9,16,25]
y4 = [-1,1,-1,1,-1]

fig, axis = plt.subplots(2, 2, figsize=(5,4))
axis[0,0].plot(x, y1, ls='solid', lw=3, color='#ffbacd', label='y1')
axis[0,1].plot(x, y2, ls='dotted', lw=3, color='#048243')
axis[1,0].plot(x, y3, ls='solid', lw=3, color='chocolate', marker='s', markersize=12)
axis[1,1].plot(x, y4, ls='--', lw=3, color='#fcc006')

axis[0,0].set_xlabel('X asis')
axis[0,0].set_ylabel('Y asis')
axis[0,1].set_xlabel('X asis')
axis[0,1].set_ylabel('Y asis')
axis[1,0].set_xlabel('X asis')
axis[1,0].set_ylabel('Y asis')
axis[1,1].set_xlabel('X asis')
axis[1,1].set_ylabel('Y asis')

axis[0,1].set_title('[0,1] grafikas', fontsize=8)
axis[1,1].set_title('[1,1] grafikas', fontsize=8)

axis[0,0].legend(loc='best')

fig.tight_layout()
plt.show()

# %%
# Sugeneruoti sąrašą x, turintį 101 elementą (nuo 0 iki 100).
# Sukurti antrą sąrašą, kuriame būtų skaičiai, pakelti kvadratu, iš
# pirmojo sąrašo (x2 )
# Sukurti trečiąjį sąrašą, kuriame skaičiai būtų pakelti kvadratu ir
# padauginti iš atsitiktinai sugeneruoto skaičiaus (x2 ⋅ a).
# Sugeneruoti 101-to elementų ilgio sąrašą iš atsitiktinių skaičių.
# Visus šiuos sąrašus atvaizduoti grafike. Grafikas turi turėti
# pavadinimą, pavadintos ašys, pakeisti šriftų dydžiai.

# a = np.arange(1,11)
# b = np.random.randint(1,15,10)
# c = np.random.randint(1,15,10)
# d = np.random.randint(1,15,10)

x = np.arange(0, 101)
y1 = list(map(lambda y: y**2, x))
a = np.random.rand()
y2 = list(map(lambda y: y**2 * a, x))
y3 = np.random.randint(0, 10000, 101)

fig, axis = plt.subplots(figsize=(4, 3))
axis.plot(x, y1, color='green', lw=3, ls='-.', label = 'x**2')
axis.plot(x, y2, color='red', lw=3, ls=':', label='x**2 *a')
axis.plot(x, y3, color='blue', lw=1, ls='--', label='random')

axis.set_xlabel('x axis', fontsize=16)
axis.set_ylabel('x priklausomybe',fontsize=16)
axis.set_title('cia galetu buti jusu reklama',fontsize=24)
axis.tick_params(axis='x', labelsize=16)
axis.tick_params(axis='y', labelsize=14)

axis.legend(loc='best')
plt.show()
