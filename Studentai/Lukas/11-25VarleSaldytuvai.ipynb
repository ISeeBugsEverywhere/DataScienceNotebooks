# %%
import selenium
from selenium.webdriver.chrome.options import Options
# from selenium.webdriver.firefox.options import Options as FirefoxOptions
import undetected_chromedriver as uc
# from selenium import webdriver
from bs4 import BeautifulSoup
import time
import sqlite3
import mysql.connector as cnt
import random

# %%
# import pandas as pd
# import undetected_chromedriver as uc
# from bs4 import BeautifulSoup
# import selenium
# from selenium.webdriver.chrome.options import Options

# import time
# import sys
# import os
# import numpy as np

# options = Options()
# options.add_argument('--incognito')
# driver = uc.Chrome(use_subprocess=True, suppress_welcome=True, options=options)

# https://www.zenrows.com/blog/undetected-chromedriver#how-to-use-undetected-chromedriver

# %%
def getColNamesList(table, dbname):
    db = sqlite3.connect(dbname)
    c = db.cursor()
    sql = '''select * from {table} limit 0'''.format(table=table)
    s = c.execute(sql)
    # r = s.description
    column_names = [description[0] for description in c.description]
    return column_names

def alterTableAddColumn(cols_i_want_to_have, cols_i_have, table, base):
    db = sqlite3.connect(base)
    c = db.cursor()
    sql = '''alter table {tname}
    add column `{n}`
    '''
    for cl in cols_i_want_to_have:
        if cl not in cols_i_have:
            c.execute(sql.format(tname=table, n=cl))
            time.sleep(1)
            db.commit()
            time.sleep(3)
    c.close()
    db.close()
    return True


def createMainTable(dbname:str) -> bool:
    sql = '''
    drop table if exists SaldytuvaiVarle
    '''
    db = sqlite3.connect(dbname)
    c = db.cursor()
    c.execute(sql)
    sql = '''create table if not exists SaldytuvaiVarle
    (
        nuoroda text,
        firstInfo text
    )
    '''
    c.execute(sql)
    c.close()
    db.close()
    return True
    pass

def writeMany(lst, table, dbname) -> bool:
    db = sqlite3.connect(dbname)
    c = db.cursor()
    sql = '''insert into {table} values ({n})'''
    q = ['?' for i in range(0,len(lst))]
    q_ = ', '.join(q)
    r_ = sql.format(table=table, n=q_)
    # print('::PROVIDED::', lst, len(lst), '::SQL COMMAND::', r_, len(q), sep='\n')
    c.execute(r_, lst)
    db.commit()
    c.close()
    db.close()
    return True

# %%
opcijos = Options()
opcijos.add_argument('--incognito')
opcijos.add_argument('--ignore-certificate-errors')
opcijos.add_argument('--ignore-ssl-errors')
driver = uc.Chrome(use_subprocess=True, suppress_welcome=True, options=opcijos)
url = 'https://www.varle.lt/saldytuvai/?p=1'
driver.get(url)
time.sleep(5)
source = driver.page_source


driver.close()
print('Baigta!!!')
# Out:
# Baigta!!!

# %%
bs = BeautifulSoup(source, 'html.parser')
p_nuorodos = []

linkai = bs.find_all('div', {'class':'GRID_ITEM'})
for linkas in linkai:
    # linkas = bs.find('div', {'class':'product-title'}).find('div', {'class':'product-title'}).find('a')
    link = linkas.find('div', {'class':'product-title'}).find('a')
    # print(link['href'])
    add_link = 'https://www.varle.lt'+ link['href']
    # print(add_link)
    p_nuorodos.append(add_link)
print(len(p_nuorodos))
print(p_nuorodos)

pages = []
pages_numbers = bs.find('div', {'class':'PAGINATION'}).find_all('li', {'class':'number'})
for page in pages_numbers:
    # print(page.text.strip())
    pages.append(int(page.text.strip()))
pages_max_number = max(pages)
print(pages_max_number)
# Out:
# 38
https://www.varle.lt/saldytuvai/saldytuvas-gastronominis-saldymo-stalas-4-stalciai--40272162.html', 'https://www.varle.lt/saldytuvai/saldytuvas-royal-catering-saldymo-vitrina-su-led-apsvietimu--40149283.html', 'https://www.varle.lt/saldytuvai/saldytuvas-hisense-rb440n4gbd--29871329.html', 'https://www.varle.lt/saldytuvai/lg-saldytuvas-gbv7180cpy-energy-efficiency-class--32152423.html', 'https://www.varle.lt/saldytuvai/saldytuvas-gorenje-rb493pw-baltas--25438488.html', 'https://www.varle.lt/saldytuvai/built-in-saldytuvas-whirlpool-70cm--28243109.html', 'https://www.varle.lt/saldytuvai/goddess-single-door-saldytuvas-with-saldiklis-compartment--39621724.html']
# 33

# %%
for nuoroda in p_nuorodos[:1]:
    print(nuoroda)
    opcijos = Options()
    opcijos.add_argument('--incognito')
    opcijos.add_argument('--ignore-certificate-errors')
    opcijos.add_argument('--ignore-ssl-errors')
    driver = uc.Chrome(use_subprocess=True, suppress_welcome=True, options=opcijos)
    url = nuoroda
    driver.get(url)
    time.sleep(5)
    source = driver.page_source


    driver.quit()
# Out:
# https://www.varle.lt/saldytuvai/saldytuvas-sharp-sj-ftb01itxse-eu--36822303.html

# %%
bs = BeautifulSoup(source, 'html.parser')
pavadinimas = bs.find('div', {'class':'main'}).find('h1', {'class':'title'}).text.strip()
print(pavadinimas)

# varle_kodas = bs.find('div', {'class':'main'}).find('span', {'itemprop':'sku'}).text
# print(varle_kodas)

kaina = bs.find('span', {'class':'price-value'}).text.strip()
print(kaina)

buvusi_kaina = bs.find('span', {'class':'previous-price'})
if buvusi_kaina != None:
    buvusi_kaina = buvusi_kaina.text.strip()
else:
    buvusi_kaina = None
print(buvusi_kaina)

specifiacija_keys = []
specifiacija_values = []
try:
    specifiacija = bs.find('div', {'class':'PRODUCT_SPEC'}).find_all('li', {'class':'spec-line'})
    for line in specifiacija:
        try:
            spec_key = line.find('span', {'class':'left-column'}).text
            # print(spec_key)
            specifiacija_keys.append(spec_key)
            spec_value = line.find('span', {'class':'right-column'}).text
            # print(spec_value)
            specifiacija_values.append(spec_value)
        except:
            pass
        try:
            spec_key = line.find('div', {'class':'left-column'}).text
            # print(spec_key)
            specifiacija_keys.append(spec_key)
            spec_value = line.find('div', {'class':'right-column'}).text
            # print(spec_value)
            specifiacija_values.append(spec_value)
        except:
            pass
except:
    pass

try:
    specifiacija_k = bs.find('div', {'class':'PRODUCT_SPEC'}).find_all('td', {'class':'key'})
    for key in specifiacija_k:
        # print(key.text.strip())
        specifiacija_keys.append(key.text.strip().lower())
    specifiacija_v = bs.find('div', {'class':'PRODUCT_SPEC'}).find_all('td', {'class':'value'})
    for val in specifiacija_v:
        # print(val.text.strip())
        specifiacija_values.append(val.text.strip())       
except:
    pass

print(len(specifiacija_keys), specifiacija_keys)
print(len(specifiacija_values), specifiacija_values)

spec_filtrai_keys = []
spec_filtrai_values = []
try:
    spec_filtai = bs.find('div', {'class':'PRODUCT_SPEC_FILTERS'}).find_all('li', {'class':'spec-line'})
    for line in spec_filtai:
        spec_key = line.find('span', {'class':'left-column'}).text.strip().lower()
        # print(spec_key)
        spec_filtrai_keys.append(spec_key)
        spec_value = line.find('span', {'class':'right-column'}).text.strip()
        # print(spec_value)
        spec_filtrai_values.append(spec_value)
except:
    pass
    
print(len(spec_filtrai_keys), spec_filtrai_keys)
print(len(spec_filtrai_values), spec_filtrai_values)

# for k,v in zip(specifiacija_keys, specifiacija_values):
#     print(k, v)
# Out:
# Šaldytuvas Sharp SJ-FTB01ITXSE-EU
# 222
# 289 €
# 2 ['Gamintojas', 'Modelio pavadinimas']
# 2 ['Sharp', 'SJFTB01ITXSEEU']
# 6 ['gamintojas', 'tipas', 'montavimo tipas', 'energijos klasė', 'talpa (l)', 'aukštis (cm)']
# 6 ['Sharp', 'Su kamera viršuje', 'Laisvai statomi', 'E', '213.0', '145.0']

# %%
# createMainTable('VarlePigu.db')
# Out:
# True

# %%
# Saldytuvai Varle scraper

opcijos = Options()
opcijos.add_argument('--incognito')
opcijos.add_argument('--ignore-certificate-errors')
opcijos.add_argument('--ignore-ssl-errors')
driver = uc.Chrome(use_subprocess=True, suppress_welcome=True, options=opcijos)
url = 'https://www.varle.lt/saldytuvai/?p=1'
driver.get(url)
time.sleep(5)
source = driver.page_source

bs = BeautifulSoup(source, 'html.parser')
pages = []
pages_numbers = bs.find('div', {'class':'PAGINATION'}).find_all('li', {'class':'number'})
for page in pages_numbers:
    # print(page.text.strip())
    pages.append(int(page.text.strip()))
pages_max_number = max(pages)

counts = 1
psl = 1
# iki_kokio_psl = 3
# while psl < iki_kokio_psl:
while psl < pages_max_number + 1:
    source = driver.page_source
    bs = BeautifulSoup(source, 'html.parser')
    p_nuorodos = []

    linkai = bs.find_all('div', {'class':'GRID_ITEM'})
    for linkas in linkai:
        # linkas = bs.find('div', {'class':'product-title'}).find('div', {'class':'product-title'}).find('a')
        link = linkas.find('div', {'class':'product-title'}).find('a')
        # print(link['href'])
        add_link = 'https://www.varle.lt'+ link['href']
        # print(add_link)
        p_nuorodos.append(add_link)
        
    for nuoroda in p_nuorodos:
        print(psl, nuoroda)
        url = nuoroda
        driver.get(url)
        # time.sleep(random.randint(5,10))
        time.sleep(3)
        source = driver.page_source
        
        cols_i_have = getColNamesList(table='SaldytuvaiVarle', dbname='VarlePigu.db')
        
        duomenys = {}
        for col in cols_i_have:
            duomenys[col] = None
            
        duomenys['nuoroda'] = nuoroda
        
        bs_preke = BeautifulSoup(source, 'html.parser')
        
        firstInfo = bs_preke.find('div', {'class':'main'}).find('h1', {'class':'title'}).text.strip()
        duomenys['firstInfo'] = firstInfo
        # print(pavadinimas)


        kaina = bs_preke.find('span', {'class':'price-value'}).text.strip()
        duomenys['kaina'] = kaina
        # print(kaina)

        buvusi_kaina = bs_preke.find('span', {'class':'previous-price'})
        if buvusi_kaina != None:
            buvusi_kaina = buvusi_kaina.text.strip()
        else:
            buvusi_kaina = None
        duomenys['buvusiKaina'] = buvusi_kaina
        # print(buvusi_kaina)

        specifiacija_keys = []
        specifiacija_values = []
        try:
            specifiacija = bs_preke.find('div', {'class':'PRODUCT_SPEC'}).find_all('li', {'class':'spec-line'})
            for line in specifiacija:
                try:
                    spec_key = line.find('span', {'class':'left-column'}).text.lower()
                    # print(spec_key)
                    specifiacija_keys.append(spec_key)
                    spec_value = line.find('span', {'class':'right-column'}).text
                    # print(spec_value)
                    specifiacija_values.append(spec_value)
                except:
                    pass
                try:
                    spec_key = line.find('div', {'class':'left-column'}).text.lower()
                    # print(spec_key)
                    specifiacija_keys.append(spec_key)
                    spec_value = line.find('div', {'class':'right-column'}).text
                    # print(spec_value)
                    specifiacija_values.append(spec_value)
                except:
                    pass
        except:
            pass

        try:
            specifiacija_k = bs_preke.find('div', {'class':'PRODUCT_SPEC'}).find_all('td', {'class':'key'})
            for key in specifiacija_k:
                # print(key.text.strip())
                specifiacija_keys.append(key.text.strip().lower())
            specifiacija_v = bs_preke.find('div', {'class':'PRODUCT_SPEC'}).find_all('td', {'class':'value'})
            for val in specifiacija_v:
                # print(val.text.strip())
                specifiacija_values.append(val.text.strip())       
        except:
            pass
        
        
        # print(len(specifiacija_keys), specifiacija_keys)
        # print(len(specifiacija_values), specifiacija_values)

        spec_filtrai_keys = []
        spec_filtrai_values = []
        try:
            spec_filtai = bs_preke.find('div', {'class':'PRODUCT_SPEC_FILTERS'}).find_all('li', {'class':'spec-line'})
            for line in spec_filtai:
                spec_key = line.find('span', {'class':'left-column'}).text.strip().lower()
                # print(spec_key)
                spec_filtrai_keys.append(spec_key)
                spec_value = line.find('span', {'class':'right-column'}).text.strip()
                # print(spec_value)
                spec_filtrai_values.append(spec_value)
                
            # print(len(spec_filtrai_keys), spec_filtrai_keys)
            # print(len(spec_filtrai_values), spec_filtrai_values)
        except:
            pass
        
        for k, v in zip(spec_filtrai_keys, spec_filtrai_values):
            duomenys[k] = v
            
        for k, v in zip(specifiacija_keys, specifiacija_values):
            duomenys[k] = v
            
        cols_i_need = list(duomenys.keys())
        
        data = tuple(duomenys.values())
        
        cols_i_have = getColNamesList(table='SaldytuvaiVarle', dbname='VarlePigu.db')
        
        alterTableAddColumn(cols_i_need, cols_i_have, 'SaldytuvaiVarle', 'VarlePigu.db')
        
        writeMany(data, 'SaldytuvaiVarle', 'VarlePigu.db')
        print(f'Įrašytas įrašas Nr {counts}, puslapis {psl}')
        counts = counts +1
    
    print(f'Įrašytas puslapis {psl}')
    psl = psl +1
    # if psl < iki_kokio_psl:
    if psl <= pages_max_number:
        next_nuoroda = f'https://www.varle.lt/saldytuvai/?p={psl}'
        driver.get(next_nuoroda)
        time.sleep(3)
        print(f'kitas puslapis: {psl}')
    
driver.quit()
print('Baigta!!!')
# Out:
# 1 https://www.varle.lt/saldytuvai/saldytuvas-sharp-sj-ftb01itxse-eu--36822303.html
# Įrašytas įrašas Nr 1, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rr106d4cbe-85cm-juodas--37859978.html
# Įrašytas įrašas Nr 2, puslapis 1
# 1 https://www.varle.lt/saldytuvai/imontuojamasis-saldytuvas-bosch-kin86nse0-nofrost--28786311.html
# Įrašytas įrašas Nr 3, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgn36nwea-2-serija-baltos-spalvos--15912426.html
# Įrašytas įrašas Nr 4, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-haier-hle-172-de--31802747.html
# Įrašytas įrašas Nr 5, puslapis 1
# 1 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-liebherr-icnd-5103-pure-nofrost--35127654.html
# Įrašytas įrašas Nr 6, puslapis 1
# 1 https://www.varle.lt/saldytuvai/marshall-fridge-black-edition-32-92l-vidutines--17311967.html
# Įrašytas įrašas Nr 7, puslapis 1
# 1 https://www.varle.lt/saldytuvai/aeg-imontuojamas-saldytuvas-ske818d1ds-178-cm--31318904.html
# Įrašytas įrašas Nr 8, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-beko-rcha270k30xbn--24738533.html
# Įrašytas įrašas Nr 9, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgn36nlea-2-serija-nerudijancio--19199686.html
# Įrašytas įrašas Nr 10, puslapis 1
# 1 https://www.varle.lt/saldytuvai/bosch-bsh-fclg-giengen-serija-2-imontuojamasis-saldytuvas--35653463.html
# Įrašytas įrašas Nr 11, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-mini-baras-guzzanti-gz-44g--11749671.html
# Įrašytas įrašas Nr 12, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-rb492pw--30151495.html
# Įrašytas įrašas Nr 13, puslapis 1
# 1 https://www.varle.lt/saldytuvai/liebherr-saldytuvas-ire-5100--16581553.html
# Įrašytas įrašas Nr 14, puslapis 1
# 1 https://www.varle.lt/saldytuvai/samsung-saldytuvas-brb26705ewwef--15968513.html
# Įrašytas įrašas Nr 15, puslapis 1
# 1 https://www.varle.lt/saldytuvai/gorenje-saldytuvas-saldiklis-nrk620ca2xl4--33990406.html
# Įrašytas įrašas Nr 16, puslapis 1
# 1 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-whirlpool-sp40-812-eu-2--35817045.html
# Įrašytas įrašas Nr 17, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-severin-rkg-8928-retro-juodas-ekspozicine--34749171.html
# Įrašytas įrašas Nr 18, puslapis 1
# 1 https://www.varle.lt/saldytuvai/midea-saldytuvas-mdrd142fge01-energy-efficiency--39578266.html
# Įrašytas įrašas Nr 19, puslapis 1
# 1 https://www.varle.lt/saldytuvai/mpm-46-cj-01h-saldytuvas-pastatomi-balta-ekspozicine--40212555.html
# Įrašytas įrašas Nr 20, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgn33nleb-ekspozicine-preke--40739823.html
# Įrašytas įrašas Nr 21, puslapis 1
# 1 https://www.varle.lt/saldytuvai/gorenje-saldytuvas-nrk6202aw4-energy-efficiency--18802196.html
# Įrašytas įrašas Nr 22, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-nrk6182ps4--16731705.html
# Įrašytas įrašas Nr 23, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-aeg-scb819e8ts--19159003.html
# Įrašytas įrašas Nr 24, puslapis 1
# 1 https://www.varle.lt/saldytuvai/built-in-saldytuvas-whirlpool-194cm-nf--18106310.html
# Įrašytas įrašas Nr 25, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-beko-b3rcna404hw--22054518.html
# Įrašytas įrašas Nr 26, puslapis 1
# 1 https://www.varle.lt/saldytuvai/lg-saldytuvas-gbv3200dpy-energy-efficiency-class--31030911.html
# Įrašytas įrašas Nr 27, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-gotie-glz-85b--30323188.html
# Įrašytas įrašas Nr 28, puslapis 1
# 1 https://www.varle.lt/saldytuvai/polar-saldytuvas-saldiklis-pob602ek-netnet--34472245.html
# Įrašytas įrašas Nr 29, puslapis 1
# 1 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-amica-uc1624e-135l-balta--35619265.html
# Įrašytas įrašas Nr 30, puslapis 1
# 1 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-liebherr-irbd-5151--16451714.html
# Įrašytas įrašas Nr 31, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-gastronominis-saldymo-stalas-4-stalciai--40272162.html
# Įrašytas įrašas Nr 32, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-royal-catering-saldymo-vitrina-su-led-apsvietimu--40149283.html
# Įrašytas įrašas Nr 33, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rb440n4gbd--29871329.html
# Įrašytas įrašas Nr 34, puslapis 1
# 1 https://www.varle.lt/saldytuvai/lg-saldytuvas-gbv7180cpy-energy-efficiency-class--32152423.html
# Įrašytas įrašas Nr 35, puslapis 1
# 1 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-rb493pw-baltas--25438488.html
# Įrašytas įrašas Nr 36, puslapis 1
# 1 https://www.varle.lt/saldytuvai/built-in-saldytuvas-whirlpool-70cm--28243109.html
# Įrašytas įrašas Nr 37, puslapis 1
# 1 https://www.varle.lt/saldytuvai/goddess-single-door-saldytuvas-with-saldiklis-compartment--39621724.html
# Įrašytas įrašas Nr 38, puslapis 1
# Įrašytas puslapis 1
# kitas puslapis: 2
# 2 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-liebherr-icbdi-5182--41054632.html
# Įrašytas įrašas Nr 39, puslapis 2
# 2 https://www.varle.lt/saldytuvai/saldytuvas-midea-mdrb521mgb02--34874779.html
# Įrašytas įrašas Nr 40, puslapis 2
# 2 https://www.varle.lt/dviduriai-saldytuvai/samsung-rs64dg53m3b1eo--36082934.html
# Įrašytas įrašas Nr 41, puslapis 2
# 2 https://www.varle.lt/saldytuvai/saldytuvas-royal-catering-saldymo-vitrina-su-plieniniu--40149414.html
# Įrašytas įrašas Nr 42, puslapis 2
# 2 https://www.varle.lt/saldytuvai/saldytuvas-royal-catering-saldymo-vitrina-su-stikline--40309841.html
# Įrašytas įrašas Nr 43, puslapis 2
# Įrašytas įrašas Nr 65, puslapis 2
# 2 https://www.varle.lt/saldytuvai/sbs-saldytuvas-hisense-rs677n4bwe--38245547.html
# Įrašytas įrašas Nr 66, puslapis 2
# 2 https://www.varle.lt/saldytuvai/saldytuvas-electrolux-e6mnte18s--41038946.html
# Įrašytas įrašas Nr 67, puslapis 2
# 2 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb38c604dsa--31509249.html
# Įrašytas įrašas Nr 68, puslapis 2
# 2 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rf65dg9h0eb1--35628948.html
# Įrašytas įrašas Nr 69, puslapis 2
# 2 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb34c775cb1--31509242.html
# Įrašytas įrašas Nr 70, puslapis 2
# 2 https://www.varle.lt/saldytuvai/haier-saldytuvas-hdpw5620dnpd-406l-juodas--38766282.html
# Įrašytas įrašas Nr 71, puslapis 2
# 2 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rt267d4awe--38266363.html
# Įrašytas įrašas Nr 72, puslapis 2
# 2 https://www.varle.lt/saldytuvai/whirlpool-w4d7-bc21-free-standing-fridge-saldiklis--39859864.html
# Įrašytas įrašas Nr 73, puslapis 2
# 2 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb34c635ebn--32748161.html
# Įrašytas įrašas Nr 74, puslapis 2
# 2 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rt267d4ade--35680030.html
# Įrašytas įrašas Nr 75, puslapis 2
# 2 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-beko-bcsa285k4sn-177cm--25607341.html
# Įrašytas įrašas Nr 76, puslapis 2
# Įrašytas puslapis 2
# kitas puslapis: 3
# 3 https://www.varle.lt/saldytuvai/baltos-spalvos-186cm-aukscio-saldytuvas-be-saldymo--24782748.html
# Įrašytas įrašas Nr 77, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-beko-bcna306e4sn--14684883.html
# Įrašytas įrašas Nr 78, puslapis 3
# 3 https://www.varle.lt/saldytuvai/midea-saldytuvas-mdrd142fge01-energy-efficiency--39118197.html
# Įrašytas įrašas Nr 79, puslapis 3
# 3 https://www.varle.lt/saldytuvai/midea-saldytuvas-mdrd125fge01-energy-efficiency--36744577.html
# Įrašytas įrašas Nr 80, puslapis 3
# 3 https://www.varle.lt/saldytuvai/samsung-saldytuvas-brb30715ewwef--16211057.html
# Įrašytas įrašas Nr 81, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-beko-ts190340n--31004868.html
# Įrašytas įrašas Nr 82, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-sharp-sj-fbb02dtxwe-eu--38404389.html
# Įrašytas įrašas Nr 83, puslapis 3
# 3 https://www.varle.lt/saldytuvai/beko-saldytuvas-rcsa270k40sn-energy-class-e-height--29869291.html
# Įrašytas įrašas Nr 84, puslapis 3
# 3 https://www.varle.lt/saldytuvai/bosch-kin96vfd0-serija-4-imontuojamasis-saldytuvas-saldiklis--29932112.html
# Įrašytas įrašas Nr 85, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-beko-b3rcna364hw-netnet--20930776.html
# Įrašytas įrašas Nr 86, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-sharp-sjfbb04dtxleeu--36352485.html
# Įrašytas įrašas Nr 87, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-rf212epw4--32586564.html
# Įrašytas įrašas Nr 88, puslapis 3
# 3 https://www.varle.lt/saldytuvai/sharp-saldytuvas-saldiklis-sj-fbb04dtxwe--36352486.html
# Įrašytas įrašas Nr 89, puslapis 3
# 3 https://www.varle.lt/saldytuvai/first-austria-mini-baras-saldytuvas-first-fa-5172--24054857.html
# Įrašytas įrašas Nr 90, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-indesit-si6-1-s--18747470.html
# Įrašytas įrašas Nr 91, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgn39aibt-6-serija-nerudijancio--18422347.html
# Įrašytas įrašas Nr 92, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-rk4182ps4--24143431.html
# Įrašytas įrašas Nr 93, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-electrolux-lfb3ae82r--31817061.html
# Įrašytas įrašas Nr 94, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-saldiklis-hisense-rb291d4cde--35795820.html
# Įrašytas įrašas Nr 95, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-nrk418ecs4--31076934.html
# Įrašytas įrašas Nr 96, puslapis 3
# 3 https://www.varle.lt/saldytuvai/candy-saldytuvas-cohs-45eb-energy-efficiency-class--35705553.html
# Įrašytas įrašas Nr 97, puslapis 3
# 3 https://www.varle.lt/saldytuvai/whirlpool-saldytuvas-w5-821e-w-2-1889-cm-e-energijos--14974264.html
# Įrašytas įrašas Nr 98, puslapis 3
# 3 https://www.varle.lt/saldytuvai/amica-saldytuvas-saldiklis-bk26654e--34218480.html
# Įrašytas įrašas Nr 99, puslapis 3
# 3 https://www.varle.lt/saldytuvai/beko-saldytuvas-rcsa270k40wn-energy-class-e-height--29768839.html
# Įrašytas įrašas Nr 100, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-saldiklis-bosch-kgn33nleb-176cm-nofrost--14203307.html
# Įrašytas įrašas Nr 101, puslapis 3
# 3 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-whirlpool-art-9811asf--9530583.html
# Įrašytas įrašas Nr 102, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-su-saldikliu-bosch-kgn33nweb-176cm-no--18802183.html
# Įrašytas įrašas Nr 103, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-indesit-li8-s2e-k--15313045.html
# Įrašytas įrašas Nr 104, puslapis 3
# 3 https://www.varle.lt/saldytuvai/beko-tse1284n-saldytuvas-saldiklis-pastatomi-balta--18774359.html
# Įrašytas įrašas Nr 105, puslapis 3
# 3 https://www.varle.lt/saldytuvai/bosch-4-serijos-imontuojamas-saldytuvas-saldiklis--16693624.html
# Įrašytas įrašas Nr 106, puslapis 3
# 3 https://www.varle.lt/saldytuvai/lg-saldytuvas-gbb72swvgn-energy-efficiency-class--16876389.html
# Įrašytas įrašas Nr 107, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-candy-cio-225ne--12927937.html
# Įrašytas įrašas Nr 108, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-beko-rdsa240k40sn--30990714.html
# Įrašytas įrašas Nr 109, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb33j3315saef--7382652.html
# Įrašytas įrašas Nr 110, puslapis 3
# 3 https://www.varle.lt/saldytuvai/candy-saldytuvas-cot1s45esh-energy-efficiency--20194280.html
# Įrašytas įrašas Nr 111, puslapis 3
# 3 https://www.varle.lt/saldytuvai/saldytuvas-vox-kg2500e--38772968.html
# Įrašytas įrašas Nr 112, puslapis 3
# 3 https://www.varle.lt/saldytuvai/candy-saldainiai-saldytuvas-cohs-38e36w-energijos--35521763.html
# Įrašytas įrašas Nr 113, puslapis 3
# 3 https://www.varle.lt/saldytuvai/bosch-kgn362idf-serie-4-laisvai-statomas-saldytuvas-saldiklis--19432167.html
# Įrašytas įrašas Nr 114, puslapis 3
# Įrašytas puslapis 3
# kitas puslapis: 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-amica-retro-fk29653raa-550mm-x-1810mm--10054507.html
# Įrašytas įrašas Nr 115, puslapis 4
# 4 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-samsung-brb30615eww--19350117.html
# Įrašytas įrašas Nr 116, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-severin-juodas--24919539.html
# Įrašytas įrašas Nr 117, puslapis 4
# 4 https://www.varle.lt/saldytuvai/electrolux-saldytuvas-enc8md19s--24782717.html
# Įrašytas įrašas Nr 118, puslapis 4
# 4 https://www.varle.lt/saldytuvai/candy-saldytuvas-ccg1l314ew-energy-efficiency--35883989.html
# Įrašytas įrašas Nr 119, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-electrolux-lrb3ae12s--31254186.html
# Įrašytas įrašas Nr 120, puslapis 4
# 4 https://www.varle.lt/saldytuvai/candy-saldytuvas-cohs-45ew-energy-efficiency-class--39903549.html
# Įrašytas įrašas Nr 121, puslapis 4
# 4 https://www.varle.lt/saldytuvai/candy-saldytuvas-cncq2t518ew-energy-efficiency--38844473.html
# Įrašytas įrašas Nr 122, puslapis 4
# 4 https://www.varle.lt/saldytuvai/liebherr-cue-2831-pure-saldytuvas-saldiklis--32592567.html
# Įrašytas įrašas Nr 123, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-nrk418ecw4--31059186.html
# Įrašytas įrašas Nr 124, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-mpm-90-cj-27--38277846.html
# Įrašytas įrašas Nr 125, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-hisense-143cm--35570909.html
# Įrašytas įrašas Nr 126, puslapis 4
# 4 https://www.varle.lt/saldytuvai/candy-saldytuvas-chasd4351ewc-energy-efficiency--30651452.html
# Įrašytas įrašas Nr 127, puslapis 4
# 4 https://www.varle.lt/saldytuvai/luxpol-lmb-46c-po-stalinis-saldytuvas--36662406.html
# Įrašytas įrašas Nr 128, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb38c675eb1--33921319.html
# Įrašytas įrašas Nr 129, puslapis 4
# 4 https://www.varle.lt/saldytuvai/beko-saldytuvas-rdsa240k40wn-energy-class-e-height--31048809.html
# Įrašytas įrašas Nr 130, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-mini-baras-guzzanti-gz-44--9973290.html
# Įrašytas įrašas Nr 131, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-beko-bcna275e4sn--16856781.html
# Įrašytas įrašas Nr 132, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-beko-b3rcna364hxb--21152330.html
# Įrašytas įrašas Nr 133, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-samsung-brb26715ewwef--15808205.html
# Įrašytas įrašas Nr 134, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-whirlpool-w5-821e-ox--14787866.html
# Įrašytas įrašas Nr 135, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-samsung-brb30715dww--16020086.html
# Įrašytas įrašas Nr 136, puslapis 4
# 4 https://www.varle.lt/saldytuvai/whirlpool-saldytuvas-w5-721e-ox-2-176-cm-energy--14863051.html
# Įrašytas įrašas Nr 137, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgv33vwea-serie-4-176cm-baltas--18802223.html
# Įrašytas įrašas Nr 138, puslapis 4
# 4 https://www.varle.lt/saldytuvai/bosch-bsh-fcli-cerkezkoy-serija-6-laisvai-statomas--19477955.html
# Įrašytas įrašas Nr 139, puslapis 4
# 4 https://www.varle.lt/saldytuvai/1col-beko-saldytuvas-saldiklis-beko-beyond-b3rcna364hxbr--20788565.html
# Įrašytas įrašas Nr 140, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-beko-bu1154hcn--31822051.html
# Įrašytas įrašas Nr 141, puslapis 4
# 4 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-bosch-kiv86vfe1-4-serija--15801652.html
# Įrašytas įrašas Nr 142, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-nrk6202cli--15254324.html
# Įrašytas įrašas Nr 143, puslapis 4
# 4 https://www.varle.lt/saldytuvai/electrolux-saldytuvas-lns5le18s--24782718.html
# Įrašytas įrašas Nr 144, puslapis 4
# 4 https://www.varle.lt/saldytuvai/mpm-mpm-182-kb-38w-saldytuvas--18736728.html
# Įrašytas įrašas Nr 145, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-r619ees5--22055069.html
# Įrašytas įrašas Nr 146, puslapis 4
# 4 https://www.varle.lt/saldytuvai/beko-saldytuvas-rcsa300k40wn-energy-class-e-height--30554268.html
# Įrašytas įrašas Nr 147, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-bosch-kil22nse0--21569269.html
# Įrašytas įrašas Nr 148, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-beko-bssa210k4sn--30919747.html
# Įrašytas įrašas Nr 149, puslapis 4
# 4 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rb343d4cwe-180cm-nofrost--35274158.html
# Įrašytas įrašas Nr 150, puslapis 4
# 4 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-su-saldikliu-aeg-sce819e5ts--21799552.html
# Įrašytas įrašas Nr 151, puslapis 4
# 4 https://www.varle.lt/saldytuvai/lg-saldytuvas-gbb72pzemn-energy-efficiency-class--14712181.html
# Įrašytas įrašas Nr 152, puslapis 4
# Įrašytas puslapis 4
# kitas puslapis: 5
# 5 https://www.varle.lt/saldytuvai/bosch-kgn497ict-serie-4-laisvai-statomas-saldytuvas-saldiklis--19472276.html
# Įrašytas įrašas Nr 153, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-snaige-c29sm-t1002e1--31763208.html
# Įrašytas įrašas Nr 154, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-r619eew5--22055055.html
# Įrašytas įrašas Nr 155, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-saldiklis-bosch-kgv58vleas--14947861.html
# Įrašytas įrašas Nr 156, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-electrolux-lrb3de18s--16581595.html
# Įrašytas įrašas Nr 157, puslapis 5
# 5 https://www.varle.lt/saldytuvai/beko-saldytuvas-rcsa240k40sn-energy-class-e-height--30110203.html
# Įrašytas įrašas Nr 158, puslapis 5
# 5 https://www.varle.lt/saldytuvai/bosch-serija-6-imontuojamasis-saldytuvas-1775-x--30258411.html
# Įrašytas įrašas Nr 159, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-mpm-46-cj-02e--31745037.html
# Įrašytas įrašas Nr 160, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb38c7b6bs9ef--22510760.html
# Įrašytas įrašas Nr 161, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgn367wct-4-serija-baltos-spalvos--20795791.html
# Įrašytas įrašas Nr 162, puslapis 5
# 5 https://www.varle.lt/saldytuvai/electrolux-saldytuvas-lnd5fe18s--24782719.html
# Įrašytas įrašas Nr 163, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-beko-rdso206k40wn--36545884.html
# Įrašytas įrašas Nr 164, puslapis 5
# 5 https://www.varle.lt/saldytuvai/145-cm-imontuojamas-saldytuvas-electrolux-lnt3le14s--36069211.html
# Įrašytas įrašas Nr 165, puslapis 5
# 5 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-liebherr-icse-5122--16213227.html
# Įrašytas įrašas Nr 166, puslapis 5
# 5 https://www.varle.lt/saldytuvai/beko-saldytuvas-rcsa300k40sn-energy-class-e-height--30381021.html
# Įrašytas įrašas Nr 167, puslapis 5
# 5 https://www.varle.lt/saldytuvai/bosch-bsh-fclg-giengen-serija-4-imontuojamasis-saldytuvas-saldiklis--35653465.html
# Įrašytas įrašas Nr 168, puslapis 5
# 5 https://www.varle.lt/saldytuvai/indesit-si6-2-w-saldytuvas--35654082.html
# Įrašytas įrašas Nr 169, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-samsung-brb30603eww--16020078.html
# Įrašytas įrašas Nr 170, puslapis 5
# 5 https://www.varle.lt/saldytuvai/bsh-fclg-giengen-serija-2-imontuojamasis-saldytuvas-saldiklis--29952880.html
# Įrašytas įrašas Nr 171, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-liebherr-cnd-5223-plus-nofrost-saldytuvo--22520244.html
# Įrašytas įrašas Nr 172, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-aeg-osc5d181es--37351246.html
# Įrašytas įrašas Nr 173, puslapis 5
# 5 https://www.varle.lt/saldytuvai/ravanson-lkk-210rc-saldytuvas--18696137.html
# Įrašytas įrašas Nr 174, puslapis 5
# 5 https://www.varle.lt/saldytuvai/bosch-saldytuvas-kiv86nse0-series-2-energy-efficiency--30165790.html
# Įrašytas įrašas Nr 175, puslapis 5
# 5 https://www.varle.lt/saldytuvai/bosch-bsh-fcli-cerkezkoy-serija-4-laisvai-statomas--22032165.html
# Įrašytas įrašas Nr 176, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-rf4142pw4--36391759.html
# Įrašytas įrašas Nr 177, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-aeg-electrolux-enp7td75s--26309027.html
# Įrašytas įrašas Nr 178, puslapis 5
# 5 https://www.varle.lt/saldytuvai/candy-saldytuvas-cncq2t620ew-energy-efficiency--36665238.html
# Įrašytas įrašas Nr 179, puslapis 5
# 5 https://www.varle.lt/saldytuvai/ravanson-saldytuvas-saldiklis-lkk-50e--35900151.html
# Įrašytas įrašas Nr 180, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-amica-retro-kgc15630r-550mm-x-1440mm-x--6635591.html
# Įrašytas įrašas Nr 181, puslapis 5
# 5 https://www.varle.lt/saldytuvai/liebherr-cte-2131-saldytuvas-su-saldikliu-virsuje--37101529.html
# Įrašytas įrašas Nr 182, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-bosch-ksv36nwep-2-serija-baltos-spalvos--16581552.html
# Įrašytas įrašas Nr 183, puslapis 5
# 5 https://www.varle.lt/saldytuvai/scandomestic-coca-cola-fiftycube-saldytuvas--27256697.html
# Įrašytas įrašas Nr 184, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-scancool-mini-baras-su-stiklinemis-durelemis--34068948.html
# Įrašytas įrašas Nr 185, puslapis 5
# 5 https://www.varle.lt/saldytuvai/saldytuvas-beko-rcna305k40wn--36872255.html
# Įrašytas įrašas Nr 186, puslapis 5
# 6 https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgn392ldf-ekspozicine-preke--41083069.html
# Įrašytas įrašas Nr 228, puslapis 6
# Įrašytas puslapis 6
# kitas puslapis: 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-nrk619epxl4-ekspozicine-preke--41083842.html
# Įrašytas įrašas Nr 229, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-siemens-bosch-q88npkx060--24892035.html
# Įrašytas įrašas Nr 230, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-mini-baras-guzzanti-gz-28-juodas--6927741.html
# Įrašytas įrašas Nr 231, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-mpm-mpm-46-cj-01h-baltos-spalvos--9505664.html
# Įrašytas įrašas Nr 232, puslapis 7
# 7 https://www.varle.lt/saldytuvai/im1884-cm-saldytuvas-su-saldikliu-electrolux-ens6te19s--14523465.html
# Įrašytas įrašas Nr 233, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-bosch-kge36awca--14565210.html
# Įrašytas įrašas Nr 234, puslapis 7
# 7 https://www.varle.lt/saldytuvai/whirlpool-saldytuvas-w5-721e-w-2-176-cm-e-energine--14829059.html
# Įrašytas įrašas Nr 235, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-bosch-kge36aica-sidabrines-spalvos--23047050.html
# Įrašytas įrašas Nr 236, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-snaige-cd350-1003-uzrakt--1133997.html
# Įrašytas įrašas Nr 237, puslapis 7
# 7 https://www.varle.lt/saldytuvai/whirlpool-saldytuvas-saldiklis-art-6502--14994673.html
# Įrašytas įrašas Nr 238, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-bosch-kge39aica-serie-6-201-x-60-cm--18802413.html
# Įrašytas įrašas Nr 239, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-beko-tse1234fsn--14170360.html
# Įrašytas įrašas Nr 240, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-saldiklis-samsung-brb30703ewwef--17669445.html
# Įrašytas įrašas Nr 241, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-rf4141ps4--14494042.html
# Įrašytas įrašas Nr 242, puslapis 7
# 7 https://www.varle.lt/saldytuvai/imontuojamasis-saldytuvas-bosch-kin86vse0-serija-4--17754402.html
# Įrašytas įrašas Nr 243, puslapis 7
# 7 https://www.varle.lt/saldytuvai/gorenje-saldytuvas-rf4141pw4--14392271.html
# Įrašytas įrašas Nr 244, puslapis 7
# 7 https://www.varle.lt/saldytuvai/gorenje-saldytuvas-nrk6192axl4-energy-efficiency--18802222.html
# Įrašytas įrašas Nr 245, puslapis 7
# 7 https://www.varle.lt/saldytuvai/lg-gbp31swlzn-saldytuvas-saldiklis-pastatomi-balta--16892576.html
# Įrašytas įrašas Nr 246, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-nrk6192abk4--14523172.html
# Įrašytas įrašas Nr 247, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgv36vbeas-4-serija-juodos-spalvos--14716407.html
# Įrašytas įrašas Nr 248, puslapis 7
# 7 https://www.varle.lt/saldytuvai/bosch-kgn392ldf-serie-4-laisvai-statomas-saldytuvas-saldiklis--19223499.html
# Įrašytas įrašas Nr 249, puslapis 7
# 7 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-su-saldikliu-188cm-electrolux--19471359.html
# Įrašytas įrašas Nr 250, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-candy-cctos-542xhn--15203046.html
# Įrašytas įrašas Nr 251, puslapis 7
# 7 https://www.varle.lt/saldytuvai/lg-saldytuvas-gbb62pzfgn-energijos-efektyvumo-klase--17301298.html
# Įrašytas įrašas Nr 252, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-snaige-rf27sm-p0002e--15714495.html
# Įrašytas įrašas Nr 253, puslapis 7
# 7 https://www.varle.lt/saldytuvai/bosch-bsh-fcli-cerkezkoy-serija-4-laisvai-statomas--14822045.html
# Įrašytas įrašas Nr 254, puslapis 7
# 7 https://www.varle.lt/saldytuvai/gorenje-saldytuvas-rb491pw--16498941.html
# Įrašytas įrašas Nr 255, puslapis 7
# 7 https://www.varle.lt/saldytuvai/lg-saldytuvas-gbb61pzjmn-energy-efficiency-class--14479967.html
# Įrašytas įrašas Nr 256, puslapis 7
# 7 https://www.varle.lt/saldytuvai/candy-saldytuvas-saldiklis-podblatowa-cru164-nen--15668691.html
# Įrašytas įrašas Nr 257, puslapis 7
# 7 https://www.varle.lt/saldytuvai/samsung-saldytuvas-brb26715dwwef--16918924.html
# Įrašytas įrašas Nr 258, puslapis 7
# 7 https://www.varle.lt/saldytuvai/9000-serijos-177-cm-aukscio-montuojamas-saldytuvas--15415468.html
# Įrašytas įrašas Nr 259, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-snaige-cd290-1008-02snj0--9925787.html
# Įrašytas įrašas Nr 260, puslapis 7
# 7 https://www.varle.lt/saldytuvai/bsh-fcli-cerkezkoy-serija-6-laisvai-statomas-saldytuvas-saldiklis--16642110.html
# Įrašytas įrašas Nr 261, puslapis 7
# 7 https://www.varle.lt/saldytuvai/laisvai-statomas-saldytuvas-saldiklis-su-saldiklio--14470129.html
# Įrašytas įrašas Nr 262, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-bk-147saw-berk--11681236.html
# Įrašytas įrašas Nr 263, puslapis 7
# 7 https://www.varle.lt/saldytuvai/bosch-kge49aica-serija-6-laisvai-statomas-saldytuvas-saldiklis--14680876.html
# Įrašytas įrašas Nr 264, puslapis 7
# 7 https://www.varle.lt/saldytuvai/saldytuvas-guzzanti-gz-102--9403686.html
# Įrašytas įrašas Nr 265, puslapis 7
# 7 https://www.varle.lt/saldytuvai/snaige-saldytuvas-fr24sm-prr50e--15255288.html
# Įrašytas įrašas Nr 266, puslapis 7
# Įrašytas puslapis 7
# kitas puslapis: 8
# 8 https://www.varle.lt/saldytuvai/lg-saldytuvas-gbb72swdmn-energy-efficiency-class--14485794.html
# Įrašytas įrašas Nr 267, puslapis 8
# 8 https://www.varle.lt/saldytuvai/lg-saldytuvas-gbb61swjmn-energy-efficiency-class--14485793.html
# Įrašytas įrašas Nr 268, puslapis 8
# 8 https://www.varle.lt/saldytuvai/whirlpool-saldytuvas-saldiklis-art66122--14896003.html
# Įrašytas įrašas Nr 269, puslapis 8
# 8 https://www.varle.lt/saldytuvai/saldytuvas-whirlpool-sw8-am2y-wr-2--14846355.html
# Įrašytas įrašas Nr 270, puslapis 8
# 8 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-whirlpool-art-66102--15637298.html
# Įrašytas įrašas Nr 271, puslapis 8
# 8 https://www.varle.lt/saldytuvai/saldytuvas-rf34sm-s0002e0--23119127.html
# Įrašytas įrašas Nr 272, puslapis 8
# 8 https://www.varle.lt/saldytuvai/201-cm-aukscio-ner-plieno-saldytuvas-su-saldikliu--15904297.html
# Įrašytas įrašas Nr 273, puslapis 8
# 8 https://www.varle.lt/saldytuvai/saldytuvas-lg-gbb71pzdmn--18799860.html
# Įrašytas įrašas Nr 274, puslapis 8
# 8 https://www.varle.lt/saldytuvai/snaige-saldytuvas-fr24sm-prc30e--15033215.html
# Įrašytas įrašas Nr 275, puslapis 8
# 8 https://www.varle.lt/saldytuvai/saldytuvas-samsung-brb26605dww--17750094.html
# Įrašytas įrašas Nr 276, puslapis 8
# 8 https://www.varle.lt/saldytuvai/1588-cm-aukscio-saldytuvas-saldiklis-indesit-li6--32843185.html
# Įrašytas įrašas Nr 277, puslapis 8
# 8 https://www.varle.lt/saldytuvai/saldytuvas-snaige-rf35sm-s0002e0--34816321.html
# Įrašytas įrašas Nr 278, puslapis 8
# 8 https://www.varle.lt/saldytuvai/bsh-fcli-cerkezkoy-serija-4-laisvai-statomas-saldytuvas-saldiklis--20856328.html
# Įrašytas įrašas Nr 279, puslapis 8
# 8 https://www.varle.lt/saldytuvai/lg-saldytuvas-gbb72pzdmn-energy-efficiency-class--18802141.html
# Įrašytas įrašas Nr 280, puslapis 8
# 8 https://www.varle.lt/saldytuvai/beko-saldytuvas-rcsa240k40wn-energy-class-e-height--30471866.html
# Įrašytas įrašas Nr 281, puslapis 8
# 8 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-r619eaxl6--22125290.html
# Įrašytas įrašas Nr 282, puslapis 8
# 8 https://www.varle.lt/saldytuvai/lg-saldytuvas-gbb72mcugn-energy-efficiency-class-d--17635594.html
# Įrašytas įrašas Nr 283, puslapis 8
# 8 https://www.varle.lt/saldytuvai/sharp-sjba10dmxwfeu-saldytuvas--21121855.html
# Įrašytas įrašas Nr 284, puslapis 8
# 8 https://www.varle.lt/saldytuvai/saldytuvas-candy-cil-220-ne--16945578.html
# Įrašytas įrašas Nr 285, puslapis 8
# 8 https://www.varle.lt/saldytuvai/liebherr-icbne-5123-built-in-saldytuvas-saldiklis--15904277.html
# Įrašytas įrašas Nr 286, puslapis 8
# 8 https://www.varle.lt/saldytuvai/saldytuvas-saldiklis-combination-ravanson-lkk-90es--34798861.html
# Įrašytas įrašas Nr 287, puslapis 8
# 8 https://www.varle.lt/saldytuvai/bosch-kgv33vlea-serie-4-laisvai-statomas-saldytuvas-saldiklis--18802157.html
# Įrašytas įrašas Nr 288, puslapis 8
# 8 https://www.varle.lt/saldytuvai/candy-pastatomas-2-duru-saldytuvas-su-low-frost--36333001.html
# Įrašytas įrašas Nr 289, puslapis 8
# 8 https://www.varle.lt/saldytuvai/saldytuvas-bosch-203cm-nf--19238631.html
# Įrašytas įrašas Nr 290, puslapis 8
# 8 https://www.varle.lt/saldytuvai/electrolux-saldytuvas-lxb1se11w0--14899910.html
# Įrašytas įrašas Nr 291, puslapis 8
# 8 https://www.varle.lt/saldytuvai/beko-indesit-saldytuvas-li6-s2e-x-energy-efficiency--36534188.html
# Įrašytas įrašas Nr 292, puslapis 8
# 8 https://www.varle.lt/saldytuvai/bosch-serie-6-saldytuvas-kis87afe0-energy-efficiency--14611921.html
# Įrašytas įrašas Nr 293, puslapis 8
# 8 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-saldiklis-liebherr-icnsf-5103--15630146.html
# Įrašytas įrašas Nr 294, puslapis 8
# 8 https://www.varle.lt/saldytuvai/first-austria-mini-baras-saldytuvas-first-fa-5172-2--24055025.html
# Įrašytas įrašas Nr 295, puslapis 8
# 8 https://www.varle.lt/saldytuvai/bosch-bsh-fclg-giengen-serija-4-imontuojamasis-saldytuvas-saldiklis--16581825.html
# Įrašytas įrašas Nr 296, puslapis 8
# 8 https://www.varle.lt/saldytuvai/saldytuvas-whirlpool-sp40-801-eu-1--15282612.html
# Įrašytas įrašas Nr 297, puslapis 8
# 8 https://www.varle.lt/saldytuvai/saldytuvas-electrolux-lfb3ae12s--31805616.html
# Įrašytas įrašas Nr 298, puslapis 8
# 8 https://www.varle.lt/saldytuvai/bosch-kgn362ldf-serie-4-laisvai-statomas-saldytuvas-saldiklis--19350137.html
# Įrašytas įrašas Nr 299, puslapis 8
# 8 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-samsung-brb30705dww--16527704.html
# Įrašytas įrašas Nr 300, puslapis 8
# 8 https://www.varle.lt/saldytuvai/saldytuvas-berk-brd-1455-w--30260936.html
# Įrašytas įrašas Nr 301, puslapis 8
# 8 https://www.varle.lt/saldytuvai/saldytuvas-snaige-fr24sm-prdo0e--18384944.html
# Įrašytas įrašas Nr 302, puslapis 8
# 8 https://www.varle.lt/saldytuvai/saldytuvas-su-virsutiniu-saldikliu-mpm-216-cf-26-inox--30552153.html
# Įrašytas įrašas Nr 303, puslapis 8
# 8 https://www.varle.lt/saldytuvai/indesit-li7-sn1e-x-saldytuvas-energy-efficiency--16211017.html
# Įrašytas įrašas Nr 304, puslapis 8
# Įrašytas puslapis 8
# kitas puslapis: 9
# 9 https://www.varle.lt/saldytuvai/saldytuvas-liebherr-irbe-5120-plus--15913618.html
# Įrašytas įrašas Nr 305, puslapis 9
# 9 https://www.varle.lt/saldytuvai/saldytuvas-ravanson-lkk-210rb-545mm-x-1470mm-x-585--18695610.html
# Įrašytas įrašas Nr 306, puslapis 9
# Įrašytas įrašas Nr 347, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-electrolux-ens8te19s--20805724.html
# Įrašytas įrašas Nr 348, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-r619eaw6--22054913.html
# Įrašytas įrašas Nr 349, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-whirlpool-w7x-83a-ox-1--19134092.html
# Įrašytas įrašas Nr 350, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb38c6b3es9ef--31393828.html
# Įrašytas įrašas Nr 351, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-arktic-saldymo-vitrina-su-stiklu-3-lentynos--35617286.html
# Įrašytas įrašas Nr 352, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgn392wdf-4-serija-baltos-spalvos--29893796.html
# Įrašytas įrašas Nr 353, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-liebherr-ice-5103--17443260.html
# Įrašytas įrašas Nr 354, puslapis 10
# 10 https://www.varle.lt/saldytuvai/combined-saldytuvas-saldiklis-mpm-182-kb-39-juodas--18735340.html
# Įrašytas įrašas Nr 355, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-bosch-ksv36aidp-6-serija-nerudijancio--15040444.html
# Įrašytas įrašas Nr 356, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-nrk6192as4--16731623.html
# Įrašytas įrašas Nr 357, puslapis 10
# 10 https://www.varle.lt/saldytuvai/gorenje-saldytuvas-saldiklis-su-nrk6202ebxl4--21387265.html
# Įrašytas įrašas Nr 358, puslapis 10
# 10 https://www.varle.lt/saldytuvai/bosch-kgn367ict-serie-4-laisvai-statomas-saldytuvas-saldiklis--21208438.html
# Įrašytas įrašas Nr 359, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-whirlpool-art-6510a-sf-fridge-saldiklis--10971815.html
# Įrašytas įrašas Nr 360, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-severin-gb-8880--24177335.html
# Įrašytas įrašas Nr 361, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-gotie-glz-85i--30323189.html
# Įrašytas įrašas Nr 362, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-liebherr-icbnsd-5123--37833452.html
# Įrašytas įrašas Nr 363, puslapis 10
# 10 https://www.varle.lt/saldytuvai/aeg-saldytuvas-ske818e1dc--15475360.html
# Įrašytas įrašas Nr 364, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-beko-bcne400e50shn--22853280.html
# Įrašytas įrašas Nr 365, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-whirlpool-whc20-t321--16044412.html
# Įrašytas įrašas Nr 366, puslapis 10
# 10 https://www.varle.lt/saldytuvai/liebherr-cnd-5203-pure-nofrost-saldytuvas-saldiklis--19550645.html
# Įrašytas įrašas Nr 367, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-liebherr-ire-4100-pure--15716599.html
# Įrašytas įrašas Nr 368, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-bosch-bo010382-ksv36aiep-6-serija-nerudijancio--14789468.html
# Įrašytas įrašas Nr 369, puslapis 10
# 10 https://www.varle.lt/saldytuvai/mpm-mpm-182-kb-33aa-saldytuvas--16313654.html
# Įrašytas įrašas Nr 370, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-bosch-ksv36awep-6-serija-baltos-spalvos--14986960.html
# Įrašytas įrašas Nr 371, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-mini-baras-guzzanti-gz-06b1--34673655.html
# Įrašytas įrašas Nr 372, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-nrk619eabxl4--18799950.html
# Įrašytas įrašas Nr 373, puslapis 10
# 10 https://www.varle.lt/saldytuvai/liebherr-ctele-2931-saldytuvas-su-saldikliu-virsuje--33547151.html
# Įrašytas įrašas Nr 374, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-nrk620eabxl4--17445445.html
# Įrašytas įrašas Nr 375, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-icnd-5123--22053562.html
# Įrašytas įrašas Nr 376, puslapis 10
# 10 https://www.varle.lt/saldytuvai/178-cm-imontuojamas-saldytuvas-su-saldikliu-electrolux--29134110.html
# Įrašytas įrašas Nr 377, puslapis 10
# 10 https://www.varle.lt/saldytuvai/bosch-kgn362wdf-saldytuvas-saldiklis--18993790.html
# Įrašytas įrašas Nr 378, puslapis 10
# 10 https://www.varle.lt/saldytuvai/saldytuvas-frigoriacutefico-combinado-lg-gbb71swvgn--23851924.html
# Įrašytas įrašas Nr 379, puslapis 10
# 10 https://www.varle.lt/saldytuvai/serie-4-laisvai-statomas-saldytuvas-saldiklis-su--20784143.html
# Įrašytas įrašas Nr 380, puslapis 10
# Įrašytas puslapis 10
# kitas puslapis: 11
# 11 https://www.varle.lt/saldytuvai/liebherr-icbsd-5122-imontuojamas-saldytuvas-saldiklis--16263629.html
# Įrašytas įrašas Nr 381, puslapis 11
# 11 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rf65dg9h0esref-prancuziskos-durys--41021465.html
# Įrašytas įrašas Nr 382, puslapis 11
# 11 https://www.varle.lt/saldytuvai/saldytuvas-arktic-saldymo-vitrina-su-2-lentynomis--40149327.html
# ...
# Įrašytas įrašas Nr 1114, puslapis 30
# 30 https://www.varle.lt/saldytuvai/liebherr-rbc-5220-saldytuvas-with-biofresh--32284911.html
# Įrašytas įrašas Nr 1115, puslapis 30
# 30 https://www.varle.lt/saldytuvai/liebherr-cnsfc-574i-saldytuvas-saldiklis-with-easyfresh--34161840.html
# Įrašytas įrašas Nr 1116, puslapis 30
# 30 https://www.varle.lt/saldytuvai/liebherr-re-1400-table-top-saldytuvas--35149890.html
# Įrašytas įrašas Nr 1117, puslapis 30
# 30 https://www.varle.lt/saldytuvai/liebherr-rsve-1201-table-top-saldytuvas-with-saldiklis--35149904.html
# Įrašytas įrašas Nr 1118, puslapis 30
# 30 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rb291d4cwe--36863607.html
# Įrašytas įrašas Nr 1119, puslapis 30
# 30 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb38c600esa--32748181.html
# Įrašytas įrašas Nr 1120, puslapis 30
# 30 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb38c7b5db1--34279227.html
# Įrašytas įrašas Nr 1121, puslapis 30
# 30 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb38c7b5e22--34279229.html
# Įrašytas įrašas Nr 1122, puslapis 30
# 30 https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgn497wdf--36909570.html
# Įrašytas įrašas Nr 1123, puslapis 30
# 30 https://www.varle.lt/saldytuvai/saldytuvas-siemens-kg-49eaica--15633057.html
# Įrašytas įrašas Nr 1124, puslapis 30
# 30 https://www.varle.lt/saldytuvai/liebherr-saldytuvas-liebherr-ctpel-231-vieno-dydzio--39262988.html
# Įrašytas įrašas Nr 1125, puslapis 30
# 30 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rb435n4bce--35680045.html
# Įrašytas įrašas Nr 1126, puslapis 30
# 30 https://www.varle.lt/saldytuvai/saldytuvas-berk-brc-186e-nf-x--38717990.html
# Įrašytas įrašas Nr 1127, puslapis 30
# 30 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb34c675esa--32748168.html
# Įrašytas įrašas Nr 1128, puslapis 30
# 30 https://www.varle.lt/saldytuvai/saldytuvas-beko-b5rcna365zxb--41035759.html
# Įrašytas įrašas Nr 1129, puslapis 30
# 30 https://www.varle.lt/saldytuvai/saldytuvas-berk-brc-18551-w--39553982.html
# Įrašytas įrašas Nr 1130, puslapis 30
# 30 https://www.varle.lt/saldytuvai/liebherr-rd-1200-table-top-saldytuvas--34161851.html
# Įrašytas įrašas Nr 1131, puslapis 30
# 30 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rb440n4wce--37252202.html
# Įrašytas įrašas Nr 1132, puslapis 30
# 30 https://www.varle.lt/saldytuvai/saldytuvas-berk-brc-186e-nf-id--38718008.html
# Įrašytas įrašas Nr 1133, puslapis 30
# 30 https://www.varle.lt/saldytuvai/saldytuvas-berk-brt-8552-w--37590719.html
# Įrašytas įrašas Nr 1134, puslapis 30
# 30 https://www.varle.lt/saldytuvai/liebherr-cuele-2831-saldytuvas-saldiklis-with-smartfrost--31389467.html
# Įrašytas įrašas Nr 1135, puslapis 30
# 30 https://www.varle.lt/saldytuvai/liebherr-ctele-2931-saldytuvas-saldiklis-with-smartfrost--31368876.html
# Įrašytas įrašas Nr 1136, puslapis 30
# 30 https://www.varle.lt/saldytuvai/liebherr-cue-2831-saldytuvas-saldiklis-with-smartfrost--31368874.html
# Įrašytas įrašas Nr 1137, puslapis 30
# 30 https://www.varle.lt/saldytuvai/gorenje-saldytuvas-saldiklis-rb491pw--40956803.html
# Įrašytas įrašas Nr 1138, puslapis 30
# 30 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb38c776cb1--37717437.html
# Įrašytas įrašas Nr 1139, puslapis 30
# 30 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb38c776cs9--39781783.html
# Įrašytas įrašas Nr 1140, puslapis 30
# Įrašytas puslapis 30
# kitas puslapis: 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb38c603db1--32748182.html
# Įrašytas įrašas Nr 1141, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb34c670esa--32748155.html
# Įrašytas įrašas Nr 1142, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rib312f4awe--35680032.html
# Įrašytas įrašas Nr 1143, puslapis 31
# 31 https://www.varle.lt/saldytuvai/liebherr-cuele-2331-saldytuvas-saldiklis-with-smartfrost--35479821.html
# Įrašytas įrašas Nr 1144, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-bosch-bosch-ksv36vxep-series-4-visos-erdves--40233510.html
# Įrašytas įrašas Nr 1145, puslapis 31
# 31 https://www.varle.lt/saldytuvai/lin-li-bc55-saldytuvas-juodas--39144715.html
# Įrašytas įrašas Nr 1146, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-sharp-sjfba05dtxleeu--37590721.html
# Įrašytas įrašas Nr 1147, puslapis 31
# 31 https://www.varle.lt/saldytuvai/liebherr-ecbn-5066-001-built-in-saldytuvas-saldiklis--17277220.html
# Įrašytas įrašas Nr 1148, puslapis 31
# 31 https://www.varle.lt/saldytuvai/liebherr-rsfd-5220-saldytuvas-with-easyfresh--34695920.html
# Įrašytas įrašas Nr 1149, puslapis 31
# 31 https://www.varle.lt/saldytuvai/liebherr-rdi-1621-table-top-saldytuvas-with-easyfresh--34695918.html
# Įrašytas įrašas Nr 1150, puslapis 31
# 31 https://www.varle.lt/saldytuvai/liebherr-srsdc-525i-freestanding-saldytuvas-with-easyfresh--34695914.html
# Įrašytas įrašas Nr 1151, puslapis 31
# 31 https://www.varle.lt/saldytuvai/liebherr-irbd-5121-imontuojamas-saldytuvas--34923599.html
# Įrašytas įrašas Nr 1152, puslapis 31
# 31 https://www.varle.lt/saldytuvai/liebherr-rbsfc-5220-saldytuvas-with-biofresh--34161852.html
# Įrašytas įrašas Nr 1153, puslapis 31
# 31 https://www.varle.lt/saldytuvai/liebherr-irbd-5121-built-in-saldytuvas-with-biofresh--32689805.html
# Įrašytas įrašas Nr 1154, puslapis 31
# 31 https://www.varle.lt/saldytuvai/liebherr-irbad-5190-001-built-in-saldytuvas-with-biofresh--32033760.html
# Įrašytas įrašas Nr 1155, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rb440n4gwd--37863008.html
# Įrašytas įrašas Nr 1156, puslapis 31
# 31 https://www.varle.lt/saldytuvai/liebherr-icne-5103-built-in-saldytuvas-saldiklis-with--31008389.html
# Įrašytas įrašas Nr 1157, puslapis 31
# 31 https://www.varle.lt/saldytuvai/liebherr-icbndi-5123-built-in-saldytuvas-saldiklis--34579674.html
# Įrašytas įrašas Nr 1158, puslapis 31
# 31 https://www.varle.lt/saldytuvai/liebherr-icbndi-5163-built-in-saldytuvas-saldiklis--37645512.html
# Įrašytas įrašas Nr 1159, puslapis 31
# 31 https://www.varle.lt/saldytuvai/liebherr-icnse-5103-built-in-saldytuvas-saldiklis--29891855.html
# Įrašytas įrašas Nr 1160, puslapis 31
# 31 https://www.varle.lt/saldytuvai/liebherr-cte-2531-saldytuvas-saldiklis-with-smartfrost--31368871.html
# Įrašytas įrašas Nr 1161, puslapis 31
# 31 https://www.varle.lt/saldytuvai/liebherr-re-1401-table-top-saldytuvas-with-saldiklis--32837323.html
# Įrašytas įrašas Nr 1162, puslapis 31
# 31 https://www.varle.lt/saldytuvai/liebherr-icbnd-5173-built-in-saldytuvas-saldiklis--39299875.html
# Įrašytas įrašas Nr 1163, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-berk-brc-15551-w--39555869.html
# Įrašytas įrašas Nr 1164, puslapis 31
# 31 https://www.varle.lt/saldytuvai/bosch-kin86vfe0-saldytuvas-saldiklis--37428191.html
# Įrašytas įrašas Nr 1165, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb50dg602es9--35283927.html
# Įrašytas įrašas Nr 1166, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rh69dg895eb1--39781793.html
# Įrašytas įrašas Nr 1167, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb38c7b6aap--31509245.html
# Įrašytas įrašas Nr 1168, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb33b612ebn--35283823.html
# Įrašytas įrašas Nr 1169, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-philco-px-502-iceberg--39925289.html
# Įrašytas įrašas Nr 1170, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-ukonic-kuhlschrank-xbox-10l--39991881.html
# Įrašytas įrašas Nr 1171, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-beko-bcna306e4zsn--41035754.html
# Įrašytas įrašas Nr 1172, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rb435n4bfe--35680052.html
# Įrašytas įrašas Nr 1173, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rb224d4bwe--32306667.html
# Įrašytas įrašas Nr 1174, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-whirlpool-whc18t132--32748220.html
# Įrašytas įrašas Nr 1175, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rb395n4bwe--27528970.html
# Įrašytas įrašas Nr 1176, puslapis 31
# 31 https://www.varle.lt/saldytuvai/saldytuvas-saldiklis-retro-ravanson-lkk-120rc--39041092.html
# Įrašytas įrašas Nr 1177, puslapis 31
# 31 https://www.varle.lt/saldytuvai/haier-saldytuvas-htw5620cnmp-414l-darl-inox--38766221.html
# Įrašytas įrašas Nr 1178, puslapis 31
# Įrašytas puslapis 31
# kitas puslapis: 32
# 32 https://www.varle.lt/saldytuvai/haier-hdpw5618dnpd-freestanding-352-l-d-juodas--38766309.html
# Įrašytas įrašas Nr 1179, puslapis 32
# 32 https://www.varle.lt/saldytuvai/saldytuvas-saldiklis-retro-ravanson-lkk-120rb--39041102.html
# Įrašytas įrašas Nr 1180, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-frfvg-5501-profi-saldytuvas--39359092.html
# Įrašytas įrašas Nr 1181, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-cnsdd-776i-saldytuvas-saldiklis-with-easyfresh--32837318.html
# Įrašytas įrašas Nr 1182, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-cnsfc-5023-plus-nofrost-saldytuvas-saldiklis--36875088.html
# Įrašytas įrašas Nr 1183, puslapis 32
# 32 https://www.varle.lt/saldytuvai/saldytuvas-beko-b5rcna365hg--36393276.html
# Įrašytas įrašas Nr 1184, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-ke-2834-saldytuvas-with-biocool--34161850.html
# Įrašytas įrašas Nr 1185, puslapis 32
# 32 https://www.varle.lt/saldytuvai/saldytuvas-berk-brc-186e-nf-w--38718007.html
# Įrašytas įrašas Nr 1186, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-rsdci-1620-table-top-saldytuvas-with-easyfresh--37209694.html
# Įrašytas įrašas Nr 1187, puslapis 32
# 32 https://www.varle.lt/saldytuvai/saldytuvas-cooler-hisense-rl415n4ace--35703169.html
# Įrašytas įrašas Nr 1188, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-cbnsda-572i-saldytuvas-saldiklis-with-biofresh--32837320.html
# Įrašytas įrašas Nr 1189, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-srbstd-529i-saldytuvas-with-biofresh--22347171.html
# Įrašytas įrašas Nr 1190, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-cuele-3331-pure-saldytuvas-saldiklis--38064603.html
# Įrašytas įrašas Nr 1191, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-icnd-5603-built-in-saldytuvas-saldiklis-with--40118811.html
# Įrašytas įrašas Nr 1192, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-icc-5123-built-in-saldytuvas-saldiklis-with--33882872.html
# Įrašytas įrašas Nr 1193, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-irbci-5150-built-in-saldytuvas-with-biofresh--34579670.html
# Įrašytas įrašas Nr 1194, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-re-1201-table-top-saldytuvas-with-saldiklis--34695916.html
# Įrašytas įrašas Nr 1195, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-ire-5101-built-in-saldytuvas-with-biocool--31543735.html
# Įrašytas įrašas Nr 1196, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-cue-3331-saldytuvas-saldiklis-with-smartfrost--31803706.html
# Įrašytas įrašas Nr 1197, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-icbc-5182-built-in-saldytuvas-saldiklis-with--32033754.html
# Įrašytas įrašas Nr 1198, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-irbd-5120-built-in-saldytuvas-with-biofresh--32689807.html
# Įrašytas įrašas Nr 1199, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-cbnsdc-575i-saldytuvas-saldiklis-with-biofresh--35186037.html
# Įrašytas įrašas Nr 1200, puslapis 32
# 32 https://www.varle.lt/saldytuvai/saldytuvas-samsung-lodowka-rb38c602eb1--40666343.html
# Įrašytas įrašas Nr 1201, puslapis 32
# 32 https://www.varle.lt/saldytuvai/saldytuvas-samsung-brb38g705dww--37230304.html
# Įrašytas įrašas Nr 1202, puslapis 32
# 32 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rf65db960e22--36684218.html
# Įrašytas įrašas Nr 1203, puslapis 32
# 32 https://www.varle.lt/saldytuvai/saldytuvas-beko-rdnt231i40xbn--41042834.html
# Įrašytas įrašas Nr 1204, puslapis 32
# 32 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rf24bb620eb1--35283930.html
# Įrašytas įrašas Nr 1205, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-cbnsfc-572i-saldytuvas-saldiklis-with-biofresh--34695910.html
# Įrašytas įrašas Nr 1206, puslapis 32
# 32 https://www.varle.lt/saldytuvai/saldytuvas-sharp-sjfba05dtxweeu--37552855.html
# Įrašytas įrašas Nr 1207, puslapis 32
# 32 https://www.varle.lt/saldytuvai/saldytuvas-sharp-sj-ftb01itxwe-eu--39349057.html
# Įrašytas įrašas Nr 1208, puslapis 32
# 32 https://www.varle.lt/saldytuvai/saldytuvas-berk-brt-851-w--40604957.html
# Įrašytas įrašas Nr 1209, puslapis 32
# 32 https://www.varle.lt/saldytuvai/saldytuvas-cooler-hisense-rl415n4awe--35703162.html
# Įrašytas įrašas Nr 1210, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-srbsfc-5220-freestanding-saldytuvas-with--32837329.html
# Įrašytas įrašas Nr 1211, puslapis 32
# 32 https://www.varle.lt/saldytuvai/saldytuvas-beko-b3rcne564hdxb--36393273.html
# Įrašytas įrašas Nr 1212, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-cuefe-3331-saldytuvas-saldiklis-with-smartfrost--35000079.html
# Įrašytas įrašas Nr 1213, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-irbci-5151-built-in-saldytuvas-with-biofresh--37645513.html
# Įrašytas įrašas Nr 1214, puslapis 32
# 32 https://www.varle.lt/saldytuvai/liebherr-cbnbsd-576i-prime-biofresh-nofrost-saldytuvas-saldiklis--24743362.html
# Įrašytas įrašas Nr 1215, puslapis 32
# 32 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rb224d4bde--32306670.html
# Įrašytas įrašas Nr 1216, puslapis 32
# Įrašytas puslapis 32
# kitas puslapis: 33
# 33 https://www.varle.lt/saldytuvai/liebherr-icbnci-5153-built-in-saldytuvas-saldiklis--35623432.html
# Įrašytas įrašas Nr 1217, puslapis 33
# 33 https://www.varle.lt/saldytuvai/liebherr-icbbi-5122-built-in-saldytuvas-saldiklis--35623431.html
# Įrašytas įrašas Nr 1218, puslapis 33
# 33 https://www.varle.lt/saldytuvai/liebherr-ctele-2131-saldytuvas-saldiklis-with-smartfrost--32284909.html
# Įrašytas įrašas Nr 1219, puslapis 33
# 33 https://www.varle.lt/saldytuvai/liebherr-cuele-3331-saldytuvas-saldiklis-with-smartfrost--32284910.html
# Įrašytas įrašas Nr 1220, puslapis 33
# 33 https://www.varle.lt/saldytuvai/liebherr-icbbi-5152-built-in-saldytuvas-saldiklis--37645510.html
# Įrašytas įrašas Nr 1221, puslapis 33
# 33 https://www.varle.lt/saldytuvai/liebherr-cnsfc-5023-saldytuvas-saldiklis-with-easyfresh--34161845.html
# Įrašytas įrašas Nr 1222, puslapis 33
# 33 https://www.varle.lt/saldytuvai/saldytuvas-berk-brc-15551-s--39555871.html
# Įrašytas įrašas Nr 1223, puslapis 33
# 33 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb34c7b5cap--35628943.html
# Įrašytas įrašas Nr 1224, puslapis 33
# 33 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb34c600ebn--34279218.html
# Įrašytas įrašas Nr 1225, puslapis 33
# 33 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb53dg703db1--35283931.html
# Įrašytas įrašas Nr 1226, puslapis 33
# 33 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb34c775cs9--34279221.html
# Įrašytas įrašas Nr 1227, puslapis 33
# 33 https://www.varle.lt/saldytuvai/saldytuvas-samsung-rb34c603cs9--39312671.html
# Įrašytas įrašas Nr 1228, puslapis 33
# 33 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rb395n4bfe--30556480.html
# Įrašytas įrašas Nr 1229, puslapis 33
# 33 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rb3b250sawe--37173350.html
# Įrašytas įrašas Nr 1230, puslapis 33
# 33 https://www.varle.lt/saldytuvai/saldytuvas-bosch-bosch-saldytuvo-ir-saldiklio-derinys--40295481.html
# Įrašytas įrašas Nr 1231, puslapis 33
# 33 https://www.varle.lt/saldytuvai/liebherr-ctele-2531-saldytuvas-su-saldikliu-virsuje--32998955.html
# Įrašytas įrašas Nr 1232, puslapis 33
# 33 https://www.varle.lt/saldytuvai/siemens-siemens-kg-49eaica-saldytuvas--40216925.html
# Įrašytas įrašas Nr 1233, puslapis 33
# 33 https://www.varle.lt/saldytuvai/saldytuvas-berk-brc-18551-s--38530342.html
# Įrašytas įrašas Nr 1234, puslapis 33
# 33 https://www.varle.lt/saldytuvai/haier-saldytuvas-hdpw5620cnpk-406l-sidabrinis--38766213.html
# Įrašytas įrašas Nr 1235, puslapis 33
# 33 https://www.varle.lt/saldytuvai/candy-fridge-freezer-cbl3518ecm--39041108.html
# Įrašytas įrašas Nr 1236, puslapis 33
# 33 https://www.varle.lt/saldytuvai/whirlpool-w4d7-bc21-free-standing-fridge-saldiklis--39859864.html
# Įrašytas įrašas Nr 1237, puslapis 33
# Įrašytas puslapis 33
# Baigta!!!
