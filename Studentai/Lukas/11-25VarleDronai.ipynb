# %%
import selenium
from selenium.webdriver.chrome.options import Options
# from selenium.webdriver.firefox.options import Options as FirefoxOptions
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import sqlite3
import mysql.connector as cnt
import random

# %%
def getColNamesList(table, dbname):
    db = sqlite3.connect(dbname)
    c = db.cursor()
    sql = '''select * from {table} limit 0'''.format(table=table)
    s = c.execute(sql)
    # r = s.description
    column_names = [description[0] for description in c.description]
    return column_names

def alterTableAddColumn(cols_i_want_to_have, cols_i_have, table, base):
    db = sqlite3.connect(base)
    c = db.cursor()
    sql = '''alter table {tname}
    add column `{n}`
    '''
    for cl in cols_i_want_to_have:
        if cl not in cols_i_have:
            c.execute(sql.format(tname=table, n=cl))
            time.sleep(1)
            db.commit()
            time.sleep(3)
    c.close()
    db.close()
    return True


def createMainTable(dbname:str) -> bool:
    sql = '''
    drop table if exists DronaiVarle
    '''
    db = sqlite3.connect(dbname)
    c = db.cursor()
    c.execute(sql)
    sql = '''create table if not exists DronaiVarle
    (
        nuoroda text,
        firstInfo text
    )
    '''
    c.execute(sql)
    c.close()
    db.close()
    return True
    pass

def writeMany(lst, table, dbname) -> bool:
    db = sqlite3.connect(dbname)
    c = db.cursor()
    sql = '''insert into {table} values ({n})'''
    q = ['?' for i in range(0,len(lst))]
    q_ = ', '.join(q)
    r_ = sql.format(table=table, n=q_)
    # print('::PROVIDED::', lst, len(lst), '::SQL COMMAND::', r_, len(q), sep='\n')
    c.execute(r_, lst)
    db.commit()
    c.close()
    db.close()
    return True

# %%
opcijos = Options()
opcijos.add_argument('--incognito')
opcijos.add_argument('--ignore-certificate-errors')
opcijos.add_argument('--ignore-ssl-errors')
driver = webdriver.Chrome(options=opcijos)
url = 'https://www.varle.lt/dronai/?p=1'
driver.get(url)
time.sleep(5)
source = driver.page_source


driver.close()
print('Baigta!!!')
# Out:
# Baigta!!!

# %%
bs = BeautifulSoup(source, 'html.parser')
p_nuorodos = []

linkai = bs.find_all('div', {'class':'GRID_ITEM'})
for linkas in linkai:
    # linkas = bs.find('div', {'class':'product-title'}).find('div', {'class':'product-title'}).find('a')
    link = linkas.find('div', {'class':'product-title'}).find('a')
    # print(link['href'])
    add_link = 'https://www.varle.lt'+ link['href']
    # print(add_link)
    p_nuorodos.append(add_link)
print(len(p_nuorodos))
print(p_nuorodos)

pages = []
pages_numbers = bs.find('div', {'class':'PAGINATION'}).find_all('li', {'class':'number'})
for page in pages_numbers:
    # print(page.text.strip())
    pages.append(int(page.text.strip()))
pages_max_number = max(pages)
print(pages_max_number)
# Out:
# 38
# ['https://www.varle.lt/dronai/dji-mini-4-pro-fly-more-combo-dji-rc-2-dronas--29184156.html', 'https://www.varle.lt/dronai/dronas-dji-mini-2-se-fly-more-combo--23881156.html', 'https://www.varle.lt/dronai/dronas-dji-mini-3-su-dji-rc-n1-valdymo-pultu--22802854.html', 'https://www.varle.lt/dronai/dronas-dji-air-3-fly-more-combo-su-dji-rc-2-valdymo--26530863.html', 'https://www.varle.lt/dronai/avernus-dronas-s1s-4k-hd--37604985.html', 'https://www.varle.lt/dronai/avernus-dronas-l900-pro-gps--37604944.html', 'https://www.varle.lt/dronai/dronas-dji-mini-2-se--23792132.html', 'https://www.varle.lt/dronai/dronas-dji-mini-3-fly-more-combo-su-dji-rc-valdymo--21966035.html', 'https://www.varle.lt/dronai/dronas-dji-mavic-3-pro-cine-premium-combo-dji-rc--24575445.html', 'https://www.varle.lt/dronai/dronas-dji-mavic-3-pro-dji-rc--24505758.html', 'https://www.varle.lt/dronai/extra-digital-kroviklis-dji-mavic-mini-2-se--39704489.html', 'https://www.varle.lt/dronai/dji-avata-2-dronas--34746172.html', 'https://www.varle.lt/dronai/dji-neo-drone-fly-more-combo-dronas--38775265.html', 'https://www.varle.lt/dronai/dronas-dji-mavic-air-2s--15711420.html', 'https://www.varle.lt/dronai/avernus-dronas-e63-pro-4k--37604932.html', 'https://www.varle.lt/dronai/dji-neo-motion-fly-more-combo-dronas--40643087.html', 'https://www.varle.lt/dronai/dronasdjiair-3s-fly-more-combo-dji-rc-n3consumercpma0000081501--39591441.html', 'https://www.varle.lt/dronai/dji-mavic-3-multispectral--24380630.html', 'https://www.varle.lt/dronai/dronas-dji-mavic-3-pro-fly-more-combo-dji-rc-pro--24554666.html', 'https://www.varle.lt/dronai/dronas-allnoel-e95-pro--32423660.html', 'https://www.varle.lt/dronai/dji-neo--38664654.html', 'https://www.varle.lt/dronai/extralink-dronas-e99-pro-su-3-baterijomis-ir-deklu--39673705.html', 'https://www.varle.lt/dronai/drono-rinkinys-extralink-dron-e88-pro-3-baterijos--38259682.html', 'https://www.varle.lt/dronai/dji-mini-4-pro-dji-rc-n2-dronas--29184151.html', 'https://www.varle.lt/dronai/dronas-dji-mini-4k-su-rc-n1c-valdymo-pultu--38764607.html', 'https://www.varle.lt/dronai/rankomis-valdomas-skraidantis-dronas-baltas--39830592.html', 'https://www.varle.lt/dronai/k911-max-gps-dronas-8k-sumine-filmavimo-kamera-profesionalus--35571291.html', 'https://www.varle.lt/dronai/dji-mini-3-pro-dronas-su-dji-rc-pultu--18933701.html', 'https://www.varle.lt/dronai/dronas-dji-mavic-3-pro-fly-more-combo-dji-rc--24537862.html', 'https://www.varle.lt/dronai/profesionalus-sulankstomas-dronas-su-6k-dviguba-hd--37236572.html', 'https://www.varle.lt/dronai/dronas-dji-air-3s-fly-more-combo-su-dji-rc-2-valdymo--39591440.html', 'https://www.varle.lt/dronai/dji-air-3-fly-more-combo-dronas-su-rc-n2-valdymo-pultu--26593170.html', 'https://www.varle.lt/dronai/parrot-anafi-usa-gov-dronas--31775527.html', 'https://www.varle.lt/dronai/dronas-dji-fpv-cpfp0000000901-atnaujinta--32235749.html', 'https://www.varle.lt/dronai/dji-mini-4-pro-dji-rc-2--29184945.html', 'https://www.varle.lt/dronai/dronas-dji-mini-4k-fly-more-combo-su-dji-rc-n1c--38731147.html', 'https://www.varle.lt/dronai/dronas-dji-mavic-3-classic-su-dji-rc-n1-valdymo-pultu--21236869.html', 'https://www.varle.lt/dronai/dji-avata-2-fly-more-combo-trys-baterijos-dronai--34230085.html']
# 3

# %%
for nuoroda in p_nuorodos[:1]:
    print(nuoroda)
    opcijos = Options()
    opcijos.add_argument('--incognito')
    opcijos.add_argument('--ignore-certificate-errors')
    opcijos.add_argument('--ignore-ssl-errors')
    driver = webdriver.Chrome(options=opcijos)
    url = nuoroda
    driver.get(url)
    time.sleep(5)
    source = driver.page_source


    driver.close()
# Out:
# https://www.varle.lt/dronai/dji-mini-4-pro-fly-more-combo-dji-rc-2-dronas--29184156.html

# %%
bs = BeautifulSoup(source, 'html.parser')
pavadinimas = bs.find('div', {'class':'main'}).find('h1', {'class':'title'}).text.strip()
print(pavadinimas)

# varle_kodas = bs.find('div', {'class':'main'}).find('span', {'itemprop':'sku'}).text
# print(varle_kodas)

kaina = bs.find('span', {'class':'price-value'}).text.strip()
print(kaina)

buvusi_kaina = bs.find('span', {'class':'previous-price'})
if buvusi_kaina != None:
    buvusi_kaina = buvusi_kaina.text.strip()
else:
    buvusi_kaina = None
print(buvusi_kaina)

specifiacija_keys = []
specifiacija_values = []
try:
    specifiacija = bs.find('div', {'class':'PRODUCT_SPEC'}).find_all('li', {'class':'spec-line'})
    for line in specifiacija:
        try:
            spec_key = line.find('span', {'class':'left-column'}).text
            # print(spec_key)
            specifiacija_keys.append(spec_key)
            spec_value = line.find('span', {'class':'right-column'}).text
            # print(spec_value)
            specifiacija_values.append(spec_value)
        except:
            pass
        try:
            spec_key = line.find('div', {'class':'left-column'}).text
            # print(spec_key)
            specifiacija_keys.append(spec_key)
            spec_value = line.find('div', {'class':'right-column'}).text
            # print(spec_value)
            specifiacija_values.append(spec_value)
        except:
            pass
except:
    pass

try:
    specifiacija_k = bs.find('div', {'class':'PRODUCT_SPEC'}).find_all('td', {'class':'key'})
    for key in specifiacija_k:
        # print(key.text.strip())
        specifiacija_keys.append(key.text.strip())
    specifiacija_v = bs.find('div', {'class':'PRODUCT_SPEC'}).find_all('td', {'class':'value'})
    for val in specifiacija_v:
        # print(val.text.strip())
        specifiacija_values.append(val.text.strip())       
except:
    pass

print(len(specifiacija_keys), specifiacija_keys)
print(len(specifiacija_values), specifiacija_values)

spec_filtrai_keys = []
spec_filtrai_values = []
try:
    spec_filtai = bs.find('div', {'class':'PRODUCT_SPEC_FILTERS'}).find_all('li', {'class':'spec-line'})
    for line in spec_filtai:
        spec_key = line.find('span', {'class':'left-column'}).text.strip()
        # print(spec_key)
        spec_filtrai_keys.append(spec_key)
        spec_value = line.find('span', {'class':'right-column'}).text.strip()
        # print(spec_value)
        spec_filtrai_values.append(spec_value)
except:
    pass
    
print(len(spec_filtrai_keys), spec_filtrai_keys)
print(len(spec_filtrai_values), spec_filtrai_values)
# Out:
# DJI Mini 4 Pro Fly More Combo ( DJI RC 2 ) dronas
# 1029.99
# None
# 37 ['Gamintojas', 'Stabilizavimas', 'Spalva', 'Perdavimo atstumas (lauke ir be kliūčių)', 'Maksimalus kilimo greitis', 'Bendras megapikselių skaičius', 'Veikimo dažnis', 'Svoris (su baterija, g)', 'Didžiausias skrydžio aukštis', 'Baterijos pavadinimas', 'Talpa', 'Didžiausias skrydžio laikas', 'Vaizdo raiška', 'Sklandymas viduje', 'Maksimalus nusileidimo greitis', 'Jutiklio dydis', 'Įkrovimas', 'Maitinimo šaltinis', 'Tinkamos operacinės sitemos', 'Maksimalus greitis', 'Atminties kortelės tipas', 'Nuotolinis vardas', 'Filmų formatas', 'Bitų skaičius', 'Įrašymo laikmena', 'Matymo laukas', 'Jutiklio tipas', 'Veikimo temperatūra', 'Mobilioji programėlė', 'Maksimalus atsparumas vėjui', 'Nejudančio vaizdo failo tipas', 'Skraidyklės modelis', 'Iso', 'Baterijos tipas', 'Mobiliojo įrenginio laikiklis', 'Komplektacija', 'Modelio pavadinimas']
# 37 ['DJI', '3 ašių (3-axis)', 'pilka', 'CE: 10 000 m', '5 m/s', '48', '5,725 – 5,825 GHz', '249 g', '4000 m (virš jūros lygio)', 'Išmanioji skrydžio baterija', '2590 mAh', '34 minutes', '[4K UHD] 3840 × 2160 60p', 'Nėra', '5 m/s', '1/1,3"', 'DJI pakrovėjas, USB PowerDelivery', 'Ličio baterija', 'Android, Apple iOS', '16 m/s', 'microSD', 'DJI RC 2', 'MP4, MOV', '150 Mbps', 'atminties kortelė', '82,1°', 'CMOS', '-10 – 40 °C', 'DJI Fly', '10,7 m/s', 'JPEG, DNG, RAW', 'DJI Mini 4 Pro', '100 – 6400', 'Ličio-polimerų', 'Išmaniajam telefonui', 'USB-C – USB-C PD kabelis, Kruvikeeraja, 18 × atsarginiai varžtai, Droon, 3 × sraigtų poros (iš viso 12), DJI RC 2 valdymo pultas, Propelerio laikiklis, 3 × Pažangi skrydžio baterija, Gimbal spaustukas, DJI õlakott, Įkrovimo dokas , RC laidas (USB-C), baterija, Gimbali apsauga', 'CP.MA.00000735.01']
# 6 ['Gamintojas', 'Tipas', 'Veikimo laikas (min)', 'Baterijos talpa (mAh)', 'Svoris (kg)', 'Spalva']
# 6 ['DJI', 'Mini', '34', '2590.0', '1.0', 'Pilka']

# %%
# Dronu lentele
# createMainTable('VarlePigu.db')
# Out:
# True

# %%
opcijos = Options()
opcijos.add_argument('--incognito')
opcijos.add_argument('--ignore-certificate-errors')
opcijos.add_argument('--ignore-ssl-errors')
driver = webdriver.Chrome(options=opcijos)
url = 'https://www.varle.lt/dronai/?p=1'
driver.get(url)
time.sleep(5)
source = driver.page_source

bs = BeautifulSoup(source, 'html.parser')
pages = []
pages_numbers = bs.find('div', {'class':'PAGINATION'}).find_all('li', {'class':'number'})
for page in pages_numbers:
    # print(page.text.strip())
    pages.append(int(page.text.strip()))
pages_max_number = max(pages)

counts = 1
psl = 1

while psl < pages_max_number + 1:
    source = driver.page_source
    bs = BeautifulSoup(source, 'html.parser')
    p_nuorodos = []

    linkai = bs.find_all('div', {'class':'GRID_ITEM'})
    for linkas in linkai:
        # linkas = bs.find('div', {'class':'product-title'}).find('div', {'class':'product-title'}).find('a')
        link = linkas.find('div', {'class':'product-title'}).find('a')
        # print(link['href'])
        add_link = 'https://www.varle.lt'+ link['href']
        # print(add_link)
        p_nuorodos.append(add_link)
        
    for nuoroda in p_nuorodos:
        print(psl, nuoroda)
        url = nuoroda
        driver.get(url)
        time.sleep(random.randint(5,10))
        source = driver.page_source
        
        cols_i_have = getColNamesList(table='DronaiVarle', dbname='VarlePigu.db')
        
        duomenys = {}
        for col in cols_i_have:
            duomenys[col] = None
            
        duomenys['nuoroda'] = nuoroda
        
        bs_preke = BeautifulSoup(source, 'html.parser')
        
        firstInfo = bs_preke.find('div', {'class':'main'}).find('h1', {'class':'title'}).text.strip()
        duomenys['firstInfo'] = firstInfo
        # print(pavadinimas)


        kaina = bs_preke.find('span', {'class':'price-value'}).text.strip()
        duomenys['kaina'] = kaina
        # print(kaina)

        buvusi_kaina = bs_preke.find('span', {'class':'previous-price'})
        if buvusi_kaina != None:
            buvusi_kaina = buvusi_kaina.text.strip()
        else:
            buvusi_kaina = None
        duomenys['buvusiKaina'] = buvusi_kaina
        # print(buvusi_kaina)

        specifiacija_keys = []
        specifiacija_values = []
        try:
            specifiacija = bs_preke.find('div', {'class':'PRODUCT_SPEC'}).find_all('li', {'class':'spec-line'})
            for line in specifiacija:
                try:
                    spec_key = line.find('span', {'class':'left-column'}).text
                    # print(spec_key)
                    specifiacija_keys.append(spec_key)
                    spec_value = line.find('span', {'class':'right-column'}).text
                    # print(spec_value)
                    specifiacija_values.append(spec_value)
                except:
                    pass
                try:
                    spec_key = line.find('div', {'class':'left-column'}).text
                    # print(spec_key)
                    specifiacija_keys.append(spec_key)
                    spec_value = line.find('div', {'class':'right-column'}).text
                    # print(spec_value)
                    specifiacija_values.append(spec_value)
                except:
                    pass
        except:
            pass

        try:
            specifiacija_k = bs_preke.find('div', {'class':'PRODUCT_SPEC'}).find_all('td', {'class':'key'})
            for key in specifiacija_k:
                # print(key.text.strip())
                specifiacija_keys.append(key.text.strip())
            specifiacija_v = bs_preke.find('div', {'class':'PRODUCT_SPEC'}).find_all('td', {'class':'value'})
            for val in specifiacija_v:
                # print(val.text.strip())
                specifiacija_values.append(val.text.strip())       
        except:
            pass
        
        
        # print(len(specifiacija_keys), specifiacija_keys)
        # print(len(specifiacija_values), specifiacija_values)

        spec_filtrai_keys = []
        spec_filtrai_values = []
        try:
            spec_filtai = bs_preke.find('div', {'class':'PRODUCT_SPEC_FILTERS'}).find_all('li', {'class':'spec-line'})
            for line in spec_filtai:
                spec_key = line.find('span', {'class':'left-column'}).text.strip()
                # print(spec_key)
                spec_filtrai_keys.append(spec_key)
                spec_value = line.find('span', {'class':'right-column'}).text.strip()
                # print(spec_value)
                spec_filtrai_values.append(spec_value)
                
            # print(len(spec_filtrai_keys), spec_filtrai_keys)
            # print(len(spec_filtrai_values), spec_filtrai_values)
        except:
            pass
        
        for k, v in zip(spec_filtrai_keys, spec_filtrai_values):
            duomenys[k] = v
            
        for k, v in zip(specifiacija_keys, specifiacija_values):
            duomenys[k] = v
            
        cols_i_need = list(duomenys.keys())
        
        data = tuple(duomenys.values())
        
        cols_i_have = getColNamesList(table='DronaiVarle', dbname='VarlePigu.db')
        
        alterTableAddColumn(cols_i_need, cols_i_have, 'DronaiVarle', 'VarlePigu.db')
        
        writeMany(data, 'DronaiVarle', 'VarlePigu.db')
        print(f'Įrašytas įrašas Nr {counts}, puslapis {psl}')
        counts = counts +1
    
    print(f'Įrašytas puslapis {psl}')
    psl = psl +1
    if psl <= pages_max_number:
        next_nuoroda = f'https://www.varle.lt/dronai/?p={psl}'
        driver.get(next_nuoroda)
        time.sleep(3)
        print(f'kitas puslapis: {psl}')
    
driver.close()
print('Baigta!!!')
# Out:
# 1 https://www.varle.lt/dronai/dji-mini-4-pro-fly-more-combo-dji-rc-2-dronas--29184156.html
# Įrašytas įrašas Nr 1, puslapis 1
# 1 https://www.varle.lt/dronai/dronas-dji-mini-2-se-fly-more-combo--23881156.html
# Įrašytas įrašas Nr 2, puslapis 1
# 1 https://www.varle.lt/dronai/dronas-dji-mini-3-su-dji-rc-n1-valdymo-pultu--22802854.html
# Įrašytas įrašas Nr 3, puslapis 1
# 1 https://www.varle.lt/dronai/dronas-dji-air-3-fly-more-combo-su-dji-rc-2-valdymo--26530863.html
# Įrašytas įrašas Nr 4, puslapis 1
# 1 https://www.varle.lt/dronai/avernus-dronas-s1s-4k-hd--37604985.html
# Įrašytas įrašas Nr 5, puslapis 1
# 1 https://www.varle.lt/dronai/avernus-dronas-l900-pro-gps--37604944.html
# Įrašytas įrašas Nr 6, puslapis 1
# 1 https://www.varle.lt/dronai/dronas-dji-mini-2-se--23792132.html
# Įrašytas įrašas Nr 7, puslapis 1
# 1 https://www.varle.lt/dronai/dronas-dji-mini-3-fly-more-combo-su-dji-rc-valdymo--21966035.html
# Įrašytas įrašas Nr 8, puslapis 1
# 1 https://www.varle.lt/dronai/dronas-dji-mavic-3-pro-cine-premium-combo-dji-rc--24575445.html
# Įrašytas įrašas Nr 9, puslapis 1
# 1 https://www.varle.lt/dronai/dronas-dji-mavic-3-pro-dji-rc--24505758.html
# Įrašytas įrašas Nr 10, puslapis 1
# 1 https://www.varle.lt/dronai/extra-digital-kroviklis-dji-mavic-mini-2-se--39704489.html
# Įrašytas įrašas Nr 11, puslapis 1
# 1 https://www.varle.lt/dronai/dji-avata-2-dronas--34746172.html
# Įrašytas įrašas Nr 12, puslapis 1
# 1 https://www.varle.lt/dronai/dji-neo-drone-fly-more-combo-dronas--38775265.html
# Įrašytas įrašas Nr 13, puslapis 1
# 1 https://www.varle.lt/dronai/dronas-dji-mavic-air-2s--15711420.html
# Įrašytas įrašas Nr 14, puslapis 1
# 1 https://www.varle.lt/dronai/avernus-dronas-e63-pro-4k--37604932.html
# Įrašytas įrašas Nr 15, puslapis 1
# 1 https://www.varle.lt/dronai/dji-neo-motion-fly-more-combo-dronas--40643087.html
# Įrašytas įrašas Nr 16, puslapis 1
# 1 https://www.varle.lt/dronai/dronasdjiair-3s-fly-more-combo-dji-rc-n3consumercpma0000081501--39591441.html
# Įrašytas įrašas Nr 17, puslapis 1
# 1 https://www.varle.lt/dronai/dji-mavic-3-multispectral--24380630.html
# Įrašytas įrašas Nr 18, puslapis 1
# 1 https://www.varle.lt/dronai/dronas-dji-mavic-3-pro-fly-more-combo-dji-rc-pro--24554666.html
# Įrašytas įrašas Nr 19, puslapis 1
# 1 https://www.varle.lt/dronai/dronas-allnoel-e95-pro--32423660.html
# Įrašytas įrašas Nr 20, puslapis 1
# 1 https://www.varle.lt/dronai/dji-neo--38664654.html
# Įrašytas įrašas Nr 21, puslapis 1
# 1 https://www.varle.lt/dronai/extralink-dronas-e99-pro-su-3-baterijomis-ir-deklu--39673705.html
# Įrašytas įrašas Nr 22, puslapis 1
# 1 https://www.varle.lt/dronai/drono-rinkinys-extralink-dron-e88-pro-3-baterijos--38259682.html
# Įrašytas įrašas Nr 23, puslapis 1
# 1 https://www.varle.lt/dronai/dji-mini-4-pro-dji-rc-n2-dronas--29184151.html
# Įrašytas įrašas Nr 24, puslapis 1
# 1 https://www.varle.lt/dronai/dronas-dji-mini-4k-su-rc-n1c-valdymo-pultu--38764607.html
# Įrašytas įrašas Nr 25, puslapis 1
# 1 https://www.varle.lt/dronai/rankomis-valdomas-skraidantis-dronas-baltas--39830592.html
# Įrašytas įrašas Nr 26, puslapis 1
# 1 https://www.varle.lt/dronai/k911-max-gps-dronas-8k-sumine-filmavimo-kamera-profesionalus--35571291.html
# Įrašytas įrašas Nr 27, puslapis 1
# 1 https://www.varle.lt/dronai/dji-mini-3-pro-dronas-su-dji-rc-pultu--18933701.html
# Įrašytas įrašas Nr 28, puslapis 1
# 1 https://www.varle.lt/dronai/dronas-dji-mavic-3-pro-fly-more-combo-dji-rc--24537862.html
# Įrašytas įrašas Nr 29, puslapis 1
# 1 https://www.varle.lt/dronai/profesionalus-sulankstomas-dronas-su-6k-dviguba-hd--37236572.html
# Įrašytas įrašas Nr 30, puslapis 1
# 1 https://www.varle.lt/dronai/dronas-dji-air-3s-fly-more-combo-su-dji-rc-2-valdymo--39591440.html
# Įrašytas įrašas Nr 31, puslapis 1
# 1 https://www.varle.lt/dronai/dji-air-3-fly-more-combo-dronas-su-rc-n2-valdymo-pultu--26593170.html
# Įrašytas įrašas Nr 32, puslapis 1
# 1 https://www.varle.lt/dronai/parrot-anafi-usa-gov-dronas--31775527.html
# Įrašytas įrašas Nr 33, puslapis 1
# 1 https://www.varle.lt/dronai/dronas-dji-fpv-cpfp0000000901-atnaujinta--32235749.html
# Įrašytas įrašas Nr 34, puslapis 1
# 1 https://www.varle.lt/dronai/dji-mini-4-pro-dji-rc-2--29184945.html
# Įrašytas įrašas Nr 35, puslapis 1
# 1 https://www.varle.lt/dronai/dronas-dji-mini-4k-fly-more-combo-su-dji-rc-n1c--38731147.html
# Įrašytas įrašas Nr 36, puslapis 1
# 1 https://www.varle.lt/dronai/dronas-dji-mavic-3-classic-su-dji-rc-n1-valdymo-pultu--21236869.html
# Įrašytas įrašas Nr 37, puslapis 1
# 1 https://www.varle.lt/dronai/dji-avata-2-fly-more-combo-trys-baterijos-dronai--34230085.html
# Įrašytas įrašas Nr 38, puslapis 1
# Įrašytas puslapis 1
# kitas puslapis: 2
# 2 https://www.varle.lt/dronai/dronas-dji-mini-3-consumer-su-dji-rc-baltos-spalvos--22854595.html
# Įrašytas įrašas Nr 39, puslapis 2
# 2 https://www.varle.lt/dronai/dji-air-3-dji-rc-n2-dronas--26530862.html
# Įrašytas įrašas Nr 40, puslapis 2
# 2 https://www.varle.lt/dronai/dronas-dji-avata-pro-view-combo--20515521.html
# Įrašytas įrašas Nr 41, puslapis 2
# 2 https://www.varle.lt/dronai/dronas-rebel-dove-pro--28902852.html
# Įrašytas įrašas Nr 42, puslapis 2
# 2 https://www.varle.lt/dronai/sulankstomas-pro-dronas-v4-rc-4k-hd--36079781.html
# Įrašytas įrašas Nr 43, puslapis 2
# 2 https://www.varle.lt/dronai/5g-wifi-fpv-daugiafunkcinis-dronas--21901430.html
# Įrašytas įrašas Nr 44, puslapis 2
# 2 https://www.varle.lt/dronai/chasing-gladius-mini-s-200-m-povandeninins-dronas--16194787.html
# Įrašytas įrašas Nr 45, puslapis 2
# 2 https://www.varle.lt/dronai/dji-avata-be-pulto-dronas--20943963.html
# Įrašytas įrašas Nr 46, puslapis 2
# 2 https://www.varle.lt/dronai/dronas-dji-avata-explorer-combo--24033286.html
# Įrašytas įrašas Nr 47, puslapis 2
# 2 https://www.varle.lt/dronai/syma-x20p-quad-copter-24g-4-channel-drone-juodas--15636450.html
# Įrašytas įrašas Nr 48, puslapis 2
# 2 https://www.varle.lt/dronai/profesionalus-dronas-su-8k-hd-kamera-5g-wi-fi--34584205.html
# Įrašytas įrašas Nr 49, puslapis 2
# 2 https://www.varle.lt/dronai/dronas-ruko-f11mini-4k-wi-fi-gps--38168111.html
# Įrašytas įrašas Nr 50, puslapis 2
# 2 https://www.varle.lt/dronai/fimi-x8-pro-combo-dronas-2x-baterija-krepsys--36090797.html
# Įrašytas įrašas Nr 51, puslapis 2
# 2 https://www.varle.lt/dronai/denver-dcw-362--37829562.html
# Įrašytas įrašas Nr 52, puslapis 2
# 2 https://www.varle.lt/dronai/nuotoliniu-budu-valdomas-dronas-syma-x37-juodas--40528449.html
# Įrašytas įrašas Nr 53, puslapis 2
# 2 https://www.varle.lt/dronai/dron-hoverair-x1-kombinuota-mazmenine-prekyba---37361580.html
# Įrašytas įrašas Nr 54, puslapis 2
# 2 https://www.varle.lt/dronai/nuotoliniu-budu-valdomas-dronas-kvadkopteris-flying--40870026.html
# Įrašytas įrašas Nr 55, puslapis 2
# 2 https://www.varle.lt/dronai/nuotoliniu-budu-valdomas-dronas-kvadkopteris-flying--40870020.html
# Įrašytas įrašas Nr 56, puslapis 2
# 2 https://www.varle.lt/dronai/dron-jamara-angel-120--12393432.html
# Įrašytas įrašas Nr 57, puslapis 2
# 2 https://www.varle.lt/dronai/dronas-fimi-x8-mini-3--37807100.html
# Įrašytas įrašas Nr 58, puslapis 2
# 2 https://www.varle.lt/dronai/autel-robotics-evo-max-4t--35027967.html
# Įrašytas įrašas Nr 59, puslapis 2
# 2 https://www.varle.lt/dronai/amewi-dre-trix-3in1-luftkissen-li-po-akku-350mah-oranzinis--25041047.html
# Įrašytas įrašas Nr 60, puslapis 2
# 2 https://www.varle.lt/dronai/fimi-x8-pro-dronas-su-4k-kamera-ir-gps--33039316.html
# Įrašytas įrašas Nr 61, puslapis 2
# 2 https://www.varle.lt/dronai/dronas-x-imvnlei-x-idrone-19-720p--38168114.html
# Įrašytas įrašas Nr 62, puslapis 2
# 2 https://www.varle.lt/dronai/dji-phantom-4-rtk-combo--10499929.html
# Įrašytas įrašas Nr 63, puslapis 2
# 2 https://www.varle.lt/dronai/nuotoliniu-budu-valdomas-dronas-juodas-syma-x23w--39567083.html
# Įrašytas įrašas Nr 64, puslapis 2
# 2 https://www.varle.lt/dronai/dronedjiavata-2-drone-onlyconsumercpfp0000014903--39312270.html
# Įrašytas įrašas Nr 65, puslapis 2
# 2 https://www.varle.lt/dronai/nuotoliniu-budu-valdomas-syma-x26-dronas-su-kliuciu--40857258.html
# Įrašytas įrašas Nr 66, puslapis 2
# 2 https://www.varle.lt/dronai/syma-v22-24g-rc-dronas--34081828.html
# Įrašytas įrašas Nr 67, puslapis 2
# 2 https://www.varle.lt/dronai/rc-dronas--40376720.html
# Įrašytas įrašas Nr 68, puslapis 2
# 2 https://www.varle.lt/dronai/povandeninis-dronas-chasing-gladius-mini-s-100m--16194786.html
# Įrašytas įrašas Nr 69, puslapis 2
# 2 https://www.varle.lt/dronai/dronas-hoverair-x1-baltas--37361578.html
# Įrašytas įrašas Nr 70, puslapis 2
# 2 https://www.varle.lt/dronai/dji-fpv-explorer-combo--28811606.html
# Įrašytas įrašas Nr 71, puslapis 2
# 2 https://www.varle.lt/dronai/dji-mini-3-fly-more-combo-su-ismaniuoju-pultu--32192724.html
# Įrašytas įrašas Nr 72, puslapis 2
# 2 https://www.varle.lt/dronai/extra-digital-kroviklis-dji-mavic-air-2s-dji-mavic--31036905.html
# Įrašytas įrašas Nr 73, puslapis 2
# 2 https://www.varle.lt/dronai/dronedjiinspire-2-x7-standard-kitprofessionalcpin0000001101--30224649.html
# Įrašytas įrašas Nr 74, puslapis 2
# 2 https://www.varle.lt/dronai/nuotoliniu-budu-valdomas-syma-x38-dronas-baltas--41046027.html
# Įrašytas įrašas Nr 75, puslapis 2
# 2 https://www.varle.lt/dronai/nuotoliniu-budu-valdomas-dronas-su-deklu-ir-kamera--40987669.html
# Įrašytas įrašas Nr 76, puslapis 2
# Įrašytas puslapis 2
# kitas puslapis: 3
# 3 https://www.varle.lt/dronai/dronedjimavic-3-enterprise-c2-labelenterprisecpen0000049801--35492918.html
# Įrašytas įrašas Nr 77, puslapis 3
# 3 https://www.varle.lt/dronai/dron-allnet-mini-dron-174879-all-gd65ablue--28640078.html
# Įrašytas įrašas Nr 78, puslapis 3
# 3 https://www.varle.lt/dronai/extra-digital-kroviklis-dji-mavic-air-2s-dji-mavic--31036900.html
# Įrašytas įrašas Nr 79, puslapis 3
# 3 https://www.varle.lt/dronai/extra-digital-kroviklis-dji-mavic-2-mavic-2-pro--31330320.html
# Įrašytas įrašas Nr 80, puslapis 3
# 3 https://www.varle.lt/dronai/rc-drone-hd-plataus-kampo-kamera--40376737.html
# Įrašytas įrašas Nr 81, puslapis 3
# 3 https://www.varle.lt/dronai/chasing-m2-s-standard-200m--34783100.html
# Įrašytas įrašas Nr 82, puslapis 3
# 3 https://www.varle.lt/dronai/fimi-x8-mini-3-dronas-su-4k-kamera-ir-gps-oranzinis--37807099.html
# Įrašytas įrašas Nr 83, puslapis 3
# 3 https://www.varle.lt/dronai/chasing-m2-s-advanced-set--34783097.html
# Įrašytas įrašas Nr 84, puslapis 3
# 3 https://www.varle.lt/dronai/dronas-dji-inspire-3--26077613.html
# Įrašytas įrašas Nr 85, puslapis 3
# 3 https://www.varle.lt/dronai/dronas-dji-mavic-3-enterprise--22854597.html
# Įrašytas įrašas Nr 86, puslapis 3
# 3 https://www.varle.lt/dronai/chasing-m2-pro-max-advanced-set--34783079.html
# Įrašytas įrašas Nr 87, puslapis 3
# 3 https://www.varle.lt/dronai/extra-digital-kroviklis-dji-mini-2--31036903.html
# Įrašytas įrašas Nr 88, puslapis 3
# 3 https://www.varle.lt/dronai/dronas-idea-33-morly-4k-kamera-5g-wi-fi-fpv--38168107.html
# Įrašytas įrašas Nr 89, puslapis 3
# 3 https://www.varle.lt/dronai/parrot-parpot-anafi-jav-centrinis-kunas--37363263.html
# Įrašytas įrašas Nr 90, puslapis 3
# 3 https://www.varle.lt/dronai/nuotoliniu-budu-valdomas-dronas-syma-x26-juodas--40528455.html
# Įrašytas įrašas Nr 91, puslapis 3
# 3 https://www.varle.lt/dronai/nuotoliniu-budu-valdomas-dronas-su-kamera-sy16-ir--40978048.html
# Įrašytas įrašas Nr 92, puslapis 3
# 3 https://www.varle.lt/dronai/nuotoliniu-budu-valdomas-dronas-su-kamera-ir-deklu--40987718.html
# Įrašytas įrašas Nr 93, puslapis 3
# 3 https://www.varle.lt/dronai/chasing-f1-pro--34100778.html
# Įrašytas įrašas Nr 94, puslapis 3
# 3 https://www.varle.lt/dronai/dronasdjiair-3s-dji-rc-n3vartotojascpma0000081401--39591438.html
# Įrašytas įrašas Nr 95, puslapis 3
# 3 https://www.varle.lt/dronai/dronas-dji-matrice-350-rtk--26653716.html
# Įrašytas įrašas Nr 96, puslapis 3
# 3 https://www.varle.lt/dronai/povandeninis-dronas-chasing-gladius-mini-drone-s-flash--17317076.html
# Įrašytas įrašas Nr 97, puslapis 3
# 3 https://www.varle.lt/dronai/utext-uparrot-dronas-parrot-anafi-usa-se--27038918.html
# Įrašytas įrašas Nr 98, puslapis 3
# 3 https://www.varle.lt/dronai/parrot-anafi-ai-dronas--19115381.html
# Įrašytas įrašas Nr 99, puslapis 3
# 3 https://www.varle.lt/dronai/dji-matrice-210-rtk-v2--33611226.html
# Įrašytas įrašas Nr 100, puslapis 3
# 3 https://www.varle.lt/dronai/parrot-anafi-usa-hinge-kit--31006492.html
# Įrašytas įrašas Nr 101, puslapis 3
# 3 https://www.varle.lt/dronai/chasing-dory-refurbished--41005348.html
# Įrašytas įrašas Nr 102, puslapis 3
# 3 https://www.varle.lt/dronai/dji-mavic-3-multispectral-eu-c2--34507932.html
# Įrašytas įrašas Nr 103, puslapis 3
# 3 https://www.varle.lt/dronai/dronas-dji-phantom-3-professional-w323b-naudotas--34782977.html
# Įrašytas įrašas Nr 104, puslapis 3
# Įrašytas puslapis 3
# Baigta!!!

# %%
a = random.randint(5,10)
print(a)
# Out:
# 9
