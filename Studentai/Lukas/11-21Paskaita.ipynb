# %%
# SELECT
# CASE WHEN OnlineOrderFlag = 1 THEN 'Online' ELSE 'Store' END AS OrderOrigin,
# strftime('%Y' , OrderDate) AS OrderYear,
# strftime('%m' , OrderDate) AS OrderMonth,
# COUNT(SalesOrderId) AS TotalSales,
# SUM(TotalDue) AS totalRevenue
# FROM `Sales/SalesOrderHeader`
# GROUP BY
# strftime('%Y' , OrderDate),
# strftime('%m' , OrderDate),
# OnlineOrderFlag
# ORDER BY
# OrderOrigin,
# OrderYear DESC,
# OrderMonth DESC;

# %%
# https://stackoverflow.com/questions/5099193/using-beautifulsoup-to-find-all-elements-starting-with-a-given-letter

# %%
import selenium
from selenium.webdriver.chrome.options import Options
# from selenium.webdriver.firefox.options import Options as FirefoxOptions
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import sqlite3
import mysql.connector as cnt
import random

# %%
def getColNamesList(table, dbname):
    db = sqlite3.connect(dbname)
    c = db.cursor()
    sql = '''select * from {table} limit 0'''.format(table=table)
    s = c.execute(sql)
    # r = s.description
    column_names = [description[0] for description in c.description]
    return column_names

def alterTableAddColumn(cols_i_want_to_have, cols_i_have, table, base):
    db = sqlite3.connect(base)
    c = db.cursor()
    sql = '''alter table {tname}
    add column `{n}`
    '''
    for cl in cols_i_want_to_have:
        if cl not in cols_i_have:
            c.execute(sql.format(tname=table, n=cl))
            time.sleep(1)
            db.commit()
            time.sleep(3)
    c.close()
    db.close()
    return True


def createMainTable(dbname:str) -> bool:
    sql = '''
    drop table if exists saldytuvaiVarle
    '''
    db = sqlite3.connect(dbname)
    c = db.cursor()
    c.execute(sql)
    sql = '''create table if not saldytuvaiVarle
    (
        pavadinimas text
    )
    '''
    c.execute(sql)
    c.close()
    db.close()
    return True
    pass

def writeMany(lst, table, dbname) -> bool:
    db = sqlite3.connect(dbname)
    c = db.cursor()
    sql = '''insert into {table} values ({n})'''
    q = ['?' for i in range(0,len(lst))]
    q_ = ', '.join(q)
    r_ = sql.format(table=table, n=q_)
    # print('::PROVIDED::', lst, len(lst), '::SQL COMMAND::', r_, len(q), sep='\n')
    c.execute(r_, lst)
    db.commit()
    c.close()
    db.close()
    return True

# %%
opcijos = Options()
opcijos.add_argument('--incognito')
opcijos.add_argument('--ignore-certificate-errors')
opcijos.add_argument('--ignore-ssl-errors')
driver = webdriver.Chrome(options=opcijos)
# url = 'https://www.varle.lt/saldytuvai/'
url = 'https://www.varle.lt/saldytuvai/?p=1'
driver.get(url)
time.sleep(5)
source = driver.page_source


driver.close()
print('Baigta!!!')
# Out:
# Baigta!!!

# %%
bs = BeautifulSoup(source, 'html.parser')
p_nuorodos = []

linkai = bs.find_all('div', {'class':'GRID_ITEM'})
for linkas in linkai:
    # linkas = bs.find('div', {'class':'product-title'}).find('div', {'class':'product-title'}).find('a')
    link = linkas.find('div', {'class':'product-title'}).find('a')
    # print(link['href'])
    add_link = 'https://www.varle.lt'+ link['href']
    # print(add_link)
    p_nuorodos.append(add_link)
print(len(p_nuorodos))
print(p_nuorodos)

pages = []
pages_numbers = bs.find('div', {'class':'PAGINATION'}).find_all('li', {'class':'number'})
for page in pages_numbers:
    # print(page.text.strip())
    pages.append(int(page.text.strip()))
pages_max_number = max(pages)


for i in range(pages_max_number):
# Out:
# 38
# ['https://www.varle.lt/saldytuvai/saldytuvas-sharp-sj-ftb01itxse-eu--36822303.html', 'https://www.varle.lt/saldytuvai/saldytuvas-hisense-rr106d4cbe-85cm-juodas--37859978.html', 'https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgn36nwea-2-serija-baltos-spalvos--15912426.html', 'https://www.varle.lt/saldytuvai/saldytuvas-haier-hle-172-de--31802747.html', 'https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-liebherr-icnd-5103-pure-nofrost--35127654.html', 'https://www.varle.lt/saldytuvai/aeg-imontuojamas-saldytuvas-ske818d1ds-178-cm--31318904.html', 'https://www.varle.lt/saldytuvai/saldytuvas-beko-rcha270k30xbn--24738533.html', 'https://www.varle.lt/saldytuvai/imontuojamasis-saldytuvas-bosch-kin86nse0-nofrost--28786311.html', 'https://www.varle.lt/saldytuvai/saldytuvas-mpm-90-cj-27--38277846.html', 'https://www.varle.lt/saldytuvai/marshall-fridge-black-edition-32-92l-vidutines--17311967.html', 'https://www.varle.lt/saldytuvai/saldytuvas-sharp-sjfbb04dtxleeu--36352485.html', 'https://www.varle.lt/saldytuvai/saldytuvas-gorenje-rb492pw--30151495.html', 'https://www.varle.lt/saldytuvai/bosch-bsh-fclg-giengen-serija-2-imontuojamasis-saldytuvas--35653463.html', 'https://www.varle.lt/saldytuvai/saldytuvas-saldiklis-mpm-108-kb-44--37708044.html', 'https://www.varle.lt/saldytuvai/liebherr-saldytuvas-ire-5100--16581553.html', 'https://www.varle.lt/saldytuvai/samsung-saldytuvas-brb26705ewwef--15968513.html', 'https://www.varle.lt/saldytuvai/saldytuvas-whirlpool-whc20-t573--16142970.html', 'https://www.varle.lt/saldytuvai/gorenje-saldytuvas-saldiklis-nrk620ca2xl4--33990406.html', 'https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-whirlpool-sp40-812-eu-2--35817045.html', 'https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgn33nleb-ekspozicine-preke--40739823.html', 'https://www.varle.lt/saldytuvai/gorenje-saldytuvas-nrk6202aw4-energy-efficiency--18802196.html', 'https://www.varle.lt/saldytuvai/saldytuvas-gorenje-nrk6182ps4--16731705.html', 'https://www.varle.lt/saldytuvai/built-in-saldytuvas-whirlpool-194cm-nf--18106310.html', 'https://www.varle.lt/saldytuvai/saldytuvas-beko-b3rcna404hw--22054518.html', 'https://www.varle.lt/saldytuvai/lg-saldytuvas-gbv3200dpy-energy-efficiency-class--31030911.html', 'https://www.varle.lt/saldytuvai/saldytuvas-gotie-glz-85b--30323188.html', 'https://www.varle.lt/saldytuvai/saldytuvas-lg-gbv5240dep--31078155.html', 'https://www.varle.lt/saldytuvai/polar-saldytuvas-saldiklis-pob602ek-netnet--34472245.html', 'https://www.varle.lt/saldytuvai/bsh-fclwr-wroclaw-serija-4-laisvai-statomas-saldytuvas-saldiklis--20783689.html', 'https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-amica-uc1624e-135l-balta--35619265.html', 'https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-liebherr-irbd-5151--16451714.html', 'https://www.varle.lt/saldytuvai/goddess-single-door-saldytuvas-with-saldiklis-compartment--39621724.html', 'https://www.varle.lt/saldytuvai/lg-saldytuvas-gbv7180cpy-energy-efficiency-class--32152423.html', 'https://www.varle.lt/saldytuvai/saldytuvas-gastronominis-saldymo-stalas-4-stalciai--40272162.html', 'https://www.varle.lt/saldytuvai/saldytuvas-royal-catering-saldymo-vitrina-su-led-apsvietimu--40149283.html', 'https://www.varle.lt/saldytuvai/saldytuvas-gorenje-rb493pw-baltas--25438488.html', 'https://www.varle.lt/saldytuvai/saldytuvas-hisense-rb440n4gbd--29871329.html', 'https://www.varle.lt/saldytuvai/built-in-saldytuvas-whirlpool-70cm--28243109.html']
# 33

# %%
kitas_psl = bs.find('li', {'class':'wide'}).find('a', {'class':'for-desktop'})['href'].strip()
print(kitas_psl)
next_psl = 'https://www.varle.lt'+kitas_psl
print(next_psl)
# Out:
# /saldytuvai/
# https://www.varle.lt/saldytuvai/

# %%
for nuoroda in p_nuorodos[:1]:
    print(nuoroda)
    opcijos = Options()
    opcijos.add_argument('--incognito')
    opcijos.add_argument('--ignore-certificate-errors')
    opcijos.add_argument('--ignore-ssl-errors')
    driver = webdriver.Chrome(options=opcijos)
    url = nuoroda
    # url = 'https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgn33nleb-ekspozicine-preke--40739823.html'
    # url = 'https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgn36nwea-2-serija-baltos-spalvos--15912426.html'
    driver.get(url)
    time.sleep(5)
    source = driver.page_source


    driver.close()
# Out:
# https://www.varle.lt/saldytuvai/saldytuvas-sharp-sj-ftb01itxse-eu--36822303.html

# %%
bs = BeautifulSoup(source, 'html.parser')
pavadinimas = bs.find('div', {'class':'main'}).find('h1', {'class':'title'}).text.strip()
print(pavadinimas)

# varle_kodas = bs.find('div', {'class':'main'}).find('span', {'itemprop':'sku'}).text
# print(varle_kodas)

kaina = bs.find('span', {'class':'price-value'}).text.strip()
print(kaina)

buvusi_kaina = bs.find('span', {'class':'previous-price'})
if buvusi_kaina != None:
    buvusi_kaina = buvusi_kaina.text.strip()
else:
    buvusi_kaina = None
print(buvusi_kaina)

specifiacija_keys = []
specifiacija_values = []
try:
    specifiacija = bs.find('div', {'class':'PRODUCT_SPEC'}).find_all('li', {'class':'spec-line'})
    for line in specifiacija:
        try:
            spec_key = line.find('span', {'class':'left-column'}).text
            # print(spec_key)
            specifiacija_keys.append(spec_key)
            spec_value = line.find('span', {'class':'right-column'}).text
            # print(spec_value)
            specifiacija_values.append(spec_value)
        except:
            pass
        try:
            spec_key = line.find('div', {'class':'left-column'}).text
            # print(spec_key)
            specifiacija_keys.append(spec_key)
            spec_value = line.find('div', {'class':'right-column'}).text
            # print(spec_value)
            specifiacija_values.append(spec_value)
        except:
            pass
except:
    pass

try:
    specifiacija_k = bs.find('div', {'class':'PRODUCT_SPEC'}).find_all('td', {'class':'key'})
    for key in specifiacija_k:
        # print(key.text.strip())
        specifiacija_keys.append(key.text.strip())
    specifiacija_v = bs.find('div', {'class':'PRODUCT_SPEC'}).find_all('td', {'class':'value'})
    for val in specifiacija_v:
        # print(val.text.strip())
        specifiacija_values.append(val.text.strip())       
except:
    pass

print(len(specifiacija_keys), specifiacija_keys)
print(len(specifiacija_values), specifiacija_values)

spec_filtrai_keys = []
spec_filtrai_values = []
try:
    spec_filtai = bs.find('div', {'class':'PRODUCT_SPEC_FILTERS'}).find_all('li', {'class':'spec-line'})
    for line in spec_filtai:
        spec_key = line.find('span', {'class':'left-column'}).text.strip()
        # print(spec_key)
        spec_filtrai_keys.append(spec_key)
        spec_value = line.find('span', {'class':'right-column'}).text.strip()
        # print(spec_value)
        spec_filtrai_values.append(spec_value)
except:
    pass
    
print(len(spec_filtrai_keys), spec_filtrai_keys)
print(len(spec_filtrai_values), spec_filtrai_values)
# Out:
# Šaldytuvas Sharp SJ-FTB01ITXSE-EU
# 229
# 289 €
# 2 ['Gamintojas', 'Modelio pavadinimas']
# 2 ['Sharp', 'SJFTB01ITXSEEU']
# 6 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)']
# 6 ['Sharp', 'Su kamera viršuje', 'Laisvai statomi', 'E', '213.0', '145.0']

# %%
opcijos = Options()
opcijos.add_argument('--incognito')
opcijos.add_argument('--ignore-certificate-errors')
opcijos.add_argument('--ignore-ssl-errors')
driver = webdriver.Chrome(options=opcijos)
nr = 1
for nuoroda in p_nuorodos:
    print(nr, nuoroda)
    nr += 1
    url = nuoroda
    # url = 'https://www.varle.lt/saldytuvai/saldytuvas-indesit-si6-1-s--18747470.html'
    # url = 'https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgn36nwea-2-serija-baltos-spalvos--15912426.html'
    driver.get(url)
    time.sleep(1)
    source = driver.page_source
    
    bs = BeautifulSoup(source, 'html.parser')
    pavadinimas = bs.find('div', {'class':'main'}).find('h1', {'class':'title'}).text.strip()
    print(pavadinimas)

    # varle_kodas = bs.find('div', {'class':'main'}).find('span', {'itemprop':'sku'}).text
    # print(varle_kodas)

    kaina = bs.find('span', {'class':'price-value'}).text.strip()
    print(kaina)

    buvusi_kaina = bs.find('span', {'class':'previous-price'})
    if buvusi_kaina != None:
        buvusi_kaina = buvusi_kaina.text.strip()
    else:
        buvusi_kaina = None
    print(buvusi_kaina)

    specifiacija_keys = []
    specifiacija_values = []
    try:
        specifiacija = bs.find('div', {'class':'PRODUCT_SPEC'}).find_all('li', {'class':'spec-line'})
        for line in specifiacija:
            try:
                spec_key = line.find('span', {'class':'left-column'}).text
                # print(spec_key)
                specifiacija_keys.append(spec_key)
                spec_value = line.find('span', {'class':'right-column'}).text
                # print(spec_value)
                specifiacija_values.append(spec_value)
            except:
                pass
            try:
                spec_key = line.find('div', {'class':'left-column'}).text
                # print(spec_key)
                specifiacija_keys.append(spec_key)
                spec_value = line.find('div', {'class':'right-column'}).text
                # print(spec_value)
                specifiacija_values.append(spec_value)
            except:
                pass
    except:
        pass

    try:
        specifiacija_k = bs.find('div', {'class':'PRODUCT_SPEC'}).find_all('td', {'class':'key'})
        for key in specifiacija_k:
            # print(key.text.strip())
            specifiacija_keys.append(key.text.strip())
        specifiacija_v = bs.find('div', {'class':'PRODUCT_SPEC'}).find_all('td', {'class':'value'})
        for val in specifiacija_v:
            # print(val.text.strip())
            specifiacija_values.append(val.text.strip())       
    except:
        pass

    print(len(specifiacija_keys), specifiacija_keys)
    print(len(specifiacija_values), specifiacija_values)

    spec_filtrai_keys = []
    spec_filtrai_values = []
    try:
        spec_filtai = bs.find('div', {'class':'PRODUCT_SPEC_FILTERS'}).find_all('li', {'class':'spec-line'})
        for line in spec_filtai:
            spec_key = line.find('span', {'class':'left-column'}).text.strip()
            # print(spec_key)
            spec_filtrai_keys.append(spec_key)
            spec_value = line.find('span', {'class':'right-column'}).text.strip()
            # print(spec_value)
            spec_filtrai_values.append(spec_value)
            
        print(len(spec_filtrai_keys), spec_filtrai_keys)
        print(len(spec_filtrai_values), spec_filtrai_values)
    except:
        pass



driver.close()
print('Baigta!!!')
# Out:
# 1 https://www.varle.lt/saldytuvai/saldytuvas-sharp-sj-ftb01itxse-eu--36822303.html
# Šaldytuvas Sharp SJ-FTB01ITXSE-EU
# 229
# 289 €
# 2 ['Gamintojas', 'Modelio pavadinimas']
# 2 ['Sharp', 'SJFTB01ITXSEEU']
# 6 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)']
# 6 ['Sharp', 'Su kamera viršuje', 'Laisvai statomi', 'E', '213.0', '145.0']
# 2 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rr106d4cbe-85cm-juodas--37859978.html
# Šaldytuvas Hisense RR106D4CBE 85cm Juodas
# 169
# 189 €
# 2 ['Gamintojas', 'Modelio pavadinimas']
# 2 ['Hisense', 'RR106D4CBE']
# 7 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Spalva']
# 7 ['Hisense', 'Mini\n\nSu kamera viduje', 'Laisvai statomi', 'E', '82.0', '85.0', 'Juoda']
# 3 https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgn36nwea-2-serija-baltos-spalvos--15912426.html
# Šaldytuvas Bosch KGN36NWEA 2 serija, Baltos spalvos
# 459
# 499 €
# 60 ['Energijos vartojimo efektyvumo klasė (reglamentas (es) 2017/1369)', 'Pagrindinė produkto spalva', 'Automatinis atitirpinimas', 'Ore skleidžiamas akustinis triukšmas', 'Big box', 'Prijungti prietaisai su home connect', 'Ore skleidžiamo akustinio triukšmo klasė', 'Pagrindinė produkto spalva', 'Korpuso spalva / medžiaga', 'Durelių vyris', 'Durelių panelio pakeitimo galimybė', 'Durelių rankenėlės tipas', 'Automatinis atitirpinimas', 'Valdymo nustatymo ir signalizavimo įtaisų tipas', 'Energijos vartojimo efektyvumo klasė (reglamentas (es) 2017/1369)', 'Vidutinės metinės energijos sąnaudos kilovatvalandėmis per metus (kwh/m.)', 'Atšaldymo kamerų tūrių suma', 'Šaldymo temperatūros kamerų tūrių suma', 'Ore skleidžiamas akustinis triukšmas', 'Ore skleidžiamo akustinio triukšmo klasė', 'Klimato klasė', 'Gaminio išmatavimai', 'Minimalus montavimo nišos aukštis', 'Maksimalus montavimo nišos aukštis', 'Mažiausias montavimo angos plotis', 'Didžiausias montavimo angos plotis', 'Montavimo gylis', 'Svoris neto', 'Supercooling', 'Superfreezing', 'Low frost', 'Butelių lentynos tipas', 'Big box', 'Vario zone', 'Easyaccess lentynos', 'Ecomode', 'Pagrindinis jutiklinis valdymas', 'Vario lentyna', 'Itin tylūs prietaisai', 'Lentynėlių skaičius šaldytuvo skyriuje', 'Reguliuojamo aukščio lentynėlių skaičius šaldytuvo skyriuje (vnt)', 'Kiaušinių dėklų skaičius', 'Durų dėžučių skaičius šaldytuvo skyriuje', 'Apšvietimo galingumas - šaldytuvas', 'Klasė žvaigždutėmis', 'Produktų laikymo laikas, nutrūkus elektros tiekimui, (h)', 'Šaldymo stalčių skaičius (vnt)', 'Atsidarančių lentynų skaičius šaldiklyje (vnt)', 'Ledo kubelių šaldymo indų skaičius', 'Prijungti prietaisai su home connect', 'Kamera', 'Energijos suvartojimas išjungtas', 'Energijos suvartojimas budėjimo režimu / įjungtas ekranas', 'Energijos suvartojimas budėjimo režimu / ekranas išjungtas', 'Energijos suvartojimas budėjimo / tinklo režimu (kaip išjungti "wifi" modulį, rasite naudotojo vadove)', 'Automatinio išjungimo laikas', 'Laiko automatinis budėjimo režimas / ekranas įjungtas', 'Laiko automatinis budėjimo / ekrano išjungimas', 'Automatinio budėjimo / tinklo laikas', 'Modelio pavadinimas']
# 60 ['E', 'Baltas', 'Fridge and freezer', '42                  db(a) re 1pw', 'Ne', 'Ne', 'D', 'Baltas', 'Balta', 'Dešinėje, grįžtamasis', 'Negalima', 'Integruota horizontali rankena', 'Fridge and freezer', 'Šaldiklio temperatūra  atidarytų durų signalas  super nustatymas šaldytuvui  įspėjamasis signalas esant trikdžiams  įspėjamoji funkcija šaldiklio skyriui', 'E', '239                  kwh/annum', '216                  l', '89                  l', '42                  db(a) re 1pw', 'D', 'Tropinio  subtropinio  išplėstinė temperatūra  vidutinio klimato', '1860x600x660                   mm', 'Mm', 'Mm', 'Mm', 'Mm', 'Mm', '61,1                  kg', 'Ne', 'Taip', 'Ne', 'Be', 'Ne', 'Ne', 'Ne', 'Ne', 'Ne', 'Ne', 'Ne', '4', '3', '0', '4', 'Šviesos diodas su švelniu paleidimu', '4', '12                  h', '3', '0', '0', 'Ne', 'Ne', 'W', 'W', 'W', 'W', 'Min', 'Min', 'Min', 'Min', '\u200eKGN36NWEA']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['Bsh Fcli Cerkezkoy', 'Su kamera apačioje', 'Laisvai statomi', 'E', '302.0', '186.0', 'Yra', 'Balta']
# 4 https://www.varle.lt/saldytuvai/saldytuvas-haier-hle-172-de--31802747.html
# Šaldytuvas Haier HLE 172 DE
# 479
# 749.99
#  €
# 2 ['Gamintojas', 'Modelio pavadinimas']
# 2 ['Haier', 'HLE172DE']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['Haier', 'Be kameros', 'Įmontuojami', 'F', '316.0', '1.739', 'Nėra', 'Balta']
# 5 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-liebherr-icnd-5103-pure-nofrost--35127654.html
# Įmontuojamas šaldytuvas Liebherr ICNd 5103 Pure NoFrost
# 899
# 1099 €
# 42 ['Gamintojas', 'Šaldiklio stalčių/lentynų skaičius', 'Ledukų generatorius', 'Oro valymo filtras', 'Apšvietimas', 'Naudinga šaldytuvo talpa', 'Svoris', 'Žemiausia darbinė temperatūra', 'Naujoji energijos vartojimo efektyvumo klasė', 'Vėsusis stalčius', 'Greito užšaldymo funkcija šaldiklyje', 'Keičiama durų atidarymo kryptis', 'Atostogų funkcija', 'Gylis', 'Plotis', 'Aukštis', 'Tipas', 'Metinės energijos sąnaudos', 'Minkštas durelių uždarymas', 'Šaldiklio šaldymo temperatūra', 'Butelių lentyna', 'Individualus lentynėlių išdėstymas durelėse', 'Ventiliatorius', 'Montavimo tipas', 'Klimato klasė', 'Dalijama stiklo lentyna', 'Metalizuota galinė sienelė', 'Standartizuotas plotis', 'Greitas vėsinimas šaldytuve', 'Valdymas', 'Atvirų durų signalas', 'Šalčio išlaikymo trukmė šaldiklyje nutrūkus elektros tiekimui', 'Užšaldymo galingumas per 24 val.', 'Spalva', 'Standartizuotas aukštis', 'Šaldymo technologijos tipas', 'Ekonominis režimas', 'Naudinga šaldiklio talpa', 'Vyrių tipas', 'Garso lygio klasė', 'Tiukšmo lygis', 'Modelio pavadinimas']
# 42 ['Liebherr', '3', 'Ne', 'Yra', 'LED', '183', '60.2', '10.0', 'D', 'Ne', 'Yra', 'Yra', 'Yra', '54.6', '55.9', '177.0', 'Šaldytuvas su apatiniu šaldikliu', '181', 'Nėra', '-15°C - -26°C', 'Nėra', 'Nėra', 'Yra', 'Pastatytas', 'SN-T', 'Nėra', 'Nėra', '60.0', 'Yra', 'Internal touch control LCD', 'Yra', '9', '6.0', 'Balta', '180', 'Šalčio nėra', 'Yra', '70', 'Door on door', 'B', '34', 'ICND5103']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['Liebherr', 'Su kamera apačioje', 'Įmontuojami', 'D', '183.0', '177.2', 'Yra', 'Balta']
# 6 https://www.varle.lt/saldytuvai/aeg-imontuojamas-saldytuvas-ske818d1ds-178-cm--31318904.html
# AEG Įmontuojamas šaldytuvas SKE818D1DS, 178 cm
# 899
# 999 €
# 7 ['Gamintojas', 'Gylis [cm]', 'Pakeisti durų atidarymo kryptį', 'Automatinis atitirpinimas', 'Plotis [cm]', 'Aukštis [cm]', 'Modelio pavadinimas']
# 7 ['AEG', '54,9', 'Taip', 'Taip', '54,8', '177,2', 'SKE818D1DS']
# 7 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 7 ['AEG', 'Be kameros', 'Įmontuojami', 'D', '178.0', 'Nėra', 'Balta']
# 7 https://www.varle.lt/saldytuvai/saldytuvas-beko-rcha270k30xbn--24738533.html
# Šaldytuvas BEKO RCHA270K30XBN
# 378.91
# None
# 2 ['Gamintojas', 'Modelio pavadinimas']
# 2 ['Beko', 'RCHA270K30XBN']
# 7 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Spalva']
# 7 ['Beko', 'Su kamera apačioje', 'Laisvai statomi', 'F', '251.0', '170.8', 'Sidabrinė']
# 8 https://www.varle.lt/saldytuvai/imontuojamasis-saldytuvas-bosch-kin86nse0-nofrost--28786311.html
# Įmontuojamasis šaldytuvas Bosch KIN86NSE0 NoFrost
# 777.59
# None
# 57 ['Energijos vartojimo efektyvumo klasė (reglamentas (es) 2017/1369)', 'Automatinis atitirpinimas', 'Ore skleidžiamas akustinis triukšmas', 'Big box', 'Prijungti prietaisai su home connect', 'Ore skleidžiamo akustinio triukšmo klasė', 'Durelių vyris', 'Durelių panelio pakeitimo galimybė', 'Vyrių tipas', 'Automatinis atitirpinimas', 'Valdymo nustatymo ir signalizavimo įtaisų tipas', 'Energijos vartojimo efektyvumo klasė (reglamentas (es) 2017/1369)', 'Vidutinės metinės energijos sąnaudos kilovatvalandėmis per metus (kwh/m.)', 'Atšaldymo kamerų tūrių suma', 'Šaldymo temperatūros kamerų tūrių suma', 'Ore skleidžiamas akustinis triukšmas', 'Ore skleidžiamo akustinio triukšmo klasė', 'Klimato klasė', 'Integruoti priedai', 'Gaminio išmatavimai', 'Minimalus montavimo nišos aukštis', 'Maksimalus montavimo nišos aukštis', 'Mažiausias montavimo angos plotis', 'Didžiausias montavimo angos plotis', 'Montavimo gylis', 'Svoris neto', 'Supercooling', 'Superfreezing', 'Low frost', 'Big box', 'Vario zone', 'Easyaccess lentynos', 'Ecomode', 'Pagrindinis jutiklinis valdymas', 'Vario lentyna', 'Itin tylūs prietaisai', 'Lentynėlių skaičius šaldytuvo skyriuje', 'Reguliuojamo aukščio lentynėlių skaičius šaldytuvo skyriuje (vnt)', 'Kiaušinių dėklų skaičius', 'Durų dėžučių skaičius šaldytuvo skyriuje', 'Apšvietimo galingumas - šaldytuvas', 'Klasė žvaigždutėmis', 'Produktų laikymo laikas, nutrūkus elektros tiekimui, (h)', 'Šaldymo stalčių skaičius (vnt)', 'Atsidarančių lentynų skaičius šaldiklyje (vnt)', 'Ledo kubelių šaldymo indų skaičius', 'Prijungti prietaisai su home connect', 'Kamera', 'Energijos suvartojimas išjungtas', 'Energijos suvartojimas budėjimo režimu / įjungtas ekranas', 'Energijos suvartojimas budėjimo režimu / ekranas išjungtas', 'Energijos suvartojimas budėjimo / tinklo režimu (kaip išjungti "wifi" modulį, rasite naudotojo vadove)', 'Automatinio išjungimo laikas', 'Laiko automatinis budėjimo režimas / ekranas įjungtas', 'Laiko automatinis budėjimo / ekrano išjungimas', 'Automatinio budėjimo / tinklo laikas', 'Modelio pavadinimas']
# 57 ['E', 'Bešerkšnis no frost', '35                  db(a) re 1pw', 'Ne', 'Ne', 'B', 'Dešinėje, grįžtamasis', 'Negalima', 'Slankiojantis vyris', 'Bešerkšnis no frost', 'Atidarytų durų signalas  super nustatymas šaldytuvui  super nustatymas šaldytuvui  įspėjamoji funkcija šaldiklio skyriui', 'E', '234                  kwh/annum', '184                  l', '76                  l', '35                  db(a) re 1pw', 'B', 'Subtropinio  išplėstinė temperatūra  vidutinio klimato', '3 x dėklas kiaušiniams, 1 x ledo kubelių forma', '1772x541x548                   mm', '1775                  mm', '1775                  mm', '560                  mm', '560                  mm', '550                  mm', '51,2                  kg', 'Taip', 'Taip', 'Ne', 'Ne', 'Ne', 'Ne', 'Ne', 'Ne', 'Ne', 'Ne', '4', '3', '3', '3', 'Led', '4', '10                  h', '3', '0', '1', 'Ne', 'Ne', 'W', 'W', 'W', 'W', 'Min', 'Min', 'Min', 'Min', 'KIN86NSE0']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['Bosch', 'Su kamera apačioje', 'Įmontuojami', 'E', '76.0', '177.0', 'Yra', 'Balta']
# 9 https://www.varle.lt/saldytuvai/saldytuvas-mpm-90-cj-27--38277846.html
# Šaldytuvas MPM-90-CJ-27
# 116.99
# None
# 16 ['Gamintojas', 'Modelis', 'Produkto spalva', 'Water-dispenser', 'Fridge-number-of-shelvesbaskets', 'Recessed-handles', 'Anti-bacterial-compartment', 'Lentynos-medžiaga', 'Durų rankena', 'Apverčiamos durys', 'Durų skaičius', 'Prietaisų išdėstymas', 'Fridge-door-balconies', 'Prekės ženklas', 'Integruotas ekranas', 'Modelio pavadinimas']
# 16 ['MPM', '5903151032416', 'Balta', 'Ne', '3', 'Taip', 'Ne', 'stiklas', 'Dešinė', 'Taip', '1 durys', 'Integruota', '3', 'MPM', 'Ne', 'MPM90CJ27']
# 6 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Aukštis (cm)', 'Spalva']
# 6 ['MPM', 'Be kameros', 'Įmontuojami', 'E', '85.0', 'Balta']
# 10 https://www.varle.lt/saldytuvai/marshall-fridge-black-edition-32-92l-vidutines--17311967.html
# Marshall Fridge Black Edition 3.2, 92L, Vidutinės talpos šaldytuvas
# 275.99
# None
# 4 ['Gamintojas', 'Modelis', 'Svoris', 'Modelio pavadinimas']
# 4 ['Marshall', 'MF3.2BLK-EU', '21', 'MF3.2BLK-EU']
# 7 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Spalva']
# 7 ['Marshall', 'Be kameros', 'Laisvai statomi', 'F', '92.0', '82.7', 'Juoda']
# 11 https://www.varle.lt/saldytuvai/saldytuvas-sharp-sjfbb04dtxleeu--36352485.html
# Šaldytuvas SHARP SJFBB04DTXLEEU
# 299.99
# 359.99
#  €
# 20 ['Gamintojas', 'Modelis', 'Spalva', 'Aukštis', 'Technologija', 'Triukšmo klasė', 'Energijos žyma', 'Užšaldymo galia', 'Šaldytuvo atitirpinimas', 'Tipas', 'Konstrukcija', 'Šaldiklio atitirpinimas', 'Šaldytuvo talpa', 'Gylis', 'Šaldiklio talpa', 'Ekranas / Valdymo skydelis', 'Plotis', 'Svoris', 'Dydžio_klasė', 'Modelio pavadinimas']
# 20 ['Sharp', '04', 'Nerūdijantis plienas', '170', 'NanoFrost', 'C', 'parsisiųsti', '3.9', 'Automatiškai', 'Laisvai pastatomas', 'Šaldiklis apačioje', 'Automatiškai', '184', '59.5', '84', 'Ne', '54', '51.000', 'gab_0002', 'SJFBB04DTXLEEU']
# 7 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Spalva']
# 7 ['Sharp', 'Su kamera apačioje', 'Laisvai statomi', 'E', '184.0', '170.0', 'Sidabrinė']
# 12 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-rb492pw--30151495.html
# Šaldytuvas Gorenje RB492PW
# 194.99
# 219.99
#  €
# 31 ['Bendras svoris', 'Grynas (neto) svoris', 'Gamintojas', 'Modelio pavadinimas', 'Gamintojo prekės serija', 'Maksimalus triukšmo lygis', 'Klimato klasė', 'Bendra talpa neto', 'Šaldymo kameros talpa neto', 'Bešerkšnė sistema', 'Šaldytuvo talpa neto', 'Vandens padavimo įtaisas', 'Garsumo klasė', 'Gaminio tipas', 'Energijos efektyvumo klasė', 'Įtampa', 'Lempos tipas', 'Gaminio spalva', 'Reversinės durys', 'Tipas', 'Kompresorių kiekis', 'Vidinis apšvietimas', 'Valdymo tipas', 'Įvertinimas žvaigždutėmis', 'Šaldiklio padėtis', 'Šaldytuvo atitirpinimo funkcija', 'Ekranas', 'Plotis', 'Aukštis', 'Gylis', 'Modelio pavadinimas']
# 31 ['30.50 kg', '28.00 kg', 'Gorenje', 'Rb492pw', 'Šaldytuvas', '40 db', 'n, st, t', '120 l', '13 l', 'Ne', '107 l', 'Ne', 'C', 'Free standing', 'E', '220-240 v', 'Led', 'Balta', 'Taip', 'Larder', '1', 'Taip', 'Mechaninis', '4', 'Inside', 'Rankinis', 'Ne', '56 cm', '84.5 cm', '57.9 cm', 'RB492PW']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['Gorenje', 'Su kamera viduje', 'Laisvai statomi', 'E', '107.0', '84.5', 'Nėra', 'Balta']
# 13 https://www.varle.lt/saldytuvai/bosch-bsh-fclg-giengen-serija-2-imontuojamasis-saldytuvas--35653463.html
# Bosch Bsh Fclg Giengen Serija 2, Įmontuojamasis šaldytuvas, 177.5 x 56 cm, slankiojantis vyris KIR815SE0
# 685.26
# None
# 49 ['Energijos vartojimo efektyvumo klasė (reglamentas (es) 2017/1369)', 'Automatinis atitirpinimas', 'Ore skleidžiamas akustinis triukšmas', 'Prijungti prietaisai su home connect', 'Ore skleidžiamo akustinio triukšmo klasė', 'Durelių vyris', 'Durelių panelio pakeitimo galimybė', 'Vyrių tipas', 'Durelių rankenėlės tipas', 'Valdymo nustatymo ir signalizavimo įtaisų tipas', 'Energijos vartojimo efektyvumo klasė (reglamentas (es) 2017/1369)', 'Vidutinės metinės energijos sąnaudos kilovatvalandėmis per metus (kwh/m.)', 'Atšaldymo kamerų tūrių suma', 'Šaldymo temperatūros kamerų tūrių suma', 'Ore skleidžiamas akustinis triukšmas', 'Ore skleidžiamo akustinio triukšmo klasė', 'Klimato klasė', 'Integruoti priedai', 'Gaminio išmatavimai', 'Minimalus montavimo nišos aukštis', 'Maksimalus montavimo nišos aukštis', 'Mažiausias montavimo angos plotis', 'Didžiausias montavimo angos plotis', 'Montavimo gylis', 'Svoris neto', 'Supercooling', 'Vario zone', 'Easyaccess lentynos', 'Ecomode', 'Pagrindinis jutiklinis valdymas', 'Vario lentyna', 'Itin tylūs prietaisai', 'Lentynėlių skaičius šaldytuvo skyriuje', 'Reguliuojamo aukščio lentynėlių skaičius šaldytuvo skyriuje (vnt)', 'Kiaušinių dėklų skaičius', 'Durų dėžučių skaičius šaldytuvo skyriuje', 'Apšvietimo galingumas - šaldytuvas', 'Klasė žvaigždutėmis', 'Produktų laikymo laikas, nutrūkus elektros tiekimui, (h)', 'Prijungti prietaisai su home connect', 'Energijos suvartojimas išjungtas', 'Energijos suvartojimas budėjimo režimu / įjungtas ekranas', 'Energijos suvartojimas budėjimo režimu / ekranas išjungtas', 'Energijos suvartojimas budėjimo / tinklo režimu (kaip išjungti "wifi" modulį, rasite naudotojo vadove)', 'Automatinio išjungimo laikas', 'Laiko automatinis budėjimo režimas / ekranas įjungtas', 'Laiko automatinis budėjimo / ekrano išjungimas', 'Automatinio budėjimo / tinklo laikas', 'Modelio pavadinimas']
# 49 ['E', 'Ne', '35                  db(a) re 1pw', 'Ne', 'B', 'Dešinėje, grįžtamasis', 'Negalima', 'Slankiojantis vyris', 'Nėra rankenos', 'Atidarytų durų signalas  super nustatymas šaldytuvui', 'E', '114                  kwh/annum', '310                  l', '0                  l', '35                  db(a) re 1pw', 'B', 'Subtropinio  išplėstinė temperatūra  vidutinio klimato', '1 x lėkštutė sviestui, 3 x dėklas kiaušiniams', '1772x541x548                   mm', '1775                  mm', '1775                  mm', '560                  mm', '560                  mm', '550                  mm', '50,5                  kg', 'Taip', 'Ne', 'Ne', 'Ne', 'Ne', 'Ne', 'Ne', '6', '5', '3', '5', 'Led', 'Ne', 'H', 'Ne', 'W', 'W', 'W', 'W', 'Min', 'Min', 'Min', 'Min', 'KIR815SE0']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['Bosch', 'Be kameros', 'Įmontuojami', 'E', '310.0', '177.2', 'Nėra', 'Balta']
# 14 https://www.varle.lt/saldytuvai/saldytuvas-saldiklis-mpm-108-kb-44--37708044.html
# šaldytuvas-šaldiklis MPM-108-KB-44
# 219.99
# 245.99
#  €
# 23 ['Gamintojas', 'Modelis', 'Kontrolė', 'Svoris', 'Spalva', 'Aukštis', 'Technologija', 'Triukšmo klasė', 'Energijos žyma', 'Užšaldymo galia', 'Šaldytuvo atitirpinimas', 'Tipas', 'Šaldiklio temperatūra', 'Konstrukcija', 'Šaldiklio atitirpinimas', 'Vienetų skaičius', 'Šaldytuvo talpa', 'Gylis', 'Šaldiklio talpa', 'Ekranas / Valdymo skydelis', 'Plotis', 'Dydžio_klasė', 'Modelio pavadinimas']
# 23 ['MPM', '10844', 'Mechaninis', '28', 'Juoda', '114', 'Ne', 'C', 'parsisiųsti', '2.2', 'Automatiškai', 'Laisvai pastatomas', '-18', 'Šaldiklis apačioje', 'Rankinis', '1', '72', '49', '36', 'taip', '48', 'gab_0001', 'MPM108KB44']
# 6 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Spalva']
# 6 ['MPM', 'Su kamera apačioje', 'Laisvai statomi', 'E', '72.0', 'Juoda']
# 15 https://www.varle.lt/saldytuvai/liebherr-saldytuvas-ire-5100--16581553.html
# LIEBHERR IRe 5100 Įmontuojamas šaldytuvas
# 899
# 999 €
# 33 ['Gamintojas', 'Naudinga šaldytuvo talpa', 'Oro valymo filtras', 'Svoris', 'Naujoji energijos vartojimo efektyvumo klasė', 'Apšvietimas', 'Vėsusis stalčius', 'Drėgmės išlaikymo technologija', 'Keičiama durų atidarymo kryptis', 'Gylis', 'Aukštis', 'Metinės energijos sąnaudos', 'Minkštas durelių uždarymas', 'Individualus lentynėlių išdėstymas durelėse', 'Ventiliatorius', 'Montavimo tipas', 'Klimato klasė', 'Metalizuota galinė sienelė', 'Greitas vėsinimas šaldytuve', 'Valdymas', 'Atvirų durų signalas', 'Spalva', 'Standartizuotas aukštis', 'Šaldymo technologijos tipas', 'Ekonominis režimas', 'Vyrių tipas', 'Reguliuojamos drėgmės vaisių/daržovių stalčius', 'Tipas', 'Tiukšmo lygis', 'Garso lygio klasė', 'Standartizuotas plotis', 'Plotis', 'Modelio pavadinimas']
# 33 ['Liebherr', '309', 'Yra', '54.5', 'IR', 'LED', 'Ne', 'Yra', 'Yra', '55.0', '177.2', '114', 'Nėra', 'Nėra', 'Nėra', 'Pastatytas', 'SN-T', 'Nėra', 'Nėra', 'Internal touch control LCD', 'Nėra', 'Balta', '180', 'statinis', 'Nėra', 'Door on door', 'Nėra', 'Fridge without freezer', '35', 'B', '60.0', '56.0', 'IRE5100']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['Liebherr', 'Be kameros', 'Įmontuojami', 'E', '309.0', '177.2', 'Nėra', 'Balta']
# 16 https://www.varle.lt/saldytuvai/samsung-saldytuvas-brb26705ewwef--15968513.html
# Šaldytuvas Samsung BRB26705EWW/EF
# 559.99
# 639.99
#  €
# 22 ['Gamintojas', 'Šaldytuvo tipas', 'Ledų gaminimo aparatas', 'Bruto svoris (pakuotė kg)', 'Metinis energijos suvartojimas (kWh)', 'Gylis (cm)', 'Svoris (kg)', 'Door installation method', 'Aukštis (cm)', 'Lentynų medžiaga', 'Total volume, net (l)', 'Cooling chamber volume, net (l)', 'Freezer volume, net (l)', 'Plotis (cm)', 'Užšaldymo pajėgumas (kg/24h)', 'Triukšmo lygis (dB)', 'Ypatumai', 'Atitirpinimo metodas', 'Veikimo trukmė dingus elektrai', 'Apšvietimo tipas', 'Noise level (class)', 'Modelio pavadinimas']
# 22 ['Samsung', 'Su šaldikliu apačioje', '+', '72', '231', '55', '69,5', 'On rails', '177,5', 'glass shelves', '267', '193', '74', '54', '4', '35', 'All-Around Cooling süsteem, SpaceMax tehnoloogia, metallist jahutusplaat, mahutab rohkem ukseriiulitele, digitaalne inverterkompressor, kiirjahutus, Fresh Zone', 'Nereikalaujantis atitirpdymų', '6', 'LED', 'B', 'BRB26705EWWEF']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['Samsung', 'Su kamera apačioje', 'Įmontuojami', 'E', '267.0', '177.5', 'Yra', 'Balta']
# 17 https://www.varle.lt/saldytuvai/saldytuvas-whirlpool-whc20-t573--16142970.html
# Šaldytuvas Whirlpool WHC20 T573
# 721.36
# 759.99
#  €
# 3 ['Gamintojas', 'Modelis', 'Modelio pavadinimas']
# 3 ['Whirlpool', 'WH215', 'WHC20T573']
# 7 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Spalva']
# 7 ['Whirlpool', 'Su kamera apačioje', 'Įmontuojami', 'D', '68.0', '194.0', 'Balta']
# 18 https://www.varle.lt/saldytuvai/gorenje-saldytuvas-saldiklis-nrk620ca2xl4--33990406.html
# Gorenje šaldytuvas-šaldiklis nrk620ca2xl4
# 639.99
# 699.99
#  €
# 23 ['Gamintojas', 'Modelis', 'Dydžio_klasė', 'Kontrolė', 'Svoris', 'Spalva', 'Aukštis', 'Technologija', 'Triukšmo klasė', 'Energijos žyma', 'Užšaldymo galia', 'Šaldytuvo atitirpinimas', 'Tipas', 'Konstrukcija', 'Saugojimas be maitinimo šaltinio', 'Šaldiklio atitirpinimas', 'Vienetų skaičius', 'Šaldytuvo talpa', 'Gylis', 'Šaldiklio talpa', 'Ekranas / Valdymo skydelis', 'Plotis', 'Modelio pavadinimas']
# 23 ['Gorenje', '743233', 'gab_0002', 'Elektroninė', '64', 'pilka', '200', 'No Frost Plus', 'B', 'parsisiųsti', '10', 'Automatiškai', 'Laisvai pastatomas', 'Šaldiklis apačioje', '10', 'Automatiškai', '1', '235', '59.2', '96', 'Taip', '60', 'NRK620CA2XL4']
# 7 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Bešerkšnė sistema', 'Spalva']
# 7 ['Gorenje', 'Su kamera apačioje', 'Laisvai statomi', 'C', '235.0', 'Yra', 'Pilka']
# 19 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-whirlpool-sp40-812-eu-2--35817045.html
# Įmontuojamas šaldytuvas Whirlpool SP40 812 EU 2
# 829.19
# 869.99
#  €
# 18 ['Gamintojas', 'Aukštis (cm)', 'Šaldytuvo tipas', 'Cooling chamber volume, net (l)', 'Atitirpinimo metodas', 'Spalva', 'Metinis energijos suvartojimas (kWh)', 'Freezer volume, net (l)', 'Gylis (cm)', 'Apšvietimo tipas', 'Plotis (cm)', 'Užšaldymo pajėgumas (kg/24h)', 'Veikimo trukmė dingus elektrai', 'Triukšmo lygis (dB)', 'Ypatumai', 'Total volume, net (l)', 'Noise level (class)', 'Modelio pavadinimas']
# 18 ['Whirlpool', '193,5', 'Su šaldikliu apačioje', '299', 'Nereikalaujantis atitirpdymų', 'Balta', '248', '101', '54,5', 'LED', '69', '8,5', '28', '335', '6th Sense Fresh Control, kiire jahutamine', '400', 'B', 'SP40812EU2']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['Whirlpool', 'Su kamera apačioje', 'Įmontuojami', 'E', '400.0', '193.5', 'Yra', 'Balta']
# 20 https://www.varle.lt/saldytuvai/saldytuvas-bosch-kgn33nleb-ekspozicine-preke--40739823.html
# Šaldytuvas Bosch KGN33NLEB (Ekspozicinė prekė)
# 430
# 489 €
# 60 ['Energijos vartojimo efektyvumo klasė (reglamentas (es) 2017/1369)', 'Pagrindinė produkto spalva', 'Automatinis atitirpinimas', 'Ore skleidžiamas akustinis triukšmas', 'Big box', 'Prijungti prietaisai su home connect', 'Ore skleidžiamo akustinio triukšmo klasė', 'Pagrindinė produkto spalva', 'Durelių vyris', 'Durelių panelio pakeitimo galimybė', 'Durelių rankenėlės tipas', 'Automatinis atitirpinimas', 'Valdymo nustatymo ir signalizavimo įtaisų tipas', 'Energijos vartojimo efektyvumo klasė (reglamentas (es) 2017/1369)', 'Vidutinės metinės energijos sąnaudos kilovatvalandėmis per metus (kwh/m.)', 'Atšaldymo kamerų tūrių suma', 'Šaldymo temperatūros kamerų tūrių suma', 'Ore skleidžiamas akustinis triukšmas', 'Ore skleidžiamo akustinio triukšmo klasė', 'Klimato klasė', 'Integruoti priedai', 'Gaminio išmatavimai', 'Minimalus montavimo nišos aukštis', 'Maksimalus montavimo nišos aukštis', 'Mažiausias montavimo angos plotis', 'Didžiausias montavimo angos plotis', 'Montavimo gylis', 'Svoris neto', 'Supercooling', 'Superfreezing', 'Low frost', 'Butelių lentynos tipas', 'Big box', 'Vario zone', 'Easyaccess lentynos', 'Ecomode', 'Pagrindinis jutiklinis valdymas', 'Vario lentyna', 'Itin tylūs prietaisai', 'Lentynėlių skaičius šaldytuvo skyriuje', 'Reguliuojamo aukščio lentynėlių skaičius šaldytuvo skyriuje (vnt)', 'Kiaušinių dėklų skaičius', 'Durų dėžučių skaičius šaldytuvo skyriuje', 'Apšvietimo galingumas - šaldytuvas', 'Klasė žvaigždutėmis', 'Produktų laikymo laikas, nutrūkus elektros tiekimui, (h)', 'Šaldymo stalčių skaičius (vnt)', 'Atsidarančių lentynų skaičius šaldiklyje (vnt)', 'Ledo kubelių šaldymo indų skaičius', 'Prijungti prietaisai su home connect', 'Kamera', 'Energijos suvartojimas išjungtas', 'Energijos suvartojimas budėjimo režimu / įjungtas ekranas', 'Energijos suvartojimas budėjimo režimu / ekranas išjungtas', 'Energijos suvartojimas budėjimo / tinklo režimu (kaip išjungti "wifi" modulį, rasite naudotojo vadove)', 'Automatinio išjungimo laikas', 'Laiko automatinis budėjimo režimas / ekranas įjungtas', 'Laiko automatinis budėjimo / ekrano išjungimas', 'Automatinio budėjimo / tinklo laikas', 'Modelio pavadinimas']
# 60 ['E', 'Inox-look', 'Fridge and freezer', '42                  db(a) re 1pw', 'Ne', 'Ne', 'D', 'Inox-look', 'Dešinėje, grįžtamasis', 'Negalima', 'Integruota horizontali rankena', 'Fridge and freezer', 'Šaldiklio temperatūra  atidarytų durų signalas  super nustatymas šaldytuvui  įspėjamasis signalas esant trikdžiams  įspėjamoji funkcija šaldiklio skyriui', 'E', '237                  kwh/annum', '193                  l', '89                  l', '42                  db(a) re 1pw', 'D', 'Tropinio  subtropinio  išplėstinė temperatūra  vidutinio klimato', '3 x dėklas kiaušiniams', '1760x600x660                   mm', 'Mm', 'Mm', 'Mm', 'Mm', 'Mm', '57,1                  kg', 'Ne', 'Taip', 'Ne', 'Be', 'Ne', 'Ne', 'Ne', 'Ne', 'Ne', 'Ne', 'Ne', '3', '2', '3', '3', 'Šviesos diodas su švelniu paleidimu', '4', '12                  h', '3', '0', '0', 'Ne', 'Ne', 'W', 'W', 'W', 'W', 'Min', 'Min', 'Min', 'Min', 'KGN33NLEB']
# 1 ['Gamintojas']
# 1 ['Bosch']
# 21 https://www.varle.lt/saldytuvai/gorenje-saldytuvas-nrk6202aw4-energy-efficiency--18802196.html
# Gorenje | Šaldytuvas | NRK6202AW4 | Energy efficiency class E | Free standing | Combi | Height 200 cm | No Frost system | Šaldytuvas net capacity 235 L | Šaldiklis net capacity 96 L | Ekranas | 38 dB | Baltas
# 519.99
# 703.36
#  €
# 49 ['Bendras svoris', 'Grynas (neto) svoris', 'Rankenėlė(-s)', 'Gamintojas', 'Modelio pavadinimas', 'Gamintojo prekės serija', 'Šaldiklio padėtis', 'Laikymo trukmė sutrikus maitinimui', 'Daugiafunkcė oro srauto sistema (šaldiklio)', 'Šaldiklio lentynų/stalčių skaičius', 'Lentynų medžiaga', 'Gaminio spalva', 'Reversinės durys', 'Tipas', 'Durelių lentynėlės', 'Durų skaičius', 'Durų vyris', 'Butelių stovas', 'Vidinis apšvietimas', 'Valdymo tipas', 'Lempos tipas', 'Šaldytuvo lentynų/krepšelių skaičius', 'Šviežių produktų zonos skyrius', 'Ledukų gaminimo aparatas', 'Bešerkšnė sistema', 'Šaldytuvo talpa neto', 'Vandens padavimo įtaisas', 'Šaldymo pajėgumas', 'Termostatas', 'Gaminio tipas', 'Maksimalus triukšmo lygis', 'Klimato klasė', 'Bendra talpa neto', 'Šaldymo kameros talpa neto', 'Bendra talpa bruto', 'Garsumo klasė', 'Daugiafunkcė oro srauto sistema (šaldytuvo)', 'Šaldytuvo vidaus lemputė', 'Dregmės reguliavimas', 'Įvertinimas žvaigždutėmis', 'Specialios funkcijos', 'Plotis', 'Aukštis', 'Gylis', 'Energijos efektyvumo klasė', 'Energijos suvartojimas per metus', 'Atidarytų durų įspėjamasis signalas', 'Ekranas', 'Modelio pavadinimas']
# 49 ['65.00 kg', '63.00 kg', 'Pocket', 'Gorenje', 'Nrk6202aw4', 'Šaldytuvas', 'Apačioje', '17 h', 'Taip', '3', 'Stiklas', 'Balta', 'Taip', 'Combi', '4', '2', 'Standartas', 'Taip', 'Taip', 'Touch', 'Led', '5 shelves', 'Taip', 'Ne', 'Taip', '235 l', 'Ne', '12 kg/24h', 'Taip', 'Free standing', '38 db', 'Sn, n, st, t', '331 l', '96 l', '353 l', 'C', 'Taip', 'Taip', 'Taip', '4*', 'Adapttech: adaptive intelligent system; fastfreeze; no frost system; ionair with multiflow 360°.', '60 cm', '200 cm', '59.2 cm', 'E', '246 kwh', 'Taip', 'Taip', 'NRK6202AW4']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['Gorenje', 'Su kamera apačioje', 'Laisvai statomi', 'E', '331.0', '200.0', 'Yra', 'Balta']
# 22 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-nrk6182ps4--16731705.html
# Šaldytuvas Gorenje NRK6182PS4
# 439.89
# 660.90
#  €
# 33 ['Bendras svoris', 'Grynas (neto) svoris', 'Gamintojas', 'Modelio pavadinimas', 'Gamintojo prekės serija', 'Energijos suvartojimas per metus', 'Energijos efektyvumo klasė', 'Maksimalus triukšmo lygis', 'Bendra talpa neto', 'Šaldymo kameros talpa neto', 'Bešerkšnė sistema', 'Šaldytuvo talpa neto', 'Vandens padavimo įtaisas', 'Garsumo klasė', 'Gaminio tipas', 'Įvertinimas žvaigždutėmis', 'Atidarytų durų įspėjamasis signalas', 'Reguliuojama kojelė', 'Šaldiklio atitirpinimo funkcija', 'Šaldiklio padėtis', 'Ekrano tipas', 'Lentynų medžiaga', 'Gaminio spalva', 'Reversinės durys', 'Tipas', 'Durų skaičius', 'Kompresorių kiekis', 'Šaldytuvo atitirpinimo funkcija', 'Ekranas', 'Plotis', 'Aukštis', 'Gylis', 'Modelio pavadinimas']
# 33 ['62.00 kg', '57.00 kg', 'Gorenje', 'Nrk6182ps4', 'Šaldytuvas', '235 kwh', 'E', '39 db', '292 l', '85 l', 'Taip', '207 l', 'Ne', 'C', 'Free standing', '4', 'Ne', 'Taip', 'Automatiškai', 'Apačioje', 'Led', 'Stiklas', 'Pilka', 'Taip', 'Combi', '2', '1', 'Automatiškai', 'Taip', '59.5 cm', '178.5 cm', '59 cm', 'NRK6182PS4']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['Gorenje', 'Su kamera apačioje', 'Laisvai statomi', 'E', '207.0', '178.5', 'Yra', 'Pilka']
# 23 https://www.varle.lt/saldytuvai/built-in-saldytuvas-whirlpool-194cm-nf--18106310.html
# Whirlpool Šaldytuvas-šaldiklis WHC20 T573 P
# 789
# 849.99
#  €
# 29 ['Gamintojas', 'Modelis', 'Šaldymo skyriaus vieta', 'Spalva', 'Priedai', 'Aukštis', 'Durelių atidarymas', 'Energijos sąnaudos', 'Šaldymo kameros atitirpinimo metodas', 'Šaldytuvo tipas', 'Šaldytuvo skyriaus talpa', 'Šaldiklio talpa', 'Durų surinkimas', 'Ore sklindančio akustinio triukšmo įvertinimas', 'Montavimo tipas', 'Šaldytuvo skyriaus atšildymo metodas', 'Plotis', 'Laikymo trukmė gedimų metu', 'Durų kiekis', 'Bendra talpa', 'Šaldiklio žvaigždutės', 'Reglamento numeris', 'Gylis', 'Vandens jungtis', 'Ekranas', 'Papildomos funkcijos', 'Užšaldymo galia', 'Triukšmo galia', 'Modelio pavadinimas']
# 29 ['Whirlpool', 'WHC20T573P', 'Apačioje', 'Pilnai įmontuojama', 'Butelių laikiklis', '193.5', 'Į dešinę', '177.0', 'Automatiškai', 'Šaldytuvas', '212.0', '68.0', 'ant bėgių', 'B', 'Integruota', 'Automatiškai', '54.0', '6.0', 'dvejos durys', '280.0', '[ * ] * * *', '2019/2016', '54.5', 'nėra ryšio', 'simbolis', 'humidity control, LED light, "Push to open" function', '7.0', '32.0', 'WHC20T573P']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['Whirlpool', 'Su kamera apačioje', 'Įmontuojami', 'D', '280.0', '194.0', 'Yra', 'Balta']
# 24 https://www.varle.lt/saldytuvai/saldytuvas-beko-b3rcna404hw--22054518.html
# Šaldytuvas BEKO B3RCNA404HW
# 519.99
# 732.32
#  €
# 14 ['Gamintojas', 'Modelis', 'Atsargos', 'Svoris', 'Spalva', 'Aukštis', 'Technologija', 'Dizaino savybės', 'Plotis', 'Galingumas', 'Konstrukcija', 'Gylis', 'Tipas', 'Modelio pavadinimas']
# 14 ['Beko', 'B3RCNA404HW', '0', '76.100 kg', 'Balta', '2035 mm', '', '', '595 mm', '', 'Laisvai pastatoma', '663 mm', 'Šaldytuvas-Šaldytuvas', 'B3RCNA404HW']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['Beko', 'Su kamera apačioje', 'Laisvai statomi', 'E', '355.0', '203.5', 'Yra', 'Balta']
# 25 https://www.varle.lt/saldytuvai/lg-saldytuvas-gbv3200dpy-energy-efficiency-class--31030911.html
# LG | Šaldytuvas | GBV3200DPY | Energy efficiency class D | Free standing | Combi | Height 203 cm | No Frost system | Šaldytuvas net capacity 277 L | Šaldiklis net capacity 110 L | Ekranas | 35 dB | Sidabrinis
# 547.98
# 615.99
#  €
# 18 ['Gamintojas', 'Aukštis (cm)', 'Šaldytuvo tipas', 'Cooling chamber volume, net (l)', 'Bruto svoris (pakuotė kg)', 'Atitirpinimo metodas', 'Spalva', 'Metinis energijos suvartojimas (kWh)', 'Freezer volume, net (l)', 'Gylis (cm)', 'Apšvietimo tipas', 'Plotis (cm)', 'Triukšmo lygis (dB)', 'Svoris (kg)', 'Total volume, net (l)', 'Noise level (class)', 'Ypatumai', 'Modelio pavadinimas']
# 18 ['LG', '203', 'Su šaldikliu apačioje', '277', '81', 'Nereikalaujantis atitirpdymų', 'Sidabrinė', '217', '110', '68,2', 'LED', '59,5', '35', '78', '387', 'B', 'NatureFRESH™, LinearCooling™, DoorCooling+™, Multi Air Flow', 'GBV3200DPY']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['LG', 'Su kamera apačioje', 'Laisvai statomi', 'D', '387.0', '203.0', 'Yra', 'Sidabrinė']
# 26 https://www.varle.lt/saldytuvai/saldytuvas-gotie-glz-85b--30323188.html
# Šaldytuvas Gotie GLZ-85B
# 189.99
# 229.99
#  €
# 22 ['Gamintojas', 'Modelis', 'Kontrolė', 'Svoris', 'Spalva', 'Aukštis', 'Technologija', 'Triukšmo klasė', 'Energijos žyma', 'Užšaldymo galia', 'Šaldytuvo atitirpinimas', 'Tipas', 'Konstrukcija', 'Šaldiklio atitirpinimas', 'Vienetų skaičius', 'Šaldytuvo talpa', 'Gylis', 'Šaldiklio talpa', 'Ekranas / Valdymo skydelis', 'Plotis', 'Dydžio_klasė', 'Modelio pavadinimas']
# 22 ['Gotie', '85', 'Mechaninis', '30', 'Balta', '84', 'Ne', 'C', 'parsisiųsti', '2', 'Rankinis', 'Laisvai pastatomas', 'viršutinis šaldiklis', 'Rankinis', '1', '60', '48.6', '26', 'taip', '53.6', 'gab_0002', 'GLZ85B']
# 6 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Spalva']
# 6 ['Gotie', 'Su kamera viršuje', 'Laisvai statomi', 'F', '60.0', 'Balta']
# 27 https://www.varle.lt/saldytuvai/saldytuvas-lg-gbv5240dep--31078155.html
# Šaldytuvas LG GBV5240DEP
# 589.99
# 645.99
#  €
# 15 ['Gamintojas', 'Modelis', 'Elemento tipas', 'Atsargos', 'Svoris', 'Spalva', 'Aukštis', 'Technologija', 'Plotis', 'Tipas', 'Galingumas', 'Konstrukcija', 'Dizaino savybės', 'Gylis', 'Modelio pavadinimas']
# 15 ['LG', 'GBV5240DEP', 'Atsargos', '0', '78.000 kg', 'Juoda', '2030 mm', '', '595 mm', 'Šaldytuvas-Šaldytuvas', 'Annual power consumption: 21.7 kWh', 'Laisvai pastatoma', '', '682 mm', 'GBV5240DEP']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['LG', 'Su kamera apačioje', 'Laisvai statomi', 'D', '387.0', '203.0', 'Yra', 'Juoda']
# 28 https://www.varle.lt/saldytuvai/polar-saldytuvas-saldiklis-pob602ek-netnet--34472245.html
# Polar šaldytuvas-šaldiklis POB602EK NetNet
# 305.99
# 349.99
#  €
# 22 ['Gamintojas', 'Modelis', 'Kontrolė', 'Svoris', 'Spalva', 'Aukštis', 'Technologija', 'Triukšmo klasė', 'Energijos žyma', 'Užšaldymo galia', 'Šaldytuvo atitirpinimas', 'Tipas', 'Konstrukcija', 'Šaldiklio atitirpinimas', 'Vienetų skaičius', 'Šaldytuvo talpa', 'Gylis', 'Šaldiklio talpa', 'Ekranas / Valdymo skydelis', 'Plotis', 'Dydžio_klasė', 'Modelio pavadinimas']
# 22 ['Polar', '602', 'Elektroninė', '53', 'Juoda', '158.8', 'Ne', 'C', 'parsisiųsti', '4', 'Automatiškai', 'Laisvai pastatomas', 'Šaldiklis apačioje', 'Rankinis', '1', '197', '65.5', '75', 'Taip', '59.5', 'gab_0002', 'POB602EK']
# 7 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Spalva']
# 7 ['Polar', 'Su kamera apačioje', 'Laisvai statomi', 'E', '197.0', '158.8', 'Pilka\n\nJuoda']
# 29 https://www.varle.lt/saldytuvai/bsh-fclwr-wroclaw-serija-4-laisvai-statomas-saldytuvas-saldiklis--20783689.html
# Bsh Fclwr Wroclaw Serija 4, Laisvai statomas šaldytuvas-šaldiklis su šaldiklio skyriumi apačioje, 203 x 60 cm, Baltas KGN397WCT
# 849.99
# 998.54
#  €
# 62 ['Energijos vartojimo efektyvumo klasė (reglamentas (es) 2017/1369)', 'Pagrindinė produkto spalva', 'Automatinis atitirpinimas', 'Ore skleidžiamas akustinis triukšmas', 'Šviežumo sistema', 'Big box', 'Prijungti prietaisai su home connect', 'Ore skleidžiamo akustinio triukšmo klasė', 'Pagrindinė produkto spalva', 'Korpuso spalva / medžiaga', 'Durelių vyris', 'Durelių panelio pakeitimo galimybė', 'Durelių rankenėlės tipas', 'Automatinis atitirpinimas', 'Valdymo nustatymo ir signalizavimo įtaisų tipas', 'Energijos vartojimo efektyvumo klasė (reglamentas (es) 2017/1369)', 'Vidutinės metinės energijos sąnaudos kilovatvalandėmis per metus (kwh/m.)', 'Atšaldymo kamerų tūrių suma', 'Šaldymo temperatūros kamerų tūrių suma', 'Ore skleidžiamas akustinis triukšmas', 'Ore skleidžiamo akustinio triukšmo klasė', 'Klimato klasė', 'Integruoti priedai', 'Gaminio išmatavimai', 'Minimalus montavimo nišos aukštis', 'Maksimalus montavimo nišos aukštis', 'Mažiausias montavimo angos plotis', 'Didžiausias montavimo angos plotis', 'Montavimo gylis', 'Svoris neto', 'Šviežumo sistema', 'Supercooling', 'Superfreezing', 'Low frost', 'Butelių lentynos tipas', 'Big box', 'Vario zone', 'Easyaccess lentynos', 'Ecomode', 'Pagrindinis jutiklinis valdymas', 'Vario lentyna', 'Itin tylūs prietaisai', 'Lentynėlių skaičius šaldytuvo skyriuje', 'Reguliuojamo aukščio lentynėlių skaičius šaldytuvo skyriuje (vnt)', 'Durų dėžučių skaičius šaldytuvo skyriuje', 'Apšvietimo galingumas - šaldytuvas', 'Klasė žvaigždutėmis', 'Produktų laikymo laikas, nutrūkus elektros tiekimui, (h)', 'Šaldymo stalčių skaičius (vnt)', 'Atsidarančių lentynų skaičius šaldiklyje (vnt)', 'Ledo kubelių šaldymo indų skaičius', 'Prijungti prietaisai su home connect', 'Kamera', 'Energijos suvartojimas išjungtas', 'Energijos suvartojimas budėjimo režimu / įjungtas ekranas', 'Energijos suvartojimas budėjimo režimu / ekranas išjungtas', 'Energijos suvartojimas budėjimo / tinklo režimu (kaip išjungti "wifi" modulį, rasite naudotojo vadove)', 'Automatinio išjungimo laikas', 'Laiko automatinis budėjimo režimas / ekranas įjungtas', 'Laiko automatinis budėjimo / ekrano išjungimas', 'Automatinio budėjimo / tinklo laikas', 'Modelio pavadinimas']
# 62 ['C', 'Baltas', 'Fridge and freezer', '35                  db(a) re 1pw', 'Freshness plus  freshness standard', 'Ne', 'Ne', 'B', 'Baltas', 'Balta', 'Dešinėje, grįžtamasis', 'Negalima', 'Vertikali rankena', 'Fridge and freezer', 'Šaldytuvo temperatūros rodymas  taupymo režimas / atostogų nustatymas  šaldiklio temperatūra  atidarytų durų signalas  super nustatymas šaldytuvui  super nustatymas šaldytuvui  įspėjamasis signalas esant trikdžiams  įspėjamoji funkcija šaldiklio skyriui', 'C', '162                  kwh/annum', '260                  l', '103                  l', '35                  db(a) re 1pw', 'B', 'Tropinio  subtropinio  išplėstinė temperatūra  vidutinio klimato', '1 x ledo kubelių forma', '2030x600x665                   mm', 'Mm', 'Mm', 'Mm', 'Mm', 'Mm', '73,7                  kg', 'Freshness plus  freshness standard', 'Taip', 'Taip', 'Ne', '1 bottle support grid', 'Ne', 'Ne', 'Ne', 'Taip', 'Taip', 'Ne', 'Ne', '5', '3', '4', 'Šviesos diodas su švelniu paleidimu', '4', '15                  h', '3', '0', '1', 'Ne', 'Ne', 'W', 'W', 'W', 'W', 'Min', 'Min', 'Min', 'Min', 'KGN397WCT']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['Bsh Fclwr Wroclaw', 'Su kamera apačioje', 'Laisvai statomi', 'C', '363.0', '203.0', 'Yra', 'Balta']
# 30 https://www.varle.lt/saldytuvai/imontuojamas-saldytuvas-liebherr-irbd-5151--16451714.html
# LIEBHERR IRBd 5151 Įmontuojamas šaldytuvas
# 1579.99
# 1915.99
#  €
# 39 ['Gamintojas', 'Garso lygio klasė', 'Oro valymo filtras', 'Naudinga šaldytuvo talpa', 'Naujoji energijos vartojimo efektyvumo klasė', 'Apšvietimas', 'Greito užšaldymo funkcija šaldiklyje', 'Vėsaus stalčiaus teleskopiniai bėgeliai', 'Drėgmės išlaikymo technologija', 'Keičiama durų atidarymo kryptis', 'Atostogų funkcija', 'Gylis', 'Aukštis', 'Metinės energijos sąnaudos', 'Minkštas durelių uždarymas', 'Individualus lentynėlių išdėstymas durelėse', 'Montavimo tipas', 'Klimato klasė', 'Metalizuota galinė sienelė', 'Greitas vėsinimas šaldytuve', 'Valdymas', 'Atvirų durų signalas', 'Šalčio išlaikymo trukmė šaldiklyje nutrūkus elektros tiekimui', 'Užšaldymo galingumas per 24 val.', 'Spalva', 'Standartizuotas aukštis', 'Šaldymo technologijos tipas', 'Ekonominis režimas', 'Naudinga šaldiklio talpa', 'Vyrių tipas', 'Tipas', 'Svoris', 'Naudinga talpa vėsaus stalčiaus', 'Plotis', 'Vėsusis stalčius', 'Tiukšmo lygis', 'Standartizuotas plotis', 'Ledukų generatorius', 'Modelio pavadinimas']
# 39 ['Liebherr', 'B', 'Yra', '250', 'D', 'LED', 'Nėra', 'Yra', 'Yra', 'Yra', 'Yra', '55.0', '177.2', '164', 'Yra', 'Nėra', 'Pastatytas', 'SN-T', 'Yra', 'Yra', 'Internal touch control LCD', 'Yra', '14', '2.0', 'Balta', '180', 'statinis', 'Yra', '27', 'Door on door', 'Fridge with freezer inside', '65.6', '98', '56.0', 'Tikroji 0°C zona', '34', '60.0', 'Ne', 'IRBD5151']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['Liebherr', 'Su kamera viduje', 'Įmontuojami', 'D', '277.0', '177.2', 'Nėra', 'Balta']
# 31 https://www.varle.lt/saldytuvai/goddess-single-door-saldytuvas-with-saldiklis-compartment--39621724.html
# Goddess Single-door Šaldytuvas with šaldiklis compartment | GODRSE084GW8SE | Energy efficiency class E | Free standing | Larder | Height 83.8 cm | Šaldytuvas net capacity 74 L | Šaldiklis net capacity 8 L | 41 dB | Baltas
# 195.99
# 229.99
#  €
# 3 ['Gamintojas', 'Modelis', 'Modelio pavadinimas']
# 3 ['Goddess', 'GODRSE084GW8SE', 'GODRSE084GW8SE']
# 1 ['Gamintojas']
# 1 ['Goddess']
# 32 https://www.varle.lt/saldytuvai/lg-saldytuvas-gbv7180cpy-energy-efficiency-class--32152423.html
# LG | Šaldytuvas | GBV7180CPY | Energy efficiency class C | Free standing | Combi | Height 186 cm | No Frost system | Šaldytuvas net capacity 234 L | Šaldiklis net capacity 110 L | Ekranas | 35 dB | Sidabrinis
# 679.99
# 1132.24
#  €
# 3 ['Gamintojas', 'Modelis', 'Modelio pavadinimas']
# 3 ['LG', 'GBV7180CPY', 'GBV7180CPY']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['LG', 'Su kamera apačioje', 'Laisvai statomi', 'C', '234.0', '186.0', 'Yra', 'Sidabrinė']
# 33 https://www.varle.lt/saldytuvai/built-in-saldytuvas-whirlpool-70cm--28243109.html
# Šaldytuvas Whirlpool WHSP70T241P
# 995.25
# 1045.99
#  €
# 29 ['Gamintojas', 'Modelis', 'Modelis', 'Šaldymo skyriaus vieta', 'Spalva', 'Aukštis', 'Durelių atidarymas', 'Energijos sąnaudos', 'Šaldymo kameros atitirpinimo metodas', 'Šaldytuvo tipas', 'Šaldytuvo skyriaus talpa', 'Šaldiklio talpa', 'Durų surinkimas', 'Užšaldymo galia', 'Montavimo tipas', 'Šaldytuvo skyriaus atšildymo metodas', 'Plotis', 'Laikymo trukmė gedimų metu', 'Durų kiekis', 'Bendra talpa', 'Šaldiklio žvaigždutės', 'Reglamento numeris', 'Ore sklindančio akustinio triukšmo įvertinimas', 'Gylis', 'Triukšmo galia', 'Vandens jungtis', 'Ekranas', 'Papildomos funkcijos', 'Modelio pavadinimas']
# 29 ['Whirlpool', 'WHSP70T241P', 'WHSP70T241P', 'Apačioje', 'Pilnai įmontuojama', '193.5', 'Į dešinę', '257.0', 'Automatiškai', 'Šaldytuvas', '295.0', '99.0', 'ant bėgių', '10.0', 'Integruota', 'Automatiškai', '69.0', '9.0', 'dvejos durys', '394.0', '[ * ] * * *', '2019/2016', 'B', '55.1', '32.0', 'nėra ryšio', 'Taip', 'LED light, 6th Sense, Push to Open', 'WHSP70T241P']
# 7 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema']
# 7 ['Whirlpool', 'Su kamera apačioje', 'Įmontuojami', 'D', '394.0', '193.5', 'Yra']
# 34 https://www.varle.lt/saldytuvai/saldytuvas-gastronominis-saldymo-stalas-4-stalciai--40272162.html
# Šaldytuvas Gastronominis šaldymo stalas, 4 stalčiai, 280 l, 136 x 70 x 85 cm
# 1839.99
# 2850.59
#  €
# 2 ['Modelis', 'Modelio pavadinimas']
# 2 ['HP1025892', 'HP1025892']
# 35 https://www.varle.lt/saldytuvai/saldytuvas-royal-catering-saldymo-vitrina-su-led-apsvietimu--40149283.html
# Šaldytuvas Royal Catering Šaldymo vitrina su LED apšvietimu, 2 lentynos, 180 l
# 615.99
# 679.99
#  €
# 4 ['Gamintojas', 'Modelis', 'Svoris', 'Modelio pavadinimas']
# 4 ['Royal Catering', '10013103', '91', 'LED2']
# 5 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Talpa (L)', 'Aukštis (cm)']
# 5 ['Royal Catering', 'Vitrina', 'Įmontuojami', '180.0', '145.0']
# 36 https://www.varle.lt/saldytuvai/saldytuvas-gorenje-rb493pw-baltas--25438488.html
# Šaldytuvas Gorenje RB493PW baltas
# 229.99
# 295.99
#  €
# 20 ['Gamintojas', 'Modelis', 'Pakeisti durų atidarymo kryptį', 'Durelių skaičius', 'Šaldytuvo talpa [l]', 'Svoris', 'Šaldiklio talpa [l]', 'Aukštis [mm]', 'Šaldiklio skyrių skaičius', 'Gylis [mm]', 'Triukšmo lygis [db]', 'Šaldytuvo skyrių skaičius', 'Svoris [kg]', 'Vertė', 'Plotis [mm]', 'Maitinimo įvestis [w]', 'Spalva', 'Šaldiklio vieta', 'Klimato klasė', 'Modelio pavadinimas']
# 20 ['Gorenje', 'RB493PW', 'Taip', '1', '105', '35,00000', '14', '845', '1', '579', '39', '3', '31', 'RB493PW', '560', '80', 'Balta', 'aukščiau', 'ST', 'RB493PW']
# 3 ['Gamintojas', 'Aukštis (cm)', 'Spalva']
# 3 ['Gorenje', '84.5', 'Balta']
# 37 https://www.varle.lt/saldytuvai/saldytuvas-hisense-rb440n4gbd--29871329.html
# Šaldytuvas HISENSE RB440N4GBD
# 515.99
# 629.99
#  €
# 27 ['Gamintojas', 'Modelis', 'Triukšmo galia', 'Svoris', 'Bendra talpa', 'Aukštis', 'Durelių atidarymas', 'Energijos sąnaudos', 'Šaldymo kameros atitirpinimo metodas', 'Šaldytuvo tipas', 'Šaldiklio talpa', 'Užšaldymo galia', 'Montavimo tipas', 'Šaldymo skyriaus vieta', 'Šaldytuvo skyriaus atšildymo metodas', 'Plotis', 'Laikymo trukmė gedimų metu', 'Rinkinyje yra', 'Šaldytuvo skyriaus talpa', 'Šaldiklio žvaigždutės', 'Reglamento numeris', 'Spalva', 'Ore sklindančio akustinio triukšmo įvertinimas', 'Papildomos funkcijos', 'Gylis', 'Vandens jungtis', 'Modelio pavadinimas']
# 27 ['Hisense', 'RB440N4GBD', '36.0', '66.5', '336.0', '200.4', 'Į dešinę', '197.0', 'Automatiškai', 'Šaldytuvas', '98.0', '6.0', 'Laisvai pastatoma', 'Apačioje', 'Automatiškai', '59.5', '15.0', 'wine rack, ice tray, egg rack, ice cube tray', '238.0', '[ * ] * * *', '2019/2016', 'Juoda', 'C', 'LED lemputė', '59.0', 'nėra ryšio', 'RB440N4GBD']
# 8 ['Gamintojas', 'Tipas', 'Montavimo tipas', 'Energijos klasė', 'Talpa (L)', 'Aukštis (cm)', 'Bešerkšnė sistema', 'Spalva']
# 8 ['Hisense', 'Su kamera apačioje', 'Laisvai statomi', 'D', '336.0', '200.0', 'Yra', 'Juoda']
# 38 https://www.varle.lt/saldytuvai/saldytuvas-midea-mdrb521mgb02--34874779.html
# Šaldytuvas Midea MDRB521MGB02
# 729.99
# 919.99
#  €
# 25 ['Gamintojas', 'Modelis', 'Durelių skaičius', 'Šaldytuvo talpa [l]', 'Electricity consumption [kwh/year]', 'Refrigerator construction', 'Super užšalimas', 'Šaldiklio talpa [l]', 'Aukštis [mm]', 'Refrigerator design', 'Type of refrigerator', 'Gylis [cm]', 'Pakeisti durų atidarymo kryptį', 'Gylis [mm]', 'Šaldiklio vieta', 'Triukšmo lygis [db]', 'Total volume [l]', 'Plotis [cm]', 'Spalva', 'Plotis [mm]', 'Aukštis [cm]', 'Ekranas', 'Svoris', 'Vertė', 'Modelio pavadinimas']
# 25 ['Midea', '40048080', '2', '256', '140', 'Kombinuotas', 'Taip', '122', '2010', 'with freezer compartment', 'Laisvai pastatomas', '70', 'Taip', '700', 'žemyn', '35', '378', '59,5', 'Sidabrinė', '595', '201', 'Taip', '104,14000', '40048080', '40048080']
# 1 ['Gamintojas']
# 1 ['Midea']
# Baigta!!!
